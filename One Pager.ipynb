# %% [markdown]
# # Python files that contains 'sklearn'

# %%
from bigquery_python_framework.GithubPython import GithubPython

# %%
sklearnFile = GithubPython().uniqueFiles().contains('sklearn').excludeByRepoName('sklearn').getCount().run()[0][0]
print("There are {} files containing 'sklearn'".format(sklearnFile))
# Out:
# There are 43629 files containing 'sklearn'

# %%
totalFile = GithubPython().uniqueFiles().getCount().run()[0][0]

# %%
print('There are {} files in total'.format(totalFile))
# Out:
# There are 5995653 files in total

# %%
print('Percentage: %f%%'%(sklearnFile/totalFile*100))
# Out:
# Percentage: 0.727677%

# %% [markdown]
# # Modules that import most 'sklearn'

# %%
moduleImportMostSklearn = GithubPython().module_with_most_import()

# %%
moduleImportMostSklearn[:20]
# Out:
# [('seckcoder/lang-learn', 121),
#  ('magic2du/contact_matrix', 96),
#  ('jpzk/evopy', 87),
#  ('GbalsaC/bitnamiP', 71),
#  ('loli/sklearn-ensembletrees', 61),
#  ('chaluemwut/fbserver', 57),
#  ('zooniverse/aggregation', 51),
#  ('B3AU/waveTree', 49),
#  ('valexandersaulys/airbnb_kaggle_contest', 47),
#  ('kedz/cuttsum', 47),
#  ('Tjorriemorrie/trading', 47),
#  ('southpaw94/MachineLearning', 47),
#  ('akhilpm/Masters-Project', 46),
#  ('salma1601/nilearn', 45),
#  ('diogo149/CauseEffectPairsPaper', 42),
#  ('NicovincX2/Python-3.5', 38),
#  ('chemelnucfin/tensorflow', 37),
#  ('abenicho/isvr', 37),
#  ('ainafp/nilearn', 37),
#  ('weissercn/MLTools', 37)]

# %% [markdown]
# # Context

# %%
def printContext(fileName = 'RFC.csv', num = 10):
    import csv
    with open('context/{}'.format(fileName),'r') as f:
        spamreader = csv.reader(f, delimiter=',', quotechar='"')
        i = 0
        for row in spamreader:
            if i < 2:
                i += 1
                continue
            if i >= num + 2:
                break
            print(row[0])
            print('\n------------------------------Separator------------------------------\n')
            i += 1

# %%
printContext()
# Out:
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.svm import SVC
# from sklearn.tree import DecisionTreeClassifier
#
#
# # classification models
# classifiers = {'K-Nearest Neighbors (Braycurtis norm)':
#                KNeighborsClassifier(n_neighbors=3, algorithm='auto',
#                                     metric='braycurtis'),
#                'Random Forest':
#                RandomForestClassifier(n_estimators=80, n_jobs=1),
#                'SVM': SVC(gamma=2, C=1),
#                'Linear Support Vector Machine': SVC(kernel="linear", C=0.025),
#                'Decision Tree': DecisionTreeClassifier(max_depth=5),
#                'Ada Boost': AdaBoostClassifier(n_estimators=80,
#                                                learning_rate=0.4),
#                'Naive Bayes': GaussianNB(),
#                }
# vc = VotingClassifier(estimators=list(classifiers.items()), voting='hard')
#
#
# ------------------------------Separator------------------------------
#
# from sklearn.ensemble import AdaBoostClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.svm import SVC
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score
#
# classifers_dict = {'AdaBoost': AdaBoostClassifier(n_estimators=50,
#                                                   learning_rate=1),
#                     'Random Forest': RandomForestClassifier(n_estimators=10,
#                                                             # max_depth=None,
#                                                             min_samples_split=50,
#                                                             random_state=0),
#                     'Naive Bayes': GaussianNB(),
#                     'SVM': SVC(C=1.5, kernel='poly', degree=2, gamma=0.),
#                     'Tree': DecisionTreeClassifier(),
#                     'KNN': KNeighborsClassifier(n_neighbors=22)
#                     }
#
#
# ------------------------------Separator------------------------------
#
#     # train_data = train_data[train_data['Credit_History'] == 1.0]
#     # print train_data['Month_Pay'].value_counts()
#
#     baseline_prediction = train_data.apply(classify, axis=1)
#     baseline_score = metrics.accuracy_score(baseline_prediction, train_data['Loan_Status'])
#     print "Baseline: {:.3f}%".format(baseline_score*100)
#     print confusion_matrix(train_data['Loan_Status'], baseline_prediction)
#
#     # model = LogisticRegression(C=1, class_weight='balanced')
#     # model = DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=5)
#     # model = RandomForestClassifier(n_estimators=100)
#     # model = MLPClassifier(algorithm='l-bfgs', alpha=1e-5, hidden_layer_sizes=(10, 3), random_state=1)
#     # model = RandomForestClassifier(n_estimators=25, min_samples_split=25, max_depth=7, max_features=1)
#     # model = SVC(C= 1.0, kernel= 'rbf', class_weight={'Y': 4, 'N':1})
#     # model = SGDClassifier(class_weight='balanced')
#     # model = GaussianNB()
#
#     # params = {'n_estimators': 100, 'max_depth': 5, 'subsample': 0.5,
#     #       'learning_rate': 0.01, 'min_samples_leaf': 1, 'random_state': 3}
#     # model = ensemble.GradientBoostingClassifier(**params)
#
# ------------------------------Separator------------------------------
#
# from sklearn.metrics import f1_score
# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score
# from sklearn.ensemble import RandomForestClassifier
# import numpy as np
#
# from skml.problem_transformation import LabelPowerset
# from skml.datasets import load_dataset
#
# X, y = load_dataset('yeast')
# clf = LabelPowerset(RandomForestClassifier())
# clf.fit(X, np.array(y))
# y_pred = clf.predict(X)
#
# print("real: ", y.shape)
# print("y_pred: ", y_pred.shape)
#
# print("hamming loss: ")
# print(hamming_loss(y, y_pred))
#
#
# ------------------------------Separator------------------------------
#
# df = pd.read_csv("parsed.csv")
# y1 = df["admission_type_id"].values
# y2 = df["discharge_disposition_id"].values
# columns = list(df)[1:4] + list(df)[8:49]
# print columns
# X = df[columns].values
#
# X1_train, X1_test, y1_train, y1_test = train_test_split(X, y1, test_size = 0.20)
# X2_train, X2_test, y2_train, y2_test = train_test_split(X, y2, test_size = 0.20)
#
# clf1 = RandomForestClassifier()
# clf2 = RandomForestClassifier()
#
# clf1.fit(X1_train, y1_train)
# clf2.fit(X2_train, y2_train)
# y1_pred = clf1.predict(X1_test)
# y2_pred = clf2.predict(X2_test)
#
# acc1 = accuracy_score(y1_test, y1_pred)
# acc2 = accuracy_score(y2_test, y2_pred)
#
# ------------------------------Separator------------------------------
#
#     count_enrollment = df_sub['3COURSEID'].value_counts()
#     #print "Number of %s enrollment: %s"%(subject,count_enrollment)
#
#     A = df_sub.as_matrix()
#     X = A[:,4:]
#     X = X.astype(np.int64, copy=False)
#     y = A[:,2]
#     y = y.astype(np.int64, copy=False)
#
#     #Training data
#     forest = RandomForestClassifier(n_estimators=10, max_depth=None,
#             min_samples_split=1, random_state=None, max_features=None)
#     clf = forest.fit(X, y)
#     scores = cross_val_score(clf, X, y, cv=5)
#     print scores
#     print "Random Forest Cross Validation of %s: %s"%(subject,scores.mean())
#     precision_rf[subject] = scores.mean()
#     df_precision.loc[subject]=precision_rf[subject]
#     print "-----------------------------------"
#
#
# ------------------------------Separator------------------------------
#
#
#     plt.xlabel('Relative Importance')
#     plt.title('%s: Top Features' %(dataName))
#     plt.grid('off')
#     plt.ion()
#     plt.show()
#     plt.savefig(str(dataName)+'TopFeatures.png',dpi=200)
#
# def altPlotFeaturesImportance(X,y,featureNames,dataName):
#     "http://nbviewer.ipython.org/github/cs109/2014/blob/master/homework-solutions/HW5-solutions.ipynb"
#     clf = RandomForestClassifier(n_estimators=50)
#
#     clf.fit(X,y)
#     importance_list = clf.feature_importances_
#     # name_list = df.columns #ORIG
#     name_list=featureNames
#
#     importance_list, name_list = zip(*sorted(zip(importance_list, name_list)))
#     plt.barh(range(len(name_list)),importance_list,align='center')
#     plt.yticks(range(len(name_list)),name_list)
#
# ------------------------------Separator------------------------------
#
# # strings.
# train_data_features = vectorizer.fit_transform(train_data).toarray()
#
# print(train_data_features.shape)
#
#
# #http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# # Initialize a Random Forest classifier with trees
# # use as many CPU cores as possible (n_jobs=-1)
# forest = RandomForestClassifier(n_estimators = 1000, n_jobs=-1, verbose=2)
#
# # Fit the forest to the training set, using the bag of words as
# # features and the sentiment labels as the response variable
# #
# # This may take a few minutes to run
# forest = forest.fit(train_data_features, train["sponsored"])
#
#
# #Run the prediction...
#
# ------------------------------Separator------------------------------
#
#     y2 += [dep(test)]
#   return x1,y1,x2,y2
#
# def learns(tests,trains,indep=lambda x: x[:-1],
#                     dep = lambda x: x[-1],
#                     rf  = Abcd(),
#                     lg  = Abcd(),
#                     dt  = Abcd(),
#                     nb  = Abcd()):
#   x1,y1,x2,y2= trainTest(tests,trains,indep,dep)
#   forest = RandomForestClassifier(n_estimators = 50)
#   forest = forest.fit(x1,y1)
#   for n,got in enumerate(forest.predict(x2)):
#     rf(predicted = got, actual = y2[n])
#   logreg = linear_model.LogisticRegression(C=1e5)
#   logreg.fit(x1, y1)
#   for n,got in enumerate(logreg.predict(x2)):
#     lg(predicted = got, actual = y2[n])
#   bayes =  GaussianNB()
#   bayes.fit(x1,y1)
#
# ------------------------------Separator------------------------------
#
#     :param selectKBest: The number of best features to select
#     :type selectKBest: int
#     :param kfold: The number of folds to use in K-fold CV
#     :type kfold: int
#     :return: A list of predicted labels across the k-folds
#     """
#     try:
#         # Prepare data
#         X, y = numpy.array(X), numpy.array(y)
#         # Define classifier
#         clf = ensemble.RandomForestClassifier(n_estimators=estimators, criterion=criterion, max_depth=maxdepth)
#         if selectKBest > 0:
#             X_new = SelectKBest(chi2, k=selectKBest).fit_transform(X, y)
#             predicted = cross_val_predict(clf, X_new, y, cv=kfold).tolist()
#         else:
#             predicted = cross_val_predict(clf, X, y, cv=kfold).tolist()
#     except Exception as e:
#         prettyPrintError(e)
#         return []
#
#
# ------------------------------Separator------------------------------

# %% [markdown]
# # BaseEstimator + @deprecated

# %%
queryString = """\
SELECT
  sample_repo_name,
  sample_path,
FROM 
  [scikit-learn-research:pyfiles.content_py] 
WHERE
  content CONTAINS 'BaseEstimator'
  AND content CONTAINS '@deprecated'
  AND (NOT RIGHT(sample_repo_name,12) = "scikit-learn")
  AND (NOT RIGHT(sample_repo_name,7) = "sklearn")
"""
baseEstimatorDeprecated = GithubPython()
result = baseEstimatorDeprecated.run(queryString)

# %%
def getGithubURL(result):
    for repo_name, path in result:
        print("https://github.com/{}/tree/master/{}".format(repo_name,path))

# %%
getGithubURL(result)
# Out:
# https://github.com/chaluemwut/fbserver/tree/master/venv/lib/python2.7/site-packages/sklearn/feature_extraction/text.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/preprocessing/data.py
# https://github.com/juharris/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/naturali/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/sandeepdsouza93/TensorFlow-15712/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/nanditav/15712-TensorFlow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/alisidd/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/mengxn/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/nanditav/15712-TensorFlow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/johndpope/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/bmcfee/librosa/tree/master/librosa/util/feature_extractor.py
# https://github.com/chaluemwut/fbserver/tree/master/venv/lib/python2.7/site-packages/sklearn/decomposition/pca.py
# https://github.com/caisq/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/haeusser/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/mjudsp/Tsallis/tree/master/sklearn/decomposition/nmf.py
# https://github.com/SubhasisDutta/WireframeTagging/tree/master/tensorflow/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/JVillella/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/Denisolt/Tensorflow_Chat_Bot/tree/master/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/dwettstein/pattern-recognition-2016/tree/master/mlp/gaussian_process/gaussian_process.py
# https://github.com/smartscheduling/scikit-learn-categorical-tree/tree/master/sklearn/svm/base.py
# https://github.com/RPGOne/Skynet/tree/master/scikit-learn-c604ac39ad0e5b066d964df3e8f31ba7ebda1e0e/sklearn/preprocessing/label.py
# https://github.com/pierreg/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/AndreasMadsen/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/ppries/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/mrry/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/DCSaunders/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/linear_model/stochastic_gradient.py
# https://github.com/ppries/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/wangyum/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/4Catalyzer/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/RPGOne/Skynet/tree/master/scikit-learn-0.18.1/sklearn/mixture/gmm.py
# https://github.com/Bismarrck/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/abhitopia/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/xzturn/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/aselle/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/tillahoffmann/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/neilhan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/renyi533/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/tongwang01/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/wangyum/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/joewalter/mne-python/tree/master/mne/decoding/transformer.py
# https://github.com/nanditav/15712-TensorFlow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/ensemble/gradient_boosting.py
# https://github.com/whn09/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/code-sauce/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/svm/base.py
# https://github.com/Bismarrck/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/aselle/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/XueqingLin/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/LUTAN/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/davidzchen/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/manazhao/tf_recsys/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/alexandrebarachant/mne-python/tree/master/mne/decoding/transformer.py
# https://github.com/BrianPin/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/tobegit3hub/deep_cnn/tree/master/java_predict_client/src/main/proto/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/anand-c-goog/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/loli/sklearn-ensembletrees/tree/master/sklearn/dummy.py
# https://github.com/laosiaudi/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/mjudsp/Tsallis/tree/master/sklearn/ensemble/gradient_boosting.py
# https://github.com/junpenglao/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/juharris/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/uglyboxer/linear_neuron/tree/master/net-p3/lib/python3.5/site-packages/sklearn/multiclass.py
# https://github.com/Weihonghao/ECM/tree/master/Vpy34/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/LUTAN/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/handroissuazo/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/tests/test_base.py
# https://github.com/cg31/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/laosiaudi/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/eerwitt/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/Denisolt/Tensorflow_Chat_Bot/tree/master/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/elingg/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/sandeepdsouza93/TensorFlow-15712/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/GbalsaC/bitnamiP/tree/master/venv/lib/python2.7/site-packages/sklearn/gaussian_process/gaussian_process.py
# https://github.com/GbalsaC/bitnamiP/tree/master/venv/lib/python2.7/site-packages/sklearn/mixture/gmm.py
# https://github.com/cg31/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/ryfeus/lambda-packs/tree/master/Sklearn_scipy_numpy/source/sklearn/feature_selection/from_model.py
# https://github.com/nelango/ViralityAnalysis/tree/master/model/lib/sklearn/decomposition/nmf.py
# https://github.com/caisq/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/Sklearn-HMM/scikit-learn-HMM/tree/master/sklean-hmm/linear_model/stochastic_gradient.py
# https://github.com/WangWenjun559/Weiss/tree/master/summary/sumy/sklearn/ensemble/gradient_boosting.py
# https://github.com/asnorkin/sentiment_analysis/tree/master/site/lib/python2.7/site-packages/sklearn/feature_selection/from_model.py
# https://github.com/HKUST-SING/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/thesuperzapper/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/RPGOne/Skynet/tree/master/scikit-learn-c604ac39ad0e5b066d964df3e8f31ba7ebda1e0e/sklearn/dummy.py
# https://github.com/GbalsaC/bitnamiP/tree/master/venv/lib/python2.7/site-packages/sklearn/hmm.py
# https://github.com/johnowhitaker/bobibabber/tree/master/sklearn/hmm.py
# https://github.com/valexandersaulys/prudential_insurance_kaggle/tree/master/venv/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.py
# https://github.com/RapidApplicationDevelopment/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/mortada/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/yaroslavvb/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/juharris/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/gnieboer/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/juharris/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/scenarios/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/neale/CS-program/tree/master/434-MachineLearning/final_project/linearClassifier/sklearn/gaussian_process/gaussian_process.py
# https://github.com/seckcoder/lang-learn/tree/master/python/sklearn/sklearn/decomposition/fastica_.py
# https://github.com/MostafaGazar/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/RapidApplicationDevelopment/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/junpenglao/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/sandeepdsouza93/TensorFlow-15712/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/tobegit3hub/deep_cnn/tree/master/java_predict_client/src/main/proto/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/tobegit3hub/deep_cnn/tree/master/java_predict_client/src/main/proto/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/JosmanPS/parallel-SVM/tree/master/m_learning/svm/base.py
# https://github.com/4Catalyzer/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/pierreg/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/kamcpp/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/ZhangXinNan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/tongwang01/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/renyi533/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/haribharadwaj/mne-python/tree/master/mne/decoding/time_gen.py
# https://github.com/gibiansky/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/linear_model/base.py
# https://github.com/jeffzheng1/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/SubhasisDutta/WireframeTagging/tree/master/tensorflow/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/Denisolt/Tensorflow_Chat_Bot/tree/master/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/WangWenjun559/Weiss/tree/master/summary/sumy/sklearn/svm/base.py
# https://github.com/ryfeus/lambda-packs/tree/master/Tensorflow/sources/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/neilhan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/AndreasMadsen/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/byronyi/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/wangyum/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/gautam1858/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/manjunaths/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/lancezlin/ml_template_py/tree/master/lib/python2.7/site-packages/sklearn/decomposition/pca.py
# https://github.com/RapidApplicationDevelopment/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/chaluemwut/fbserver/tree/master/venv/lib/python2.7/site-packages/sklearn/mixture/gmm.py
# https://github.com/ryfeus/lambda-packs/tree/master/Sklearn_scipy_numpy/source/sklearn/svm/base.py
# https://github.com/aselle/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/byronyi/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/gojira/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/psarka/uplift/tree/master/uplift/preprocessing/data.py
# https://github.com/Mistobaan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/gaussian_process/gaussian_process.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/feature_selection/from_model.py
# https://github.com/WangWenjun559/Weiss/tree/master/summary/sumy/sklearn/multiclass.py
# https://github.com/hubertjb/mne-python/tree/master/mne/decoding/base.py
# https://github.com/Denisolt/Tensorflow_Chat_Bot/tree/master/local/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/Mazecreator/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/asnorkin/sentiment_analysis/tree/master/site/lib/python2.7/site-packages/sklearn/svm/base.py
# https://github.com/Mistobaan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/liyi193328/seq2seq/tree/master/seq2seq/contrib/estimator.py
# https://github.com/psarka/uplift/tree/master/uplift/tests/test_base.py
# https://github.com/anand-c-goog/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/scenarios/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/rew4332/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/dlatk/dlatk/tree/master/dlatk/pca_mod.py
# https://github.com/ikaee/bfr-attendant/tree/master/facerecognitionlibrary/jni-build/jni/include/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/pierreg/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/XueqingLin/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/haeusser/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/Bismarrck/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/AndreasMadsen/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/HKUST-SING/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/benoitsteiner/tensorflow-opencl/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/markslwong/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/elingg/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/jwlawson/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/neilhan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/renyi533/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/mdrumond/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/dimroc/tensorflow-mnist-tutorial/tree/master/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/AndreasMadsen/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/ppries/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/aselle/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/tongwang01/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/pavelchristof/gomoku-ai/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/GehenHe/Recognize-Face-on-Android/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/tongwang01/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/seaotterman/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/aselle/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/sugartom/tensorflow-alien/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/GbalsaC/bitnamiP/tree/master/venv/lib/python2.7/site-packages/sklearn/linear_model/stochastic_gradient.py
# https://github.com/4Catalyzer/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/jjas0nn/solvem/tree/master/tensorflow/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/jjx02230808/project0223/tree/master/sklearn/linear_model/stochastic_gradient.py
# https://github.com/mjudsp/Tsallis/tree/master/sklearn/svm/base.py
# https://github.com/tongwang01/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/pierreg/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/CforED/Machine-Learning/tree/master/sklearn/gaussian_process/gaussian_process.py
# https://github.com/GbalsaC/bitnamiP/tree/master/venv/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/base.py
# https://github.com/mrry/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/yaroslavvb/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/ppries/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/alheinecke/tensorflow-xsmm/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/cg31/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/cg31/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/Mistobaan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/code-sauce/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/kevin-coder/tensorflow-fork/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/rew4332/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/zhonghualiu/FaST-LMM/tree/master/fastlmm/external/pca.py
# https://github.com/cg31/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/caisq/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/haeusser/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/B3AU/waveTree/tree/master/sklearn/linear_model/stochastic_gradient.py
# https://github.com/DCSaunders/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/nanditav/15712-TensorFlow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/cg31/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/Astroua/SCIMES/tree/master/scimes/spectral.py
# https://github.com/WangWenjun559/Weiss/tree/master/summary/sumy/sklearn/linear_model/stochastic_gradient.py
# https://github.com/jeffzheng1/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/odejesush/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/tomasreimers/tensorflow-emscripten/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/ageron/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/kevin-coder/scikit-learn-fork/tree/master/sklearn/decomposition/pca.py
# https://github.com/guschmue/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/SubhasisDutta/WireframeTagging/tree/master/tensorflow/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/Weihonghao/ECM/tree/master/Vpy34/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/AsimmHirani/ISpyPi/tree/master/tensorflow/contrib/tensorflow-master/tensorflow/contrib/learn/python/learn/estimators/dnn_linear_combined.py
# https://github.com/ppries/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/jeffzheng1/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/liyi193328/seq2seq/tree/master/seq2seq/contrib/monitors.py
# https://github.com/jniediek/mne-python/tree/master/mne/decoding/transformer.py
# https://github.com/seckcoder/lang-learn/tree/master/python/sklearn/sklearn/gaussian_process/gaussian_process.py
# https://github.com/rdipietro/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/mdrumond/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/random_forest.py
# https://github.com/kchodorow/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/AsimmHirani/ISpyPi/tree/master/tensorflow/contrib/tensorflow-master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/psarka/uplift/tree/master/uplift/base.py
# https://github.com/mrry/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/Mistobaan/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/linear.py
# https://github.com/tongwang01/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/XueqingLin/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/utils/export.py
# https://github.com/chaluemwut/fbserver/tree/master/venv/lib/python2.7/site-packages/sklearn/preprocessing/label.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/feature_extraction/text.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/isotonic.py
# https://github.com/nelango/ViralityAnalysis/tree/master/model/lib/sklearn/linear_model/base.py
# https://github.com/caisq/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/haeusser/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py
# https://github.com/krikru/tensorflow-opencl/tree/master/tensorflow/contrib/learn/python/learn/monitors.py
# https://github.com/pcm17/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/svm.py
# https://github.com/ravindrapanda/tensorflow/tree/master/tensorflow/contrib/learn/python/learn/estimators/dnn.py
# https://github.com/DailyActie/Surrogate-Model/tree/master/projects/scikit-learn-master/sklearn/decomposition/nmf.py
# https://github.com/hfp/tensorflow-xsmm/tree/master/tensorflow/contrib/learn/python/learn/estimators/estimator.py

# %% [markdown]
# ## Context of @deprecated in above files

# %%
def getContext(modelName):
  from google.cloud import bigquery
  client = bigquery.Client()
  query = '''\
  #standardSQL
  CREATE TEMPORARY FUNCTION parsePythonFile(a STRING)
  RETURNS STRING
  LANGUAGE js AS """
    if (a === null) {
      return null;
    }
    var lines = a.split('\\\\n');
    for (i=0;i<lines.length;i++) {
      if (lines[i].indexOf("%s")!==-1){
        return lines.slice(Math.max(i-10,0),Math.min(i+10,lines.length-1)).join("\\\\n");
      }
    }
  """;

  CREATE TEMPORARY FUNCTION parsePythonFile2(a STRING, b STRING)
  RETURNS STRING
  LANGUAGE js AS """
    if (a === null) {
      return null;
    }
    var lines = a.split('\\\\n');
    for (i=0;i<lines.length;i++) {
      if (lines[i].indexOf("%s")!==-1){
        return b;
      }
    }
  """;

  SELECT
    parsePythonFile(content) match,
    parsePythonFile2(content,sample_path) path,
    parsePythonFile2(content,sample_repo_name ) repo_name,
    count(*) count
  FROM   
    `scikit-learn-research.pyfiles.content_py` 
  WHERE
    (NOT ENDS_WITH(sample_repo_name, "scikit-learn"))
     AND (NOT ENDS_WITH(sample_repo_name, "sklearn"))
     AND NOT STRPOS(content,'BaseEstimator') = 0
  GROUP BY
  1,2,3
  ORDER BY 
  count DESC
  '''% (modelName,modelName)
  result = client.run_sync_query(query)
  result.timeout_ms = 99999999
  result.run()
  return result

# %%
resultForContext = getContext('@deprecated')

# %%
resultForContext = resultForContext.rows

# %%
for val, _, _, _ in resultForContext[:20]:
    print(val)
    print('\n------------------------------Separator------------------------------\n')
# Out:
# None
#
# ------------------------------Separator------------------------------
#
#     if self._n_classes == 2:
#       metrics.update({
#           "auc": metric_spec.MetricSpec(
#               metric_fn=metrics_lib.streaming_auc,
#               prediction_key=_LOGISTIC,
#               weight_key=self._weight_column_name)})
#     return self._estimator.evaluate(
#         x=x, y=y, input_fn=input_fn, feed_fn=feed_fn, batch_size=batch_size,
#         steps=steps, metrics=metrics, name=name)
#
#   @deprecated_arg_values(
#       estimator.AS_ITERABLE_DATE, estimator.AS_ITERABLE_INSTRUCTIONS,
#       as_iterable=False)
#   def predict(self, x=None, input_fn=None, batch_size=None, as_iterable=True):
#     """Returns predicted classes for given features.
#
#     Args:
#       x: features.
#       input_fn: Input function. If set, x must be None.
#       batch_size: Override default batch size.
#
# ------------------------------Separator------------------------------
#
#     """
#
#     def __init__(self, y_min=None, y_max=None, increasing=True,
#                  out_of_bounds='nan'):
#         self.y_min = y_min
#         self.y_max = y_max
#         self.increasing = increasing
#         self.out_of_bounds = out_of_bounds
#
#     @property
#     @deprecated("Attribute ``X_`` is deprecated in version 0.18 and will be"
#                 " removed in version 0.20.")
#     def X_(self):
#         return self._X_
#
#     @X_.setter
#     def X_(self, value):
#         self._X_ = value
#
#     @X_.deleter
#
# ------------------------------Separator------------------------------
#
#           "joint_weights": _joint_weight,
#       })
#
#     super(LinearClassifier, self).__init__(
#         model_fn=model_fn,
#         model_dir=model_dir,
#         config=config,
#         params=params,
#         feature_engineering_fn=feature_engineering_fn)
#
#   @deprecated_arg_values(
#       estimator.AS_ITERABLE_DATE, estimator.AS_ITERABLE_INSTRUCTIONS,
#       as_iterable=False)
#   @deprecated_arg_values(
#       "2017-03-01",
#       "Please switch to predict_classes, or set `outputs` argument.",
#       outputs=None)
#   def predict(self, x=None, input_fn=None, batch_size=None, outputs=None,
#               as_iterable=True):
#     """Returns predictions for given features.
#
# ------------------------------Separator------------------------------
#
#     self._features_info = None
#     self._labels_info = None
#
#     self._graph = None
#
#   @property
#   def config(self):
#     # TODO(wicke): make RunConfig immutable, and then return it without a copy.
#     return copy.deepcopy(self._config)
#
#   @deprecated_args(
#       SCIKIT_DECOUPLE_DATE, SCIKIT_DECOUPLE_INSTRUCTIONS, ('x', None),
#       ('y', None), ('batch_size', None)
#   )
#   def fit(self, x=None, y=None, input_fn=None, steps=None, batch_size=None,
#           monitors=None, max_steps=None):
#     # pylint: disable=g-doc-args,g-doc-return-or-yield
#     """See `Trainable`.
#
#     Raises:
#
# ------------------------------Separator------------------------------
#
#     self._features_info = None
#     self._labels_info = None
#
#     self._graph = None
#
#   @property
#   def config(self):
#     # TODO(wicke): make RunConfig immutable, and then return it without a copy.
#     return copy.deepcopy(self._config)
#
#   @deprecated_args(
#       SCIKIT_DECOUPLE_DATE, SCIKIT_DECOUPLE_INSTRUCTIONS, ('x', None),
#       ('y', None), ('batch_size', None)
#   )
#   def fit(self, x=None, y=None, input_fn=None, steps=None, batch_size=None,
#           monitors=None, max_steps=None):
#     # pylint: disable=g-doc-args,g-doc-return-or-yield
#     """See `Trainable`.
#
#     Raises:
#
# ------------------------------Separator------------------------------
#
#     self._features_info = None
#     self._labels_info = None
#
#     self._graph = None
#
#   @property
#   def config(self):
#     # TODO(wicke): make RunConfig immutable, and then return it without a copy.
#     return copy.deepcopy(self._config)
#
#   @deprecated_args(
#       SCIKIT_DECOUPLE_DATE, SCIKIT_DECOUPLE_INSTRUCTIONS, ('x', None),
#       ('y', None), ('batch_size', None)
#   )
#   def fit(self, x=None, y=None, input_fn=None, steps=None, batch_size=None,
#           monitors=None, max_steps=None):
#     # pylint: disable=g-doc-args,g-doc-return-or-yield
#     """See `Trainable`.
#
#     Raises:
#
# ------------------------------Separator------------------------------
#
#           matched.append(key)
#     return matched, non_matched
#
#
# class ExportMonitor(EveryN):
#   """Monitor that exports Estimator every N steps."""
#
#   # TODO(philstahlfeld): Investigate switching export.export_estimator
#   # configuration values to **kwargs so that updates to the export_estimator
#   # function don't have to be reflected here.
#   @deprecated_arg_values(
#       "2016-09-23",
#       "The signature of the input_fn accepted by export is changing to be "
#       "consistent with what's used by tf.Learn Estimator's train/evaluate. "
#       "input_fn (and in most cases, input_feature_key) will both become "
#       "required args.",
#       input_fn=None)
#   def __init__(self,
#                every_n_steps,
#                export_dir,
#
# ------------------------------Separator------------------------------
#
#                         max_steps=max_steps)
#     return self
#
#   def evaluate(self, x=None, y=None, input_fn=None, feed_fn=None,
#                batch_size=None, steps=None, metrics=None, name=None):
#     """See evaluable.Evaluable. Note: Labels must be integer class indices."""
#     return self._estimator.evaluate(
#         x=x, y=y, input_fn=input_fn, feed_fn=feed_fn, batch_size=batch_size,
#         steps=steps, metrics=metrics, name=name)
#
#   @deprecated_arg_values(
#       estimator.AS_ITERABLE_DATE, estimator.AS_ITERABLE_INSTRUCTIONS,
#       as_iterable=False)
#   def predict(self, x=None, input_fn=None, batch_size=None, as_iterable=True):
#     """Returns predicted classes for given features.
#
#     Args:
#       x: features.
#       input_fn: Input function. If set, x must be None.
#       batch_size: Override default batch size.
#
# ------------------------------Separator------------------------------
#
# from sklearn.metrics.pairwise import manhattan_distances
# from sklearn.utils import check_random_state, check_array, check_X_y
# from sklearn.utils.validation import check_is_fitted
# from . import regression_models as regression
# from . import correlation_models as correlation
# from sklearn.utils import deprecated
#
# MACHINE_EPSILON = np.finfo(np.double).eps
#
#
# @deprecated("l1_cross_distances is deprecated and will be removed in 0.20.")
# def l1_cross_distances(X):
#     """
#     Computes the nonzero componentwise L1 cross-distances between the vectors
#     in X.
#
#     Parameters
#     ----------
#
#     X: array_like
#
# ------------------------------Separator------------------------------
#
#           "joint_weights": _joint_weight,
#       })
#
#     super(LinearClassifier, self).__init__(
#         model_fn=model_fn,
#         model_dir=model_dir,
#         config=config,
#         params=params,
#         feature_engineering_fn=feature_engineering_fn)
#
#   @deprecated_arg_values(
#       estimator.AS_ITERABLE_DATE, estimator.AS_ITERABLE_INSTRUCTIONS,
#       as_iterable=False)
#   @deprecated_arg_values(
#       "2017-03-01",
#       "Please switch to predict_classes, or set `outputs` argument.",
#       outputs=None)
#   def predict(self, x=None, input_fn=None, batch_size=None, outputs=None,
#               as_iterable=True):
#     """Returns predictions for given features.
#
# ------------------------------Separator------------------------------
#
#
#     return result
#
#   def evaluate(self, x=None, y=None, input_fn=None, feed_fn=None,
#                batch_size=None, steps=None, metrics=None, name=None):
#     """See evaluable.Evaluable."""
#     return self._estimator.evaluate(x=x, y=y, input_fn=input_fn,
#                                     feed_fn=feed_fn, batch_size=batch_size,
#                                     steps=steps, metrics=metrics, name=name)
#
#   @deprecated_arg_values(
#       estimator.AS_ITERABLE_DATE, estimator.AS_ITERABLE_INSTRUCTIONS,
#       as_iterable=False)
#   def predict(self, x=None, input_fn=None, batch_size=None, as_iterable=True):
#     """Runs inference to determine the predicted class."""
#     key = prediction_key.PredictionKey.CLASSES
#     preds = self._estimator.predict(
#         x=x,
#         input_fn=input_fn,
#         batch_size=batch_size,
#
# ------------------------------Separator------------------------------
#
#         reduced_likelihood_function_value = - sigma2.sum() * detR
#         par['sigma2'] = sigma2 * self.y_std ** 2.
#         par['beta'] = beta
#         par['gamma'] = solve_triangular(C.T, rho)
#         par['C'] = C
#         par['Ft'] = Ft
#         par['G'] = G
#
#         return reduced_likelihood_function_value, par
#
#     @deprecated("to be removed in 0.14, access ``self.theta_`` etc. directly "
#                 " after fit.")
#     def arg_max_reduced_likelihood_function(self):
#         return self._arg_max_reduced_likelihood_function()
#
#     @property
#     @deprecated('``theta`` is deprecated and will be removed in 0.14, '
#                 'please use ``theta_`` instead.')
#     def theta(self):
#         return self.theta_
#
# ------------------------------Separator------------------------------
#
#         score = self.init_.predict(X).astype(np.float64)
#         return score
#
#     def _decision_function(self, X):
#         # for use in inner loop, not raveling the output in single-class case,
#         # not doing input validation.
#         score = self._init_decision_function(X)
#         predict_stages(self.estimators_, X, self.learning_rate, score)
#         return score
#
#     @deprecated(" and will be removed in 0.19")
#     def decision_function(self, X):
#         """Compute the decision function of ``X``.
#
#         Parameters
#         ----------
#         X : array-like of shape = [n_samples, n_features]
#             The input samples.
#
#         Returns
#
# ------------------------------Separator------------------------------
#
#     self._features_info = None
#     self._labels_info = None
#
#     self._graph = None
#
#   @property
#   def config(self):
#     # TODO(wicke): make RunConfig immutable, and then return it without a copy.
#     return copy.deepcopy(self._config)
#
#   @deprecated_args(
#       SCIKIT_DECOUPLE_DATE, SCIKIT_DECOUPLE_INSTRUCTIONS, ('x', None),
#       ('y', None), ('batch_size', None)
#   )
#   def fit(self, x=None, y=None, input_fn=None, steps=None, batch_size=None,
#           monitors=None, max_steps=None):
#     # pylint: disable=g-doc-args,g-doc-return-or-yield
#     """See `Trainable`.
#
#     Raises:
#
# ------------------------------Separator------------------------------
#
#     self._features_info = None
#     self._labels_info = None
#
#     self._graph = None
#
#   @property
#   def config(self):
#     # TODO(wicke): make RunConfig immutable, and then return it without a copy.
#     return copy.deepcopy(self._config)
#
#   @deprecated_args(
#       SCIKIT_DECOUPLE_DATE, SCIKIT_DECOUPLE_INSTRUCTIONS, ('x', None),
#       ('y', None), ('batch_size', None)
#   )
#   def fit(self, x=None, y=None, input_fn=None, steps=None, batch_size=None,
#           monitors=None, max_steps=None):
#     # pylint: disable=g-doc-args,g-doc-return-or-yield
#     """See `Trainable`.
#
#     Raises:
#
# ------------------------------Separator------------------------------
#
#         if value1 != value2:
#           non_matched[key] = (value1, value2)
#         else:
#           matched.append(key)
#     return matched, non_matched
#
#
# class ExportMonitor(EveryN):
#   """Monitor that exports Estimator every N steps."""
#
#   @deprecated("2017-03-25",
#               "ExportMonitor is deprecated. Please pass an "
#               "ExportStrategy to Experiment instead.")
#   def __init__(self,
#                every_n_steps,
#                export_dir,
#                input_fn=None,
#                input_feature_key=None,
#                exports_to_keep=5,
#                signature_fn=None,
#
# ------------------------------Separator------------------------------
#
#           matched.append(key)
#     return matched, non_matched
#
#
# class ExportMonitor(EveryN):
#   """Monitor that exports Estimator every N steps."""
#
#   # TODO(philstahlfeld): Investigate switching export.export_estimator
#   # configuration values to **kwargs so that updates to the export_estimator
#   # function don't have to be reflected here.
#   @deprecated_arg_values(
#       "2016-09-23",
#       "The signature of the input_fn accepted by export is changing to be "
#       "consistent with what's used by tf.Learn Estimator's train/evaluate. "
#       "input_fn (and in most cases, input_feature_key) will both become "
#       "required args.",
#       input_fn=None)
#   def __init__(self,
#                every_n_steps,
#                export_dir,
#
# ------------------------------Separator------------------------------
#
#     self.graph_builder_class = graph_builder_class
#     self.training_args = {}
#     self.construction_args = {}
#     self._feature_engineering_fn = (
#         feature_engineering_fn or
#         (lambda features, targets: (features, targets)))
#
#     super(TensorForestEstimator, self).__init__(model_dir=model_dir,
#                                                 config=config)
#
#   @deprecated_arg_values(
#       estimator.AS_ITERABLE_DATE, estimator.AS_ITERABLE_INSTRUCTIONS,
#       as_iterable=False)
#   def predict_proba(
#       self, x=None, input_fn=None, batch_size=None, outputs=None,
#       as_iterable=False):
#     """Returns prediction probabilities for given features (classification).
#
#     Args:
#       x: features.
#
# ------------------------------Separator------------------------------
#
#     self._features_info = None
#     self._labels_info = None
#
#     self._graph = None
#
#   @property
#   def config(self):
#     # TODO(wicke): make RunConfig immutable, and then return it without a copy.
#     return copy.deepcopy(self._config)
#
#   @deprecated_args(
#       SCIKIT_DECOUPLE_DATE, SCIKIT_DECOUPLE_INSTRUCTIONS, ('x', None),
#       ('y', None), ('batch_size', None)
#   )
#   def fit(self, x=None, y=None, input_fn=None, steps=None, batch_size=None,
#           monitors=None, max_steps=None):
#     # pylint: disable=g-doc-args,g-doc-return-or-yield
#     """See `Trainable`.
#
#     Raises:
#
# ------------------------------Separator------------------------------

# %% [markdown]
# ## How about DeprecationWarning + BaseEstimator?

# %%
queryStringForDepreciationWarning = """\
SELECT
  sample_repo_name,
  sample_path,
FROM 
  [scikit-learn-research:pyfiles.content_py] 
WHERE
  content CONTAINS 'BaseEstimator'
  AND content CONTAINS 'DepreciationWarning'
  AND (NOT RIGHT(sample_repo_name,12) = "scikit-learn")
  AND (NOT RIGHT(sample_repo_name,7) = "sklearn")
"""
baseEstimatorDeprecated = GithubPython()
result = baseEstimatorDeprecated.run(queryStringForDepreciationWarning)
getGithubURL(result) #0 result

# %% [markdown]
# ## Only DepreciationWarning?

# %%
queryStringForDepreciationWarningOnly = """\
SELECT
  sample_repo_name,
  sample_path,
FROM 
  [scikit-learn-research:pyfiles.content_py] 
WHERE
  content CONTAINS 'DepreciationWarning'
  AND (NOT RIGHT(sample_repo_name,12) = "scikit-learn")
  AND (NOT RIGHT(sample_repo_name,7) = "sklearn")
"""
depreciationOnly = GithubPython().run(queryStringForDepreciationWarningOnly)
getGithubURL(depreciationOnly)
# Out:
# https://github.com/jaduimstra/nilmtk/tree/master/nilmtk/metrics.py
# https://github.com/mmottahedi/nilmtk/tree/master/nilmtk/feature_detectors/steady_states.py
# https://github.com/total-impact/total-impact-core/tree/master/totalimpact/providers/provider.py
# https://github.com/jaduimstra/nilmtk/tree/master/nilmtk/disaggregate/combinatorial_optimisation.py
# https://github.com/josemao/nilmtk/tree/master/nilmtk/metrics.py
# https://github.com/josemao/nilmtk/tree/master/nilmtk/disaggregate/combinatorial_optimisation.py
# https://github.com/rvbelefonte/Rockfish2/tree/master/rockfish2/navigation/ukooa/p190/database.py
# https://github.com/AlexRobson/nilmtk/tree/master/nilmtk/feature_detectors/cluster.py
# https://github.com/Impactstory/total-impact-webapp/tree/master/totalimpact/providers/provider.py
# https://github.com/nilmtk/nilmtk/tree/master/nilmtk/disaggregate/combinatorial_optimisation.py
