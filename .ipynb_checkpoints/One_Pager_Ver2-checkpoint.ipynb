# %% [markdown]
# # Python files that contains sklearn

# %% [markdown]
# ### We search through all python files that are not a fork of sklearn (by repo_name and path), and count how many files contain 'sklearn' in the content.

# %%
from bigquery_python_framework.GithubPython import GithubPython

# %%
pythonFilesThatContainsSklearn = """\
SELECT
    COUNT(*) count
FROM
    [scikit-learn-research.pyfiles.content_py]
WHERE
    (NOT sample_repo_name CONTAINS "scikit-learn") AND
    (NOT sample_repo_name CONTAINS "sklearn") AND
    (NOT sample_path CONTAINS "scikit-learn") AND
    (NOT sample_path CONTAINS "sklearn") AND
    (REGEXP_MATCH(content, r'from sklearn.*? import .+') OR
    REGEXP_MATCH(content, r'import sklearn'))
"""

# %%
result = GithubPython().run(pythonFilesThatContainsSklearn)

# %%
sklearnFile = result[0][0]

# %% [markdown]
# ### How many python files in total?

# %%
howManyPythonFiles = """\
SELECT
    COUNT(*) count
FROM
    [scikit-learn-research.pyfiles.content_py]
WHERE
    (NOT sample_repo_name CONTAINS "scikit-learn") AND
    (NOT sample_repo_name CONTAINS "sklearn") AND
    (NOT sample_path CONTAINS "scikit-learn") AND
    (NOT sample_path CONTAINS "sklearn")
"""
totalFile = GithubPython().run(howManyPythonFiles)[0][0]

# %%
import matplotlib.pyplot as plt

# %%
labels = 'Files that imports sklearn', 'Files that do not import sklearn'
sizes = [sklearnFile, totalFile-sklearnFile]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # Repo that imports sklearn the most

# %% [markdown]
# ### The most is in terms of number of lines

# %%
from bigquery_python_framework.GithubPython import GithubPython

# %%
repoThatImportsSklearnTheMostQuery = """\
SELECT
  repo_name,
  COUNT(*) count
FROM (
    SELECT
      SPLIT(content, '\n') line,
      repo_name
    FROM
      [scikit-learn-research.pyfiles.content_py_full]
    WHERE
      (NOT repo_name CONTAINS "scikit-learn") AND
      (NOT repo_name CONTAINS "sklearn") AND
      (NOT path CONTAINS "scikit-learn") AND
      (NOT path CONTAINS "sklearn")
    HAVING
      REGEXP_MATCH(line, r'from sklearn.*? import .+') OR
      REGEXP_MATCH(line, r'import sklearn')
)
GROUP BY
  1
ORDER BY
  count DESC
"""

repoThatImportsSklearnTheMost = GithubPython().run(repoThatImportsSklearnTheMostQuery)

# %%
fig, ax = plt.subplots()

# Example data
repos = [repo for repo, _ in repoThatImportsSklearnTheMost[:20]]
y_pos = range(len(repos))
count = [count for _, count in repoThatImportsSklearnTheMost[:20]]

ax.barh(y_pos, count, align='center', color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(repos)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Count')
ax.set_title('Top 20 repos with most sklearn imports')

plt.show()

# %% [markdown]
# ### It seems that filtering sklearn forks by path and repo_name is not good enough. For example, jjx02230808/project0223 is indeed a fork of sklearn. Although we exclude counting of files that has sklearn in the path, this repo still ranks high because it contains all sklearn examples. For those, they do not have "sklearn" in the path. See https://github.com/jjx02230808/project0223/blob/master/examples/calibration/plot_calibration.py for example

# %% [markdown]
# ## Detail look of files that import sklearn

# %%
repoAndPathThatImportsSklearnQuery = """\
SELECT
  repo_name,
  path
FROM (
    SELECT
      SPLIT(content, '\n') line,
      repo_name,
      path
    FROM
      [scikit-learn-research.pyfiles.content_py_full]
    WHERE
      (NOT repo_name CONTAINS "scikit-learn") AND
      (NOT repo_name CONTAINS "sklearn") AND
      (NOT path CONTAINS "scikit-learn") AND
      (NOT path CONTAINS "sklearn")
    HAVING
      REGEXP_MATCH(line, r'from sklearn.*? import .+') OR
      REGEXP_MATCH(line, r'import sklearn')
)
"""

repoAndPathThatImportsSklearn = GithubPython().run(repoAndPathThatImportsSklearnQuery)

# %%
def getGithubURL(result):
    for repo_name, path in result:
        print("https://github.com/{}/tree/master/{}".format(repo_name,path))

# %% [markdown]
# ### Below is a list of GitHub urls that import "sklearn"

# %% [raw]
# getGithubURL(repoAndPathThatImportsSklearn)

# %% [markdown]
# # Most common models

# %% [markdown]
# ### What are the most common submodule imported?

# %%
mostImportedSubmoduleQuery="""\
SELECT
  REGEXP_EXTRACT(line, r'(from sklearn.*? import .+|import sklearn.*)'),
  COUNT(*) count
FROM (
    SELECT
      SPLIT(content, '\n') line,
      id
    FROM
      [scikit-learn-research:pyfiles.content_py] 
    WHERE
      (NOT sample_repo_name CONTAINS "scikit-learn") AND
      (NOT sample_repo_name CONTAINS "sklearn") AND
      (NOT sample_path CONTAINS "scikit-learn") AND
      (NOT sample_path CONTAINS "sklearn")
)
GROUP BY
  1
ORDER BY
  count DESC
"""
mostImportedSubmodule = GithubPython().run(mostImportedSubmoduleQuery)

# %%
# Let's clean up the suffix \r, etc.
from collections import defaultdict
mostImportedSubmoduleDict = defaultdict(int)
for key,val in mostImportedSubmodule:
    if key == None: continue
    newKey = key.strip(" \r;")
    if "#" in newKey:
        newKey = newKey.split("#")[0]
    mostImportedSubmoduleDict[newKey]+=int(val)

# %% [markdown]
# ### We provide a helper utility function, so if you want to have a GitHub url link for any of the result above, you may do queryByKeyword(regular_expression)

# %%
def queryByKeyword(keyword):
    keywordQuery = GithubPython().run("""\
    SELECT
        sample_repo_name,
        sample_path
    FROM (
    SELECT
      SPLIT(content, '\n') line,
      sample_repo_name,
      sample_path
    FROM
      [scikit-learn-research:pyfiles.content_py] 
    WHERE
      (NOT sample_repo_name CONTAINS "scikit-learn") AND
      (NOT sample_repo_name CONTAINS "sklearn") AND
      (NOT sample_path CONTAINS "scikit-learn") AND
      (NOT sample_path CONTAINS "sklearn")
    HAVING
      line CONTAINS '%s'
    )
    """ % keyword
    )
    return keywordQuery

# %% [markdown]
# ### Example of showing all "import sklearn"

# %%
importSklearn = queryByKeyword('import sklearn$')

# %%
len(importSklearn)
# Out:
# 1254

# %%
getGithubURL(importSklearn)
# Out:
# https://github.com/ceholden/glmnet-python/tree/master/glmnet/elastic_net.py
# https://github.com/BenKaehler/q2-feature-classifier/tree/master/q2_feature_classifier/tests/test_taxonomic_classifier.py
# https://github.com/indiependente/nextsong/tree/master/tsne.py
# https://github.com/choldgraf/mne-python/tree/master/mne/cov.py
# https://github.com/hlin117/statsmodels/tree/master/statsmodels/sandbox/examples/thirdparty/ex_ratereturn.py
# https://github.com/aspiringguru/sentexTuts/tree/master/PracMachLrng/sentex_ML_demo3.py
# https://github.com/kvh/ramp/tree/master/examples/iris.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_01_08_2015_parallel.py
# https://github.com/wasiahmad/Paraphrase-Identification-Task/tree/master/code/input.py
# https://github.com/MicrosoftResearch/Azimuth/tree/master/azimuth/models/ensembles.py
# https://github.com/gskielian/Creating-a-Neural-Net-From-Scratch-With-Theano-Python/tree/master/01-generating-dataset.py
# https://github.com/mjirik/pyseg_base/tree/master/pysegbase/pycut.py
# https://github.com/theonaun/theo_site/tree/master/app_hms/services/analyzer.py
# https://github.com/cudbg/Dialectic/tree/master/src/old_pipeline/examples.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_server_test_0515.py
# https://github.com/crawles/text-analytics-service-example/tree/master/flask_deployment/sentiment_service.py
# https://github.com/chuajiesheng/twitter-sentiment-analysis/tree/master/step_4/scripts/train_sentiment_model.py
# https://github.com/md-k-sarker/ML-Analyze-Morality/tree/master/src/DataAnalysis.py
# https://github.com/marcbllv/lime/tree/master/lime/lime_text.py
# https://github.com/cudbg/Dialectic/tree/master/src/old_pipeline/fsvm.py
# https://github.com/danblick/robocar/tree/master/classifier/model.py
# https://github.com/craffel/librosa/tree/master/librosa/segment.py
# https://github.com/fraimondo/mne-python/tree/master/mne/utils.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/lrreadmeonly.py
# https://github.com/hammerlab/mhcflurry/tree/master/mhcflurry/scoring.py
# https://github.com/yousrabk/mne-python/tree/master/mne/utils.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_03_24_2015_parallel.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_local_test.py
# https://github.com/Erotemic/hotspotter/tree/master/hotspotter/algos.py
# https://github.com/mrrizal/TextProcessing/tree/master/term_matrix.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_04_22_2015_parallel_for_final.py
# https://github.com/salilab/imp/tree/master/modules/pmi/test/test_em_fit.py
# https://github.com/alonecoder1337/Dos-Attack-Detection-using-Machine-Learning/tree/master/Dataset.py
# https://github.com/psarka/uplift/tree/master/uplift/utils/testing.py
# https://github.com/haijieg/SFrame/tree/master/oss_src/unity/python/sframe/deps/__init__.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v2.3.py
# https://github.com/dimkal/mne-python/tree/master/mne/cov.py
# https://github.com/vansky/meg_playground/tree/master/notebooks/exported/Topomap_real.py
# https://github.com/neuropsychology/NeuroKit.py/tree/master/neurokit/statistics/feature_reduction.py
# https://github.com/julms/shipshape/tree/master/shipshape.py
# https://github.com/widdowquinn/THAPBI-pycits/tree/master/pycits/Rand_index.py
# https://github.com/swingr/swingr/tree/master/followthrough.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/test_hlf_cache.py
# https://github.com/adrinjalali/Network-Classifier/tree/master/test_ratboost.py
# https://github.com/NonWhite/IA_EP3/tree/master/code/nearest_neighbors.py
# https://github.com/haya14busa/alc-etm-searcher/tree/master/nltk-3.0a3/build/lib/nltk/classify/scikitlearn.py
# https://github.com/PEAT-AI/Crampy/tree/master/PCA/standard_pca_linear_regression.py
# https://github.com/marakeby/udl/tree/master/udl/model.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/bernoullinbdescriptiononly.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/crossval_cache3.py
# https://github.com/zzw922cn/Automatic_Speech_Recognition/tree/master/feature/wsj/wsj_preprocess.py
# https://github.com/benchling/Azimuth/tree/master/azimuth/predict.py
# https://github.com/flo-compbio/gopca/tree/master/gopca/gopca.py
# https://github.com/nishantnath/MusicPredictiveAnalysis_EE660_USCFall2015/tree/master/Code/Machine_Learning_Algos/10k_Tests/ml_classification_gmm_training.py
# https://github.com/NCBI-Hackathons/DASH_cell_type/tree/master/model.py
# https://github.com/martianstudio/stockanalysis/tree/master/first_try.py
# https://github.com/beltrame/mmMRI/tree/master/scripts/PCA.py
# https://github.com/rbharath/deepchem/tree/master/deepchem/models/tests/test_overfit.py
# https://github.com/azz2k/RLCarExp/tree/master/legacy/pairwise_distances_log.py
# https://github.com/jeffheaton/aifh/tree/master/vol3/vol3-python-examples/examples/example_sunspots.py
# https://github.com/tinghuiz/learn-reflectance/tree/master/bell2014/solver.py
# https://github.com/Chinmoy07/ML-Term-Project-Team-Pikachu/tree/master/Python-PHP-Codes/neural.py
# https://github.com/TomDLT/mne-python/tree/master/mne/utils.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_10_30_2014_server_8.py
# https://github.com/henchc/CLFL_2016/tree/master/CLFL_ngram.py
# https://github.com/aspiringguru/sentexTuts/tree/master/PracMachLrng/sentex_ML_demo2.py
# https://github.com/gpfreitas/bokeh/tree/master/examples/plotting/file/clustering.py
# https://github.com/alpatania/MapperTools/tree/master/clusters.py
# https://github.com/zzw922cn/Automatic_Speech_Recognition/tree/master/feature/timit/timit_preprocess.py
# https://github.com/Rostlab/LocText/tree/master/scripts/util.py
# https://github.com/claesenm/optunity-benchmark/tree/master/benchmarks/optunity/executable.py
# https://github.com/belkinsky/SFXbot/tree/master/src/pyAudioAnalysis/audioSegmentation.py
# https://github.com/jamesjarlathlong/resourceful/tree/master/visualise_one.py
# https://github.com/shenbai/tradesafe/tree/master/org/tradesafe/train/train.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_05_17_2015.py
# https://github.com/CalvinNeo/EasyMLPlatform/tree/master/py/ml_models/bp.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/bernoullinbreadmeonly.py
# https://github.com/wdbm/abstraction/tree/master/classification_ttH_ttbb_1.py
# https://github.com/andersbll/texture_benchmarks/tree/master/code/plots.py
# https://github.com/BovineJoni/StylometricClustering/tree/master/data_util.py
# https://github.com/chuajiesheng/twitter-sentiment-analysis/tree/master/step_3/scripts/train_relevance_model.py
# https://github.com/iskandr/immuno/tree/master/seq_feature_tests.py
# https://github.com/drphilmarshall/LocalGroupHaloProps/tree/master/final_scripts/gmm_pair.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/gbrtfilesandfolders.py
# https://github.com/ijmarshall/cochrane-nlp/tree/master/quality2.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/svmreadmemeta.py
# https://github.com/suresh/notes/tree/master/python/gaussian_mixture.py
# https://github.com/rampasek/seizure-prediction/tree/master/features/extractFeaturesWThuman.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Mnist_classification_05202015.py
# https://github.com/rosenbrockc/acorn/tree/master/acorn/analyze/__init__.py
# https://github.com/chengsoonong/crowdastro/tree/master/crowdastro/experiment/experiment_learning_curve.py
# https://github.com/CSE512-14W/fp-edbutler-piscean/tree/master/src/progression.py
# https://github.com/azz2k/RLCarExp/tree/master/legacy/cv.py
# https://github.com/chuajiesheng/twitter-sentiment-analysis/tree/master/step_4/scripts/build_sentiment_pipeline.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v2.3.1.py
# https://github.com/antoinecarme/pyaf/tree/master/TS/TimeSeriesModel.py
# https://github.com/kingjr/mne-python/tree/master/mne/decoding/csp.py
# https://github.com/adriantorrie/adriantorrie.github.io_src/tree/master/content/downloads/code/version_check.py
# https://github.com/ktrnka/helpers/tree/master/neural.py
# https://github.com/tedmeeds/tcga_encoder/tree/master/tcga_encoder/models/analyses.py
# https://github.com/SU-ECE-17-7/ibeis/tree/master/ibeis/new_annots.py
# https://github.com/JOHNKYON/Lab_models/tree/master/src/official_test/t-SNE.py
# https://github.com/JeffAbrahamson/MLWeek/tree/master/theory/J1-3_linear-regression/code_lab_solutions.py
# https://github.com/pietroquaglio/elephant/tree/master/elephant/test/test_asset.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/svmall.py
# https://github.com/hammerlab/immuno_research/tree/master/Mar17_balanced.py
# https://github.com/NonWhite/IA_EP3/tree/master/code/best_classifiers_tfidf.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_02_19_2015.py
# https://github.com/IntelPNI/brainiak/tree/master/brainiak/fcma/voxelselector.py
# https://github.com/bharadwajramachandran/TartanRoof/tree/master/vectorExtractor.py
# https://github.com/marcotcr/lime-experiments/tree/master/evaluate_explanations.py
# https://github.com/lesleymaraina/DataScience.Restaurants/tree/master/driver.py
# https://github.com/rpp0/lora-phy-fingerprinting/tree/master/tf_train.py
# https://github.com/antoinecarme/pyaf/tree/master/tests/bugs/issue_36/display_version_info.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_15_2015_02.py
# https://github.com/leafwind/ringo/tree/master/run_this_for_result.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/metaonlyadaboost.py
# https://github.com/adamsumm/TheRecipeOfZelda/tree/master/analyze_summaries.py
# https://github.com/claesenm/optunity-benchmark/tree/master/benchmarks/optunity/bayesopt-wrapper.py
# https://github.com/hammerlab/immuno_research/tree/master/Jan23.py
# https://github.com/mkeyran/EmotionRecognizer/tree/master/mappings.py
# https://github.com/origingod/salary-prediction-with-machine-learning/tree/master/Analyser.py
# https://github.com/vansky/meg_playground/tree/master/scripts/meg_coherence_runner.py
# https://github.com/jamarzka/borg/tree/master/borg/experiments/simulate_iid.py
# https://github.com/manopaul/Autonomous-Vehicles/tree/master/3 - Behavioral Cloning/model.py
# https://github.com/glrs/StackedDAE/tree/master/Train_SDAE/tools/evaluate_model.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_11_10_2014_server.py
# https://github.com/ARudiuk/mne-python/tree/master/mne/utils.py
# https://github.com/jamesjarlathlong/resourceful/tree/master/vis_plotter.py
# https://github.com/networkitproject/networkit-mirror/tree/master/networkit/linkprediction.py
# https://github.com/MicrosoftResearch/Azimuth/tree/master/azimuth/predict.py
# https://github.com/cudbg/Dialectic/tree/master/src/old_pipeline/naivebayes.py
# https://github.com/idiosyncraticee/chalearn/tree/master/src/skeleton.py
# https://github.com/palday/mne-python/tree/master/mne/utils.py
# https://github.com/mirjalil/ml-visual-recognition/tree/master/codes/classify_half5.py
# https://github.com/bloyl/mne-python/tree/master/mne/decoding/csp.py
# https://github.com/laputian/dml/tree/master/equation/nnfromscratch.py
# https://github.com/nishantnath/MusicPredictiveAnalysis_EE660_USCFall2015/tree/master/Code/Machine_Learning_Algos/10k_Tests/ml_classification_knn_training.py
# https://github.com/mworles/capstone_one/tree/master/src/models/ml_train.py
# https://github.com/agramfort/mne-python/tree/master/mne/tests/test_cov.py
# https://github.com/MartinThoma/algorithms/tree/master/ML/hasy/classifier_comp.py
# https://github.com/marcbllv/lime/tree/master/lime/lime_tabular.py
# https://github.com/annapasca/mne-python/tree/master/mne/utils.py
# https://github.com/librosa/librosa/tree/master/librosa/segment.py
# https://github.com/kizzen/Baller-Shot-Caller/tree/master/ModelFitting/single_Kmeans.py
# https://github.com/belkinsky/SFXbot/tree/master/src/pyAudioAnalysis/audioVisualization.py
# https://github.com/WladimirSidorenko/DiscourseSenser/tree/master/tests/xgboost/test_xgb_base.py
# https://github.com/adrinjalali/Network-Classifier/tree/master/read_deep_aging.py
# https://github.com/nesterione/problem-solving-and-algorithms/tree/master/problems/Kaggle/TitanicMachineLearningfromDisaster/myfirstsvm.py
# https://github.com/dolphyin/cs194-16-data_manatees/tree/master/precision_recall_split.py
# https://github.com/danqiye1/CS4786/tree/master/competition_1/topicModel.py
# https://github.com/Lewuathe/kaggle-repo/tree/master/facebook-recruiting-iii-keyword-extraction/src/tagger.py
# https://github.com/dmitru/rankpy/tree/master/rankpy/models/lambdamart.py
# https://github.com/mjbommar/scotus-predict/tree/master/model.py
# https://github.com/danqiye1/CS4786/tree/master/competition_1/challenge1.py
# https://github.com/cigroup-ol/windml/tree/master/examples/unsupervised/sequence.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_01_08_2015_03.py
# https://github.com/dengemann/mne-python/tree/master/mne/utils.py
# https://github.com/georgetown-analytics/nba-tracking/tree/master/Visual_Game/CreatingBaseDF.py
# https://github.com/RomainBrault/OVFM/tree/master/Faces/Faces.py
# https://github.com/Bihaqo/exp-machines/tree/master/src/TTRegression.py
# https://github.com/murq/movie-datamining/tree/master/Bayes.py
# https://github.com/schollz/find/tree/master/RF.py
# https://github.com/chrissly31415/amimanera/tree/master/competition_scripts/caterpillar/run_nn-br6lin.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_12_01_2014.py
# https://github.com/lilleswing/deepchem/tree/master/deepchem/models/tensorflow_models/tests/test_progressive.py
# https://github.com/emhuff/regularizedInversion/tree/master/reweightDES.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_11_03_2014_server.py
# https://github.com/tedmeeds/tcga_encoder/tree/master/tcga_encoder/models/pytorch/weibull_survival_sandbox.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_01_09_2015_01.py
# https://github.com/SU-ECE-17-7/ibeis/tree/master/ibeis/scripts/classify_shark.py
# https://github.com/hammerlab/immuno_research/tree/master/May13_sliding_kmers.py
# https://github.com/BeckResearchLab/USP-inhibition/tree/master/scripts/models.py
# https://github.com/mayavanand/RMMAFinalProject/tree/master/build/lib/azimuth/models/ensembles.py
# https://github.com/thypad/brew/tree/master/test/test_selection_dynamic.py
# https://github.com/liquidSVM/liquidSVM/tree/master/bindings/python/liquidSVM/learn.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/generate_local_cache_FAST.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_08_2015_03.py
# https://github.com/georgetown-analytics/housing-risk/tree/master/code/prediction/run_models.py
# https://github.com/TuKo/brainiak/tree/master/brainiak/fcma/classifier.py
# https://github.com/JWageM/planet-wars/tree/master/train-ml-bot.py
# https://github.com/achadha0111/hack-the-burgh/tree/master/hack2vec.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_12_2015_01.py
# https://github.com/murq/movie-datamining/tree/master/SVM_test.py
# https://github.com/drphilmarshall/LocalGroupHaloProps/tree/master/final_scripts/gmm_prior_pair.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_11_18_2014.py
# https://github.com/hammerlab/immuno_research/tree/master/eval_dataset.py
# https://github.com/SUTDMEC/Travel-Mode-Auto-Validation/tree/master/CRFmodel/generateFeatureNLP.py
# https://github.com/jamarzka/borg/tree/master/borg/experiments/ll_vs_features.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_09_2015_01.py
# https://github.com/cudbg/Dialectic/tree/master/src/old_pipeline/svm.py
# https://github.com/ainafp/nilearn/tree/master/nilearn/__init__.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_Server_0706_2015_3.py
# https://github.com/iskandr/immuno/tree/master/Jan18.py
# https://github.com/remigius42/code_camp_2017_machine_learning/tree/master/examples/remigius-thoemel/alm-incs-iteration-0.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_05_20_2015.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_05_18_2015.py
# https://github.com/ijmarshall/cochrane-nlp/tree/master/quality4.py
# https://github.com/Enucatl/machine-learning-aging-brains/tree/master/agingbrains/voxel_fit.py
# https://github.com/josiahdavis/base_python/tree/master/base_python.py
# https://github.com/ursgal/ursgal/tree/master/ursgal/resources/platform_independent/arc_independent/svm_1_0_0/svm_1_0_0.py
# https://github.com/rajul/mne-python/tree/master/mne/cov.py
# https://github.com/dgwakeman/mne-python/tree/master/mne/tests/test_cov.py
# https://github.com/csferrie/python-qinfer/tree/master/src/qinfer/metrics.py
# https://github.com/hrishikeshio/whale/tree/master/fft/000_pre_2spectral.py
# https://github.com/Ikuo89/4s/tree/master/tagger/tagger.py
# https://github.com/rajegannathan/grasp-lift-eeg-cat-dog-solution-updated/tree/master/python-packages/mne-python-0.10/mne/utils.py
# https://github.com/jessept/cognoml/tree/master/cognoml/utils.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_Server_0715_2015_pre_activation_rectifier_didnotwork.py
# https://github.com/borg-project/borg/tree/master/borg/experiments/ll_vs_train.py
# https://github.com/euclides5414/ml_utils/tree/master/ml_utils/cv/classes.py
# https://github.com/remigius42/code_camp_2017_machine_learning/tree/master/examples/remigius-thoemel/alm-incs-iteration-1.py
# https://github.com/SXBK/kaggle/tree/master/zillow/multi_feautre.py
# https://github.com/gskielian/Creating-a-Neural-Net-From-Scratch-With-Theano-Python/tree/master/02-logistic-regression.py
# https://github.com/dtamayo/MachineLearning/tree/master/Day3/py_brute/svm.py
# https://github.com/borg-project/borg/tree/master/borg/experiments/mix_over_k.py
# https://github.com/d-grossman/pelops/tree/master/pelops/models/makesvm.py
# https://github.com/rkmaddox/mne-python/tree/master/mne/utils.py
# https://github.com/mikecroucher/GPy/tree/master/GPy/examples/non_gaussian.py
# https://github.com/cycomachead/info290/tree/master/lab4_decision_trees/lab4submission/Lab4_decision_trees.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_10_30_2014_server_4.py
# https://github.com/mirjalil/ml-visual-recognition/tree/master/codes/classify_half6.py
# https://github.com/wdbm/abstraction/tree/master/abstraction.py
# https://github.com/mayavanand/RMMAFinalProject/tree/master/azimuth/models/DNN.py
# https://github.com/matthew-tucker/mne-python/tree/master/mne/decoding/csp.py
# https://github.com/jeremymchacon/colony_counter/tree/master/cc_n.py
# https://github.com/awduda/awduda.github.io/tree/master/index.py
# https://github.com/tedmeeds/tcga_encoder/tree/master/tcga_encoder/models/survival_analysis.py
# https://github.com/jcrudy/py-earth/tree/master/pyearth/test/testing_utils.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_server_test_0513.py
# https://github.com/effigies/mne-python/tree/master/mne/utils.py
# https://github.com/MartinThoma/algorithms/tree/master/ML/mnist/many-classifiers/python.py
# https://github.com/drphilmarshall/LocalGroupHaloProps/tree/master/final_scripts/savegmm.py
# https://github.com/jbkopecky/housebot/tree/master/models/db_to_json.py
# https://github.com/ckbjimmy/epi/tree/master/structured_feature_extraction.py
# https://github.com/renatopp/liac/tree/master/liac/_random.py
# https://github.com/anaderi/lhcb_trigger_ml/tree/master/hep_ml/meanadaboost.py
# https://github.com/jonpdx/gsoc2014/tree/master/rocktotext-v2.py
# https://github.com/norbertbin/subredditAnalysis/tree/master/processText.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/gbrtreadmeonly.py
# https://github.com/hammerlab/immuno_research/tree/master/Apr8_filter_by_mhc_pos.py
# https://github.com/tyiannak/pyAudioAnalysis/tree/master/audioSegmentation.py
# https://github.com/trogdorsey/data_hacking/tree/master/dga_detection/dga_model_gen.py
# https://github.com/hammerlab/immuno_research/tree/master/Jan22.py
# https://github.com/rbharath/deepchem/tree/master/deepchem/models/models.py
# https://github.com/yukisakurai/hhana/tree/master/mva/classify.py
# https://github.com/WillBrennan/DigitClassifier/tree/master/DeepConv.py
# https://github.com/BIDS-collaborative/EDAM/tree/master/jackye/predict_jack.py
# https://github.com/emhuff/regularizedInversion/tree/master/reweight.py
# https://github.com/wolverton-research-group/qmpy/tree/master/qmpy/__init__.py
# https://github.com/glrs/StackedDAE/tree/master/Train_SDAE/stacked_dae.py
# https://github.com/bakfu/bakfu/tree/master/bakfu/process/tagging/tag_treetagger.py
# https://github.com/mcraig2/py-analysis/tree/master/src/metrics/metrics.py
# https://github.com/ucscHexmap/hexagram/tree/master/.calc/compute_sparse_matrix.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v1.04.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/generate_local_cache_MSER.py
# https://github.com/chkoar/imbalanced-learn/tree/master/imblearn/under_sampling/instance_hardness_threshold.py
# https://github.com/kquist/DoubleML-Python/tree/master/DoubleML/ML2.py
# https://github.com/origingod/salary-prediction-with-machine-learning/tree/master/DataAnalyser.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_Server_0910_2015_pre_activation_rectifier_didnotwork.py
# https://github.com/sankar-mukherjee/CoFee/tree/master/laurent/coFeeClassif.py
# https://github.com/ainafp/nilearn/tree/master/nilearn/decomposition/canica.py
# https://github.com/hammerlab/immuno_research/tree/master/Jan21_toxin_positional.py
# https://github.com/EFavDB/svm-classification/tree/master/svm.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_01_05_2015_server.py
# https://github.com/effigies/mne-python/tree/master/mne/decoding/csp.py
# https://github.com/s-alexey/orange3/tree/master/Orange/tests/test_logistic_regression.py
# https://github.com/adrinjalali/Network-Classifier/tree/master/RatBoost/learner.py
# https://github.com/SU-ECE-17-7/ibeis/tree/master/ibeis/algo/hots/tmp_cluster.py
# https://github.com/marcotcr/lime/tree/master/lime/lime_image.py
# https://github.com/robbisg/mvpa_itab_wu/tree/master/mvpa_itab/script/misc/megmri.py
# https://github.com/danjamker/DiffusionSimulation/tree/master/MRJobNetworkX-PredictDepth.py
# https://github.com/joewalter/mne-python/tree/master/mne/utils.py
# https://github.com/MichaelHills/seizure-prediction/tree/master/seizure_prediction/classifiers.py
# https://github.com/seanbell/intrinsic/tree/master/bell2014/solver.py
# https://github.com/JustPhyCs/cs231n_proj/tree/master/transfer_learning/logistic_regression.py
# https://github.com/msmbuilder/osprey/tree/master/osprey/fit_estimator.py
# https://github.com/lol/BCI-BO-old/tree/master/submit_all_lost_jobs.py
# https://github.com/Skobnikoff/Datasets/tree/master/Kagle_Titanic_Python/skLearn.py
# https://github.com/laurent-george/protolab_sound_recognition/tree/master/sound_classification/classification_service.py
# https://github.com/kdaily/altanalyze/tree/master/setup.py
# https://github.com/YeoLab/gscripts/tree/master/gscripts/general/analysis_tools.py
# https://github.com/anishgt/DeepCustomerSatisfaction/tree/master/linear.py
# https://github.com/SXBK/kaggle/tree/master/zillow/fe_lgbm.py
# https://github.com/alan-mnix/MLFinalProject/tree/master/svm.py
# https://github.com/smidget/video-learning/tree/master/learning.py
# https://github.com/iskandr/immuno/tree/master/Jan31_bigram.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/train_attr.py
# https://github.com/ucscHexmap/hexagram/tree/master/server/compute_pivot_vs_background.py
# https://github.com/rbharath/deepchem/tree/master/deepchem/models/tests/test_predict.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_local_test.py
# https://github.com/ankoorb/scipy2015_tutorial/tree/master/check_env.py
# https://github.com/salilab/imp/tree/master/modules/pmi/test/test_dof.py
# https://github.com/awni/tensorflow/tree/master/tensorflow/contrib/skflow/python/skflow/__init__.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_Server_0519_2015.py
# https://github.com/jeremy-ma/gmmmc/tree/master/examples/benchmark.py
# https://github.com/PUTvision/ImageProcessingCourse/tree/master/s01e06.py
# https://github.com/marcotcr/lime-experiments/tree/master/data_trusting.py
# https://github.com/snovd/test-scripts/tree/master/kpext/kp_crfsuite_projection.py
# https://github.com/vansky/meg_playground/tree/master/scripts/meg_coherence_linerunner.py
# https://github.com/JPMoresmau/aifh/tree/master/vol3/vol3-python-examples/examples/example_iris_anneal.py
# https://github.com/antiface/mne-python/tree/master/mne/cov.py
# https://github.com/gticket/scikit-neuralnetwork/tree/master/sknn/ae.py
# https://github.com/ARudiuk/mne-python/tree/master/mne/cov.py
# https://github.com/agramfort/mne-python/tree/master/mne/utils.py
# https://github.com/chrissly31415/amimanera/tree/master/competition_scripts/otto.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_12_01_2014_server2.py
# https://github.com/canard0328/malss/tree/master/setup.py
# https://github.com/alan-mnix/MLFinalProject/tree/master/classifier_fusion.py
# https://github.com/vignettist/image-import/tree/master/place_cluster.py
# https://github.com/wgyn/github-topics/tree/master/parse_data.py
# https://github.com/hammerlab/immuno_research/tree/master/Feb7_tumor_specific_antigens.py
# https://github.com/andyh616/mne-python/tree/master/mne/utils.py
# https://github.com/SXBK/kaggle/tree/master/zillow/lgbm.py
# https://github.com/zhangxyz/MLFSdel/tree/master/src/knn.py
# https://github.com/brsu/Learning-And-Adaptivity/tree/master/assignment_template/code/zoo_ml.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Mnist_classification_0519_2.py
# https://github.com/chengsoonong/crowdastro/tree/master/crowdastro/experiment/experiment_rgz_raykar_class_balance.py
# https://github.com/MMKrell/pyspace/tree/master/pySPACE/missions/nodes/scikit_nodes.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_05_21_2015.py
# https://github.com/nishantnath/MusicPredictiveAnalysis_EE660_USCFall2015/tree/master/Code/Machine_Learning_Algos/10k_Tests/ml_classification_naive_gaussian_bayes.py
# https://github.com/Alan-Robertson/python-qinfer/tree/master/src/qinfer/metrics.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_Server_0625_2015.py
# https://github.com/chop-dbhi/arrc/tree/master/model_persist.py
# https://github.com/shotastage/prism/tree/master/prism/coreml/converter.py
# https://github.com/chuajiesheng/twitter-sentiment-analysis/tree/master/methodology/scripts/run.py
# https://github.com/jpzhangvincent/InstacartKaggleCompetition/tree/master/models/NNv1.py
# https://github.com/ljchang/nltools/tree/master/nltools/pbs_job.py
# https://github.com/andosa/treeinterpreter/tree/master/treeinterpreter/treeinterpreter.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_local_test (u-PC's conflicted copy 2015-04-15).py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_15_2015_01.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_count_stags.py
# https://github.com/jparrent/usvotesgraphs/tree/master/src/visualization/visualize.py
# https://github.com/asncd/MIMOSCA/tree/master/mimosca.py
# https://github.com/numeristical/introspective/tree/master/ml_insights/calibration_utils.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/lrstacking.py
# https://github.com/mdeff/cnn_graph/tree/master/lib/models.py
# https://github.com/janusnic/21v-python/tree/master/unit_20/parallel_ml/00 - Tutorial Setup .py
# https://github.com/Curly-Mo/mir-tools/tree/master/machine_learning.py
# https://github.com/anshuli-patil/secret-project/tree/master/src/classification/svdclassifier.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Mnist_classification_0511.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_04_07_2015_parallel.py
# https://github.com/eredmiles/Fraud-Corruption-Detection-Data-Science-Pipeline-DSSG2015/tree/master/WorldBank2015/Code/modeling/predict.py
# https://github.com/hammerlab/immuno_research/tree/master/May13_fritsch_neoepitopes.py
# https://github.com/marcotcr/lime-experiments/tree/master/compare_classifiers.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_08_2015_01.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v1.05.py
# https://github.com/drphilmarshall/LocalGroupHaloProps/tree/master/final_scripts/make_gmm_samples.py
# https://github.com/lavizhao/keyword/tree/master/learning/knn.py
# https://github.com/lilleswing/deepchem/tree/master/deepchem/models/tests/test_generalize.py
# https://github.com/mbillingr/SCoT/tree/master/scot/tests/test_xvschema.py
# https://github.com/xiangdal/TrajectoryNet/tree/master/Context.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/multinomialnbdescriptiononly.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/crossval_cache.py
# https://github.com/rlowrance/re-avm/tree/master/AVM2.py
# https://github.com/kbiscanic/apt_project/tree/master/apt/Model.py
# https://github.com/rampasek/seizure-prediction/tree/master/features/extractFeaturesWT.py
# https://github.com/SXBK/kaggle/tree/master/zillow/fuse.py
# https://github.com/mmaguero/Intel-mobileodt-cervical-cancer-screening/tree/master/Python-scripts/class_image.py
# https://github.com/tedmeeds/tcga_encoder/tree/master/tcga_encoder/models/survival_analysis_ordinal.py
# https://github.com/mjbommar/cscs-531-rps-tournament/tree/master/entrants1/BommaritoRandomForest.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/svcfilenamesonly.py
# https://github.com/nekomiko/wkcaptcha/tree/master/neural.py
# https://github.com/Silianbo/salary-prediction-with-machine-learning/tree/master/DataAnalyser.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v2.2.py
# https://github.com/arunreddy/text-analysis/tree/master/textanalysis/data/multiDomainSentiment.py
# https://github.com/ajnam12/MusicNLP/tree/master/graph_utils.py
# https://github.com/jadielam/pingo/tree/master/testing/ml_testing.py
# https://github.com/abenicho/isvr/tree/master/nilearn/decoding/searchlight.py
# https://github.com/jpopham91/berserker/tree/master/berserker/nodes.py
# https://github.com/agiovann/CalBlitz/tree/master/calblitz/movies.py
# https://github.com/loli/semisupervisedforests/tree/master/setup.py
# https://github.com/perimosocordiae/viztricks/tree/master/viztricks/tests/test.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_04_27_2015_parallel_for_final.py
# https://github.com/jqug/microscopy-object-detection/tree/master/detectobjects.py
# https://github.com/gregversteeg/corex_topic/tree/master/tests/data/get_twenty.py
# https://github.com/Ignotus/DataMining/tree/master/Assignment-1/3/sd.py
# https://github.com/nicproulx/mne-python/tree/master/mne/cov.py
# https://github.com/earlybackhome/easy-expression/tree/master/modules/OCR/Image2txt.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/generate_local_cache.py
# https://github.com/bharadwajramachandran/TartanRoof/tree/master/vectorExtractorWithTuples.py
# https://github.com/alan-mnix/MLFinalProject/tree/master/final.py
# https://github.com/SU-ECE-17-7/ibeis/tree/master/_broken/workspace.py
# https://github.com/snyang/TechNotes/tree/master/ML/DL/WildML/RNN/scr/NeuralNetworkFromScratch.py
# https://github.com/hlt-mt/adaptiveMT/tree/master/scripts/tuning.py
# https://github.com/mirjalil/ml-visual-recognition/tree/master/codes/logisticRegression.py
# https://github.com/chengsoonong/crowdastro/tree/master/crowdastro/experiment/experiment_raykar.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/lrstackingmeta.py
# https://github.com/rbharath/deepchem/tree/master/deepchem/models/multitask.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Mnist_classification_0519.py
# https://github.com/ColCarroll/ai_talk/tree/master/talk_code/clean_data.py
# https://github.com/iskandr/immuno/tree/master/Jan24.py
# https://github.com/salma1601/nilearn/tree/master/nilearn/decoding/searchlight.py
# https://github.com/reisalex/test-sfm/tree/master/testsfm/stats.py
# https://github.com/Texju/DIT-Machine_Learning/tree/master/Codes/display.py
# https://github.com/lol/BCI-BO-old/tree/master/spearmint_lite.py
# https://github.com/jccaicedo/localization-agent/tree/master/detection/masks/trainCascade.py
# https://github.com/Odingod/mne-python/tree/master/mne/tests/test_cov.py
# https://github.com/mwalton/artificial-olfaction/tree/master/CNN/gen-testData.py
# https://github.com/dvro/brew/tree/master/brew/generation/ics_bagging.py
# https://github.com/ahna/wikiscore/tree/master/app/qualPred.py
# https://github.com/jiajunshen/partsNet/tree/master/pnet/randomPartitionSVMLayer.py
# https://github.com/UpSea/midProjects/tree/master/01_aat-ebook-full-source-code-20160430/chapter12/cross_validation.py
# https://github.com/smly/ume/tree/master/ume/cmd.py
# https://github.com/burnash/neurolearn/tree/master/nltools/analysis.py
# https://github.com/leonardbj/rubik/tree/master/src/py/deprecated/1/DataImage.py
# https://github.com/valpasq/yatsm/tree/master/yatsm/algorithms/yatsm.py
# https://github.com/cxhernandez/osprey/tree/master/osprey/fit_estimator.py
# https://github.com/jotterbach/dstk/tree/master/DSTK/FeatureBinning/decision_tree_binner.py
# https://github.com/wfurine/htdrive/tree/master/pca.py
# https://github.com/zang0/bpro/tree/master/bpro.py
# https://github.com/cudbg/Dialectic/tree/master/src/old_pipeline/load_svm.py
# https://github.com/sinwav/pypr/tree/master/mlwp/versions.py
# https://github.com/gmum/r2-learner/tree/master/r2.py
# https://github.com/prisms-center/CASMcode/tree/master/python/casm/casm/learn/linear_model.py
# https://github.com/ericxk/MachineLearningExercise/tree/master/first_nn.py
# https://github.com/kudkudak/word-embeddings-benchmarks/tree/master/web/analogy.py
# https://github.com/jubatus/jubakit/tree/master/jubakit/test/__init__.py
# https://github.com/Li-Jiaqi/BugRiskPrediction/tree/master/dongge/SVM.py
# https://github.com/thypad/brew/tree/master/skensemble/generation/bagging.py
# https://github.com/devinplatt/extraction_worker/tree/master/lib/extract_features.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_11_03_2014_server_2.py
# https://github.com/ravenshooter/BA_Analysis/tree/master/Main.py
# https://github.com/wgmueller1/unicorn/tree/master/app/views.py
# https://github.com/RomainBrault/OVFM/tree/master/Simulated/Learn.py
# https://github.com/valpasq/yatsm/tree/master/tests/algorithms/conftest.py
# https://github.com/adrn/AASAbstractSorter/tree/master/cluster.py
# https://github.com/mcraig2/py-analysis/tree/master/src/neural/neural_network.py
# https://github.com/kvh/ramp/tree/master/ramp/reporters.py
# https://github.com/kianho/sentiment-playground/tree/master/sentiment/sentiment.py
# https://github.com/jnarhan/Breast_Cancer/tree/master/src/helper_modules/Package_Versions.py
# https://github.com/mayavanand/RMMAFinalProject/tree/master/azimuth/models/ensembles.py
# https://github.com/DryRun/seizures/tree/master/code/test_train.py
# https://github.com/cycomachead/info290/tree/master/project/code/analysis/log_reg.py
# https://github.com/yunque/librosa/tree/master/librosa/segment.py
# https://github.com/jcdesimp/NLP-ps3/tree/master/main.py
# https://github.com/georgid/SourceFilterContoursMelody/tree/master/src/contour_classification/run_contour_training_melody_extraction.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_10_13_2014_server.py
# https://github.com/achadha0111/hack-the-burgh/tree/master/wordvecmodel.py
# https://github.com/kit-parco/networkit/tree/master/setup_util.py
# https://github.com/ceholden/yatsm/tree/master/yatsm/regression/robust_fit.py
# https://github.com/yuriyminin/leap-gesture/tree/master/machineLearning.py
# https://github.com/jamesjarlathlong/resourceful/tree/master/exploit_sharedbattery.py
# https://github.com/leahrnh/ticktock_text_api/tree/master/breakdown_detector_svm.py
# https://github.com/mdeff/ntds_2016/tree/master/project/reports/el_nino/utils.py
# https://github.com/mayavanand/RMMAFinalProject/tree/master/azimuth/features/featurization.py
# https://github.com/eredmiles/Fraud-Corruption-Detection-Data-Science-Pipeline-DSSG2015/tree/master/WorldBank2015/Code/data_pipeline_src/rank_gen.py
# https://github.com/alan-mnix/MLFinalProject/tree/master/SupTfidfVectorizer.py
# https://github.com/svohara/proximityforest/tree/master/samples/LatentConfigurationClustering_Demo.py
# https://github.com/viisar/brew/tree/master/brew/generation/smote_bagging.py
# https://github.com/LoadedCoders/iHear/tree/master/iHear-Py/pyAudioAnalysis/audioSegmentation.py
# https://github.com/rich-d-wilkinson/MyGPy/tree/master/GPy/examples/non_gaussian.py
# https://github.com/diogo149/du/tree/master/du/model/nbsvm.py
# https://github.com/alan-mnix/MLFinalProject/tree/master/acc.py
# https://github.com/CalculatedContent/tsvm/tree/master/incremental_tsvm_news.py
# https://github.com/keflavich/TurbuStat/tree/master/setup.py
# https://github.com/OFAI/hub-toolbox-python3/tree/master/hub_toolbox/__init__.py
# https://github.com/x75/actinf/tree/master/active_inference_basic.py
# https://github.com/SuperSaiyanSSS/SinaWeiboSpider/tree/master/ml/random_forest.py
# https://github.com/bmcfee/librosa/tree/master/librosa/segment.py
# https://github.com/pearlphilip/USP-inhibition/tree/master/models.py
# https://github.com/BerryAI/Acai/tree/master/OpenMRS/API/user.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_04_27_2015_server_for_final.py
# https://github.com/deepchem/deepchem/tree/master/deepchem/models/tests/test_predict.py
# https://github.com/askldjd/udacity-machine-learning/tree/master/proj/ud120-projects/tools/startup.py
# https://github.com/iskandr/immuno/tree/master/Feb1_majority_label.py
# https://github.com/rhoef/afw/tree/master/cat/classifiers/ocsvm.py
# https://github.com/mehdidc/py-earth/tree/master/pyearth/test/testing_utils.py
# https://github.com/chosenone75/Neural-Networks/tree/master/Some Testing Script/have_a_look_lr.py
# https://github.com/locuslab/icnn/tree/master/multi-label-cls/util.py
# https://github.com/brookemosby/titanic/tree/master/test_TitanicAttempt.py
# https://github.com/chuajiesheng/twitter-sentiment-analysis/tree/master/analysis/feature_union.py
# https://github.com/Funtimezzhou/TradeBuildTools/tree/master/SAT eBook/chapter11/forecast.py
# https://github.com/jniediek/mne-python/tree/master/mne/cov.py
# https://github.com/marakeby/udl/tree/master/udl/examples/mnist_caffe.py
# https://github.com/marcotcr/lime/tree/master/lime/lime_text.py
# https://github.com/leonardbinet/Transilien-Api-ETL/tree/master/api_etl/regressor_train.py
# https://github.com/iskandr/immuno/tree/master/Jan17.py
# https://github.com/SXBK/kaggle/tree/master/zillow/xgb.py
# https://github.com/Curly-Mo/mir-tools/tree/master/cross_validate.py
# https://github.com/CaptainEgregious/Python_NN/tree/master/NN_python.py
# https://github.com/AndySchuetz/homemade_pi/tree/master/serverImageProcRuntime.py
# https://github.com/mjirik/lisa/tree/master/docs/conf.py
# https://github.com/motazsaad/comparable-text-miner/tree/master/textpro.py
# https://github.com/Kelina/SentenceEmbeddings/tree/master/TestClassifier.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_server_test_0514.py
# https://github.com/pearlphilip/USP-inhibition/tree/master/utils.py
# https://github.com/charanpald/sandbox/tree/master/sandbox/predictors/test/LibSVMTest.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/crossval_numAug.py
# https://github.com/marcbllv/lime/tree/master/lime/discretize.py
# https://github.com/Skobnikoff/Datasets/tree/master/Kagle_Titanic_Python/BestResults.py
# https://github.com/anaderi/lhcb_trigger_ml/tree/master/hep_ml/grid_search.py
# https://github.com/cigroup-ol/windml/tree/master/examples_alt/visualization/wind_embeddings.py
# https://github.com/diegocavalca/Studies/tree/master/Python/Machine-Learning/Introduction-Udacity/tools/startup.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/metaonlyrandomforest.py
# https://github.com/veronicatozzo/dalila/tree/master/setup.py
# https://github.com/agartland/utils/tree/master/roc.py
# https://github.com/cduvedi/CS229-project/tree/master/deeplearning/utils.py
# https://github.com/sappo/simindex/tree/master/simindex/weak_labels.py
# https://github.com/MicrosoftResearch/Azimuth/tree/master/azimuth/models/regression.py
# https://github.com/DryRun/seizures/tree/master/code/main.py
# https://github.com/rluch/InfoMine/tree/master/infomine/gender_classifier.py
# https://github.com/white-lab/pyproteome/tree/master/pyproteome/analysis.py
# https://github.com/ljchang/neurolearn/tree/master/nltools/simulator.py
# https://github.com/henchc/CLFL_2016/tree/master/CLFL_CRF_held-out.py
# https://github.com/johnmartinsson/bird-species-classification/tree/master/run_predictions.py
# https://github.com/bmilde/deepschmatzing/tree/master/sequence_cnn.py
# https://github.com/juliannieb/StudentsApp/tree/master/welcome.py
# https://github.com/SU-ECE-17-7/ibeis/tree/master/ibeis/algo/hots/_grave_bayes.py
# https://github.com/uvasrg/EvadeML/tree/master/utils/detection_agent_server.py
# https://github.com/decebel/librosa/tree/master/librosa/segment.py
# https://github.com/olinguyen/comp6321/tree/master/project/startup.py
# https://github.com/sshihata/mash/tree/master/src/graph.py
# https://github.com/azmodii/aifh/tree/master/vol3/vol3-python-examples/examples/example_iris.py
# https://github.com/snovd/test-scripts/tree/master/kpext/kp_crfsuite.py
# https://github.com/chengsoonong/crowdastro/tree/master/crowdastro/experiment/experiment_raykar_class_balance.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v2.2.2.py
# https://github.com/hammerlab/immuno_research/tree/master/Jan18.py
# https://github.com/ktaneishi/deepchem/tree/master/deepchem/models/tests/test_generalize.py
# https://github.com/ktaneishi/deepchem/tree/master/deepchem/models/models.py
# https://github.com/antiface/mne-python/tree/master/mne/tests/test_cov.py
# https://github.com/zimmermegan/smarda/tree/master/nltk-3.0.3/nltk/classify/scikitlearn.py
# https://github.com/marakeby/udl/tree/master/udl/examples/logistic_caffe.py
# https://github.com/dgwakeman/mne-python/tree/master/mne/utils.py
# https://github.com/azmodii/aifh/tree/master/vol3/vol3-python-examples/examples/example_iris_anneal.py
# https://github.com/chop-dbhi/arrc/tree/master/learn/printers.py
# https://github.com/cbentivoglio/neurolearn_clone/tree/master/build/lib/nltools/analysis.py
# https://github.com/elvandy/nltools/tree/master/nltools/searchlight.py
# https://github.com/bahmanh/DocumentClassification/tree/master/classification.py
# https://github.com/Team-T2-NMR/NMR-T2/tree/master/readfile.py
# https://github.com/laputian/dml/tree/master/manifold_embedding/tsne_rossant.py
# https://github.com/chengsoonong/crowdastro/tree/master/crowdastro/experiment/experiment_yan.py
# https://github.com/mirjalil/ml-visual-recognition/tree/master/codes/classify_half8.py
# https://github.com/bwpriest/rossmannsales/tree/master/src/forecasting.py
# https://github.com/Remi-C/LOD_ordering_for_patches_of_points/tree/master/script/loading benchmark/rforest_on_patch_lean.py
# https://github.com/ijmarshall/cochrane-nlp/tree/master/joint_supervised_learner.py
# https://github.com/rbdavid/Clustering_scripts/tree/master/clustering.py
# https://github.com/bakfu/bakfu/tree/master/bakfu/process/tagging/tag_pattern.py
# https://github.com/yr3var14/ata/tree/master/src/Classifier.py
# https://github.com/rlowrance/re-avm/tree/master/fit-predict.py
# https://github.com/BIDS-collaborative/EDAM/tree/master/LH/kmeans.py
# https://github.com/knowledgegraph/schema/tree/master/dimensionality/manifold.py
# https://github.com/DudLab/nanshe/tree/master/nanshe/imp/segment.py
# https://github.com/adrinjalali/clue-hackathon/tree/master/src/pipeline.py
# https://github.com/dvro/ml/tree/master/mlcin/prototypes/rps.py
# https://github.com/ChengeLi/VehicleTracking/tree/master/sparse_subspace_clusteringClass.py
# https://github.com/NawfalTachfine/PredictionAPI/tree/master/application.py
# https://github.com/umbriel47/malgo/tree/master/util/preproc.py
# https://github.com/moonbury/pythonanywhere/tree/master/MasteringMLWithScikit-learn/8365OS_04_Codes/movies.py
# https://github.com/JMill/edX-Learning-From-Data-Solutions-jm/tree/master/Final/Python/by_Mark_B2/hw7.py
# https://github.com/RomainBrault/operalib/tree/master/setup.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_10_27_2014_server.py
# https://github.com/phbradley/tcr-dist/tree/master/run_basic_analysis.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_04_22_2015.py
# https://github.com/nausheenfatma/embeddings/tree/master/gsoc2017-nausheen/complex/efe/evaluation.py
# https://github.com/hammerlab/immuno_research/tree/master/Feb1_majority_label.py
# https://github.com/rampasek/seizure-prediction/tree/master/features/extractSpectrum.py
# https://github.com/yancz1989/cancer/tree/master/classical.py
# ...
# https://github.com/cycomachead/info290/tree/master/project/code/analysis/bayes.py
# https://github.com/takacsg84/kaggle/tree/master/NDSB/benchmark.py
# https://github.com/mirjalil/ml-visual-recognition/tree/master/codes/classify_half1.py
# https://github.com/ijmarshall/cochrane-nlp/tree/master/quality3.py
# https://github.com/eshavlyugin/Preferans/tree/master/newalgo/tf_train_py2.py
# https://github.com/wilselby/diy_driverless_car_ROS/tree/master/rover_ml/behavior_cloning/src/behavior_cloning/train_model.py
# https://github.com/nishantnath/MusicPredictiveAnalysis_EE660_USCFall2015/tree/master/Code/Machine_Learning_Algos/10k_Tests/ml_classification_knc.py
# https://github.com/marohngroup/kpfm/tree/master/kpfm/scratch/timedomain1703.py
# https://github.com/drphilmarshall/LocalGroupHaloProps/tree/master/final_scripts/proposal_samples.py
# https://github.com/shugamoe/MACS30200proj/tree/master/changemyview/process_pkl.py
# https://github.com/daleloogn/all-in-one/tree/master/feature_selection.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_09_2015_03.py
# https://github.com/zhongyuanzhou/FCH808.github.io/tree/master/Intro to Machine Learning/ud120-projects/tools/startup.py
# https://github.com/bretthandrews/stacking/tree/master/stacking/stack.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v3.0.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/allbernoullinb.py
# https://github.com/benjohnston24/icy-torpedo/tree/master/icyTorpedo/resources/bioid_data.py
# https://github.com/kgori/treeCl/tree/master/treeCl/distance_matrix.py
# https://github.com/Astroua/TurbuStat/tree/master/setup.py
# https://github.com/GreenGear5/planet-wars/tree/master/train-ml-bot.py
# https://github.com/achadha0111/hack-the-burgh/tree/master/main.py
# https://github.com/whitewhim2718/python-qinfer/tree/master/src/qinfer/clustering.py
# https://github.com/rampasek/seizure-prediction/tree/master/features/extractFeaturesWTlog.py
# https://github.com/ChengeLi/VehicleTracking/tree/master/utilities/vis_ConnectedComponent.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/multinomialnbreadmeonly.py
# https://github.com/hammerlab/immuno_research/tree/master/Mar18_hp_aromatic_combined.py
# https://github.com/saromanov/scikit-json/tree/master/scikit_json/scikit_json.py
# https://github.com/TensorVision/MediSeg/tree/master/svm/basic_local_classifier.py
# https://github.com/nishantnath/MusicPredictiveAnalysis_EE660_USCFall2015/tree/master/Code/Machine_Learning_Algos/10k_Tests/ml_classification_kmeans_training.py
# https://github.com/ljchang/nltools/tree/master/nltools/simulator.py
# https://github.com/chosenone75/Neural-Networks/tree/master/vanillaNN/vanillaNN.py
# https://github.com/joshua-cogliati-inl/raven/tree/master/framework/SupervisedLearning.py
# https://github.com/dfd/sktutor/tree/master/src/sktutor/pipeline.py
# https://github.com/hammerlab/immuno_research/tree/master/Mar18_no_mincount.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/averageensemble.py
# https://github.com/rampasek/seizure-prediction/tree/master/pkl2mat.py
# https://github.com/yvlasov/ConProbIN/tree/master/try-ml/check_env.py
# https://github.com/astroumd/admit/tree/master/integration-test/check_numpy.py
# https://github.com/agartland/TCRpred/tree/master/tcrpred_load.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_12_15_2014_server3.py
# https://github.com/sysid/kg/tree/master/fish/Inception3-SVM-Classifier.py
# https://github.com/ucsd-progsys/ml2/tree/master/learning/trees.py
# https://github.com/valpasq/yatsm/tree/master/yatsm/regression/robust_fit.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v2.5.py
# https://github.com/ktaneishi/deepchem/tree/master/deepchem/models/multitask.py
# https://github.com/grisaitis/regressions/tree/master/modelBuilding/modelBuilding.py
# https://github.com/dvro/ml/tree/master/mlcin/prototypes/rsp2.py
# https://github.com/ebellm/ztf_summerschool_2015/tree/master/bootcamp_software/test_python_packages.py
# https://github.com/in3rtial/ift6390_machine_learning_fundamentals/tree/master/project/project/linear_committee.py
# https://github.com/gabrielspadon/SCC5948_DataScience/tree/master/src/engine.py
# https://github.com/CedricVallee/pythonFinancialAnalyst/tree/master/FinancialAnalystV2/Matcher.py
# https://github.com/HasanIssa88/EMG_Classification/tree/master/Linear _Reg_Model.py
# https://github.com/NCBI-Hackathons/DASH_cell_type/tree/master/grid_search.py
# https://github.com/jatraug/Dataclass/tree/master/Module5/assignment2.py
# https://github.com/whodewho/FluxEnder/tree/master/src/dga_model_eval.py
# https://github.com/henchc/CLFL_2016/tree/master/CLFL_CRF_dev.py
# https://github.com/kingjr/mne-python-i/tree/master/mne/utils.py
# https://github.com/drphilmarshall/LocalGroupHaloProps/tree/master/final_scripts/gof_plots.py
# https://github.com/kmaehashi/jubakit/tree/master/jubakit/test/__init__.py
# https://github.com/arnaudsj/mdp-toolkit/tree/master/mdp/configuration.py
# https://github.com/lol/BCI-BO-old/tree/master/BO_BCI.py
# https://github.com/matthijsvk/multimodalSR/tree/master/code/Experiments/Tutorials/nn-from-scratch/StanfordNN_GPU.py
# https://github.com/benchling/Azimuth/tree/master/azimuth/models/regression.py
# https://github.com/salilab/imp/tree/master/modules/pmi/test/test_tools.py
# https://github.com/peastman/deepchem/tree/master/deepchem/utils/evaluate.py
# https://github.com/benjohnston24/icy-torpedo/tree/master/icyTorpedo/resources/muct_data.py
# https://github.com/pyspace/test/tree/master/pySPACE/missions/nodes/scikits_nodes.py
# https://github.com/Vaibhav/Stock-Analysis/tree/master/LDA/logisticRegression.py
# https://github.com/pierrebaque/EM/tree/master/pom_room.py
# https://github.com/jvpoulos/cs289-hw6/tree/master/code/nnet.py
# https://github.com/widdowquinn/THAPBI-pycits/tree/master/tests/test_tool_rand_index_TOOLS.py
# https://github.com/nkundiushuti/pydata2017bcn/tree/master/dataset.py
# https://github.com/xasopheno/audio_visual/tree/master/audio/Training/csv/knn.py
# https://github.com/hammerlab/immuno_research/tree/master/Jan17.py
# https://github.com/arnaudsj/mdp-toolkit/tree/master/mdp/nodes/scikits_nodes.py
# https://github.com/emmjaykay/shiny-octo-shame/tree/master/eke.py
# https://github.com/DJCordhose/speed-limit-signs/tree/master/server/prediction.py
# https://github.com/shanot/imp/tree/master/modules/pmi/test/test_topology_input.py
# https://github.com/vipmunot/Data-Analysis-using-Python/tree/master/Machine learning Beginner/Introduction to Machine Learning-57.py
# https://github.com/farhankhwaja/INF550/tree/master/SourceCode/SGDClassifier/clickthrough.py
# https://github.com/mrminy/ProjectAmazonTextAnalysis/tree/master/johannes/Amazon_notebook.py
# https://github.com/CartoDB/crankshaft/tree/master/release/python/0.4.2/crankshaft/crankshaft/segmentation/segmentation.py
# https://github.com/alan-mnix/MLFinalProject/tree/master/svm_optimize.py
# https://github.com/benchling/Azimuth/tree/master/azimuth/features/featurization.py
# https://github.com/jatraug/Dataclass/tree/master/Module5/assignment3.py
# https://github.com/nmetts/sp2016-csci7000-bda-project/tree/master/classifyAkash_2.py
# https://github.com/matthew-tucker/mne-python/tree/master/mne/utils.py
# https://github.com/mayavanand/RMMAFinalProject/tree/master/azimuth/models/baselines.py
# https://github.com/pravsripad/mne-python/tree/master/mne/cov.py
# https://github.com/shanot/imp/tree/master/modules/pmi/test/test_dof.py
# https://github.com/chengsoonong/crowdastro/tree/master/crowdastro/experiment/experiment_lr_rf.py
# https://github.com/vipmunot/Data-Analysis-using-Python/tree/master/Machine learning Beginner/Challenge_ Machine Learning Basics-205.py
# https://github.com/cjacoby/streambuilder/tree/master/tests/test_streambuilder.py
# https://github.com/kudkudak/r2-learner/tree/master/misc/data_api.py
# https://github.com/chop-dbhi/arrc/tree/master/icd9_analysis.py
# https://github.com/dodger487/MIST/tree/master/data/test_detect.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_12_15_2014.py
# https://github.com/ijmarshall/cochrane-nlp/tree/master/quality5.py
# https://github.com/rproepp/spykeutils/tree/master/spykeutils/sorting_quality_assesment.py
# https://github.com/BIDS-collaborative/EDAM/tree/master/LH/predict_lh.py
# https://github.com/Ichaelus/Github-Classifier/tree/master/Application/Models/ClassificationModules/lrdescriptiononly.py
# https://github.com/DLTK/DLTK/tree/master/examples/MNIST_graph_cnn/graph_utils.py
# https://github.com/jamesjarlathlong/resourceful/tree/master/two_agents_presleep.py
# https://github.com/borg-project/borg/tree/master/borg/experiments/simulate_runs.py
# https://github.com/neuropsychology/NeuroKit.py/tree/master/neurokit/eeg/eeg_microstates.py
# https://github.com/MiladHooshyar/WetChannelExtraction/tree/master/WetChannelExtraction/Wet_Extraction_Fun.py
# https://github.com/ielashi/chinese-zodiac-classifier/tree/master/svm.py
# https://github.com/imsparsh/stanford-mir/tree/master/stanford_mir/core.py
# https://github.com/drubinstein/kaggle_seizure/tree/master/run_wavelets.py
# https://github.com/stanford-gfx/Horus/tree/master/Code/flashlight/quadrotorcamera3d.py
# https://github.com/AssistiveRoboticsUNH/threespace_ros/tree/master/scripts/canal_surface_test/intialize_exercises.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_01_08_2015_02.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/generate_local_cache_ORB.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_Server_0906_2015_pre_activation_rectifier_didnotwork.py
# https://github.com/fracta/ift6390_machine_learning_fundamentals/tree/master/project/project/distortion.py
# https://github.com/teonbrooks/mne-python/tree/master/mne/utils.py
# https://github.com/chuajiesheng/twitter-sentiment-analysis/tree/master/analysis/end_to_end.py
# https://github.com/ijmarshall/cochrane-nlp/tree/master/quality.py
# https://github.com/singhjaideep/Stuff/tree/master/linear_regression.py
# https://github.com/shanot/imp/tree/master/modules/pmi/test/medium_test_topology.py
# https://github.com/salma1601/nilearn/tree/master/nilearn/decomposition/canica.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_10_09_2014_server.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_01_08_2015_01.py
# https://github.com/Funtimezzhou/TradeBuildTools/tree/master/Document/szse/Quantitative Trading/sat-ebook-and-full-source-20150618/algo-ebook-full-source-code-20150618/chapter16/grid_search.py
# https://github.com/dato-code/SFrame/tree/master/oss_src/unity/python/sframe/deps/__init__.py
# https://github.com/johnny555/2d3g/tree/master/ML_stuff.py
# https://github.com/kizzen/Baller-Shot-Caller/tree/master/ModelFitting/single_SVM.py
# https://github.com/Neuroglycerin/neukrill-net-work/tree/master/test_hlf_cache_with_local.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/mnist_psuedo_ipython_dl_ppi/code/DL_Stacked_Model_Mnist_Psuedo_05_11_2015.py
# https://github.com/totuta/deep-supertagging/tree/master/DST_v2.4.py
# https://github.com/bbengfort/TextBlob/tree/master/textblob/nltk/classify/scikitlearn.py
# https://github.com/bowenliu16/deepchem/tree/master/deepchem/models/tests/test_predict.py
# https://github.com/jccaicedo/localization-agent/tree/master/detection/rcnn/trainRegionDetector.py
# https://github.com/dvro/ml/tree/master/mlcin/prototypes/rsp1.py
# https://github.com/NCBI-Hackathons/DASH_cell_type/tree/master/norm_test_data.py
# https://github.com/gregversteeg/corex_topic/tree/master/tests/data/get_twenty_subdocs.py
# https://github.com/ljchang/neurolearn/tree/master/nltools/pbs_job.py
# https://github.com/alexandrwang/hackmit/tree/master/server.py
# https://github.com/DistrictDataLabs/django-data-product/tree/master/irisfinder/views.py
# https://github.com/cggh/biipy/tree/master/test.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_10_30_2014_server.py
# https://github.com/Skobnikoff/Datasets/tree/master/Kagle_Titanic_Python/sandBox.py
# https://github.com/elvandy/nltools/tree/master/nltools/simulator.py
# https://github.com/tridesclous/tridesclous/tree/master/tridesclous/cluster.py
# https://github.com/eredmiles/Fraud-Corruption-Detection-Data-Science-Pipeline-DSSG2015/tree/master/WorldBank2015/Code/modeling/model_pipeline_script.py
# https://github.com/anaderi/lhcb_trigger_ml/tree/master/hep_ml/experiments/metaclassifiers.py
# https://github.com/aufziehvogel/kaggle/tree/master/stumbleupon/predict.py
# https://github.com/vansky/meg_playground/tree/master/scripts/lexicalAccessAnalysisOnSingleMEGchannelV2.py
# https://github.com/marakeby/udl/tree/master/udl/pylearni/models/GaussianBinaryRBM.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_load2-new10fold_12_30_2014_server.py
# https://github.com/luntos/bianalyzer/tree/master/bianalyzer/biclustering/__init__.py
# https://github.com/chrisjmccormick/simsearch/tree/master/runDBSCAN.py
# https://github.com/gabrielspadon/SCC5948_DataScience/tree/master/src/engine2.py
# https://github.com/rmcgibbo/osprey/tree/master/osprey/fit_estimator.py
# https://github.com/viisar/brew/tree/master/examples/pruning.py
# https://github.com/lmc2179/chevrons/tree/master/chevrons/tests/tests.py
# https://github.com/sjyk/activedetect/tree/master/activedetect/model_based/model_eval_utils.py
# https://github.com/amarack/python-rl/tree/master/pyrl/agents/__init__.py
# https://github.com/TensorVision/MediSeg/tree/master/AP3/basic_local_classifier.py
# https://github.com/AssistiveRoboticsUNH/threespace_ros/tree/master/scripts/canal_surface_test/gmm.py
# https://github.com/achadha0111/hack-the-burgh/tree/master/ranker.py
# https://github.com/hammerlab/avm/tree/master/generate_cv_roc_plots.py
# https://github.com/ainafp/nilearn/tree/master/nilearn/_utils/fixes/__init__.py
# https://github.com/marcotcr/lime/tree/master/lime/lime_tabular.py
# https://github.com/yr3var14/ata/tree/master/src/FeatureExtractor.py
# https://github.com/andyh616/mne-python/tree/master/mne/tests/test_cov.py
# https://github.com/magic2du/contact_matrix/tree/master/Contact_maps/DeepLearning/DeepLearningTool/DL_contact_matrix_New_Server_0706_2015_2.py
# https://github.com/mirjalil/ml-visual-recognition/tree/master/codes/classify_half3.py
# https://github.com/dhiana/pretty_tsne/tree/master/pretty_tsne.py
# https://github.com/vansky/cocopro/tree/master/scripts/find_feature_weights.py
# https://github.com/BIDS-collaborative/EDAM/tree/master/app/webtool/views.py
# https://github.com/ernestyalumni/udacity-data-science/tree/master/IntrotoML/Lesson04ChooseYourOwn/adaboost_algo.py
# https://github.com/marcotcr/lime/tree/master/lime/discretize.py
# https://github.com/borg-project/borg/tree/master/borg/experiments/mul_over_alpha.py
# https://github.com/QInfer/python-qinfer/tree/master/src/qinfer/clustering.py
# https://github.com/rockdragon/julia-programming/tree/master/code/ML/learn.py
# https://github.com/beltrame/mmMRI/tree/master/scripts/JasonStart.py
# https://github.com/rlowrance/re-avm/tree/master/rfbound.py
# https://github.com/mayavanand/RMMAFinalProject/tree/master/azimuth/predict.py
# https://github.com/chengsoonong/crowdastro/tree/master/crowdastro/experiment/experiment_scaling.py
# https://github.com/ucscHexmap/hexagram/tree/master/.calc/clr.py
# https://github.com/marcotcr/lime/tree/master/lime/lime_base.py

# %% [markdown]
# ### Plotting most imported submodule (including all models, methods and submodules)

# %%
def barhplot(result, xlabel, title,  color='green'):
    fig, ax = plt.subplots()
    xs = [x for x, _ in result]
    y_pos = range(len(xs))
    ys = [y for _, y in result]
    ax.barh(y_pos, ys, align='center', color=color, ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(xs)
    ax.invert_yaxis()  # labels read top-to-bottom
    for i, v in enumerate(ys):
        ax.text(v + 3, i + .25, str(v), color=color)
    ax.set_xlabel(xlabel)
    ax.set_title(title)

    plt.show()

# %%
barhplot(mostImportedSubmodule[1:21], 'Count', 'Top 20 most imported submodules')

# %%
with open("sklearn_submodule_import/content_py/new/most_imported_function_cleaned.csv", "r") as f:
    mostImportedFunction = [(s.split(",")[0], int(s.split(",")[1][:-1]) if s.split(",")[1][:-1]!='' else 0 ) for s in f.readlines()]
barhplot(mostImportedFunction[:20], "Count", "Top 20 Most Imported sklearn Functions", "blue")

# %%
with open("sklearn_submodule_import/content_py/new/most_imported_submodule_cleaned.csv", "r") as f:
    mostImportedSubmodule = [(s.split(",")[0], int(s.split(",")[1][:-1]) if s.split(",")[1][:-1]!='' else 0 ) for s in f.readlines()]
barhplot(mostImportedSubmodule[:20], "Count", "Top 20 Most Imported sklearn Submodule", "gray")

# %%
with open("sklearn_submodule_import/content_py/new/most_imported_model_cleaned.csv", "r") as f:
    mostImportedModel = [(s.split(",")[0], int(s.split(",")[1][:-1]) if s.split(",")[1][:-1]!='' else 0 ) for s in f.readlines()]
barhplot(mostImportedModel[:20], "Count", "Top 20 Most Imported sklearn Models", "red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2c665a3ca94d> in <module>()
#       1 with open("sklearn_submodule_import/content_py/new/most_imported_model_cleaned.csv", "r") as f:
#       2     mostImportedModel = [(s.split(",")[0], int(s.split(",")[1][:-1]) if s.split(",")[1][:-1]!='' else 0 ) for s in f.readlines()]
# ----> 3 barhplot(mostImportedModel[:20], "Count", "Top 20 Most Imported sklearn Models", "red")
#
# NameError: name 'barhplot' is not defined

# %% [markdown]
# ### Now we compare between python files and ipython notebooks:

# %%
with open("ipynb/sklearn_submodule_import/most_imported_model_cleaned.csv", "r") as f:
    mostImportedModelipynb = [(s.split(",")[0], int(s.split(",")[1][:-1]) if s.split(",")[1][:-1]!='' else 0 ) for s in f.readlines()]

with open("ipynb/sklearn_submodule_import/most_imported_function_cleaned.csv", "r") as f:
    mostImportedFunctionipynb = [(s.split(",")[0], int(s.split(",")[1][:-1]) if s.split(",")[1][:-1]!='' else 0 ) for s in f.readlines()]

with open("ipynb/sklearn_submodule_import/most_imported_submodule_cleaned.csv", "r") as f:
    mostImportedSubmoduleipynb = [(s.split(",")[0], int(s.split(",")[1][:-1]) if s.split(",")[1][:-1]!='' else 0 ) for s in f.readlines()]

# %%
def scatterPlotForPythonIpynbComparison(a,b,num):
    common_keys = list(set([key for key, _ in a[:num]]) & set([key for key, _ in b[:num]]))
    import numpy as np
    N = len(common_keys)
    x = [dict((key, val) for key, val in a)[key] for key in common_keys]
    y = [dict((key, val) for key, val in b)[key] for key in common_keys]
    colors = np.random.rand(N)

    fig, ax = plt.subplots(figsize=(20,20))
    ax.scatter(x, y, s=10, c=colors)
    ax.set_xlabel('Python')
    ax.set_ylabel('ipynb')

    for i, txt in enumerate(common_keys):
        ax.annotate(txt, (x[i],y[i]))

    plt.show()

# %%
scatterPlotForPythonIpynbComparison(mostImportedSubmodule, mostImportedSubmoduleipynb, 10)

# %%
scatterPlotForPythonIpynbComparison(mostImportedModel, mostImportedModelipynb, 20)

# %% [markdown]
# # Context

# %% [markdown]
# ### We want to examine the context of some code. For example, the code around the instantiation of a RandomForestClassifier.

# %%
# The getContext function can only return the first 
# occurence of modelName in each file
def getContext(modelName):
  from google.cloud import bigquery
  client = bigquery.Client()
  query = '''\
  #standardSQL
  CREATE TEMPORARY FUNCTION parsePythonFile(a STRING)
  RETURNS STRING
  LANGUAGE js AS """
    if (a === null) {
      return null;
    }
    var lines = a.split('\\\\n');
    for (i=0;i<lines.length;i++) {
      if (lines[i].indexOf("%s")!==-1){
        return lines.slice(Math.max(i-10,0),Math.min(i+10,lines.length-1)).join("\\\\n");
      }
    }
  """;

  CREATE TEMPORARY FUNCTION parsePythonFile2(a STRING, b STRING)
  RETURNS STRING
  LANGUAGE js AS """
    if (a === null) {
      return null;
    }
    var lines = a.split('\\\\n');
    for (i=0;i<lines.length;i++) {
      if (lines[i].indexOf("%s")!==-1){
        return b;
      }
    }
  """;

  SELECT
    parsePythonFile(content) match,
    parsePythonFile2(content,sample_path) path,
    parsePythonFile2(content,sample_repo_name) repo_name,
    count(*) count
  FROM   
    `scikit-learn-research.pyfiles.content_py` 
  WHERE
     STRPOS(sample_repo_name, 'sklearn') = 0
     AND STRPOS(sample_repo_name, 'scikit-learn') = 0
     AND STRPOS(sample_path,'sklearn') = 0
     AND STRPOS(sample_path,'scikit-learn') = 0
     AND NOT(STRPOS(content, 'sklearn') = 0)
  GROUP BY
  1,2,3
  ORDER BY 
  count DESC
  '''% (modelName,modelName)
  result = client.run_sync_query(query)
  result.timeout_ms = 99999999
  result.run()
  return result.rows

# %%
gridSearchCVcontext = getContext("GridSearchCV(")
prettyPrintContext(gridSearchCVcontext[1:30])
# Out:
# 1.
# https://github.com/lol/BCI-BO-old/tree/master/BCI_Framework/SVM_Learner.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="k">def</span> <span class="nf">train_learner_cv</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">X</span><span class="p">,</span> <span class="n">Y</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot; &quot;&quot;&quot;</span>
#         <span class="n">scaler</span> <span class="o">=</span> <span class="n">StandardScaler</span><span class="p">()</span>
#
#         <span class="n">X</span> <span class="o">=</span> <span class="n">scaler</span><span class="o">.</span><span class="n">fit_transform</span><span class="p">(</span><span class="n">X</span><span class="p">)</span>
#
#         <span class="k">for</span> <span class="n">i</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">config</span><span class="o">.</span><span class="n">configuration</span><span class="p">[</span><span class="s2">&quot;number_of_cvs&quot;</span><span class="p">]):</span>
#             <span class="n">X_new</span><span class="p">,</span> <span class="n">Y_new</span> <span class="o">=</span> <span class="n">shuffle</span><span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="n">Y</span><span class="p">,</span> <span class="n">random_state</span><span class="o">=</span><span class="n">i</span><span class="p">)</span>
#             <span class="n">cv</span> <span class="o">=</span> <span class="n">StratifiedKFold</span><span class="p">(</span><span class="n">y</span><span class="o">=</span><span class="n">Y_new</span><span class="p">,</span> <span class="n">n_folds</span><span class="o">=</span><span class="bp">self</span><span class="o">.</span><span class="n">config</span><span class="o">.</span><span class="n">configuration</span><span class="p">[</span><span class="s2">&quot;number_of_cv_folds&quot;</span><span class="p">])</span>
#
#             <span class="n">grid</span> <span class="o">=</span> <span class="n">GridSearchCV</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">learner</span><span class="p">(</span><span class="n">kernel</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">kernel</span><span class="p">,</span><span class="n">cache_size</span><span class="o">=</span><span class="mi">2000</span><span class="p">),</span> <span class="n">score_func</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">my_loss</span><span class="p">,</span> <span class="n">param_grid</span><span class="o">=</span><span class="bp">self</span><span class="o">.</span><span class="n">param_grid</span><span class="p">,</span>
#                                 <span class="n">cv</span><span class="o">=</span><span class="n">cv</span><span class="p">,</span> <span class="n">n_jobs</span> <span class="o">=</span> <span class="mi">1</span><span class="p">)</span>
#
#             <span class="n">grid</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X_new</span><span class="p">,</span> <span class="n">Y_new</span><span class="p">)</span>
#
#             <span class="k">for</span> <span class="n">j</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="nb">len</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">scores</span><span class="p">)):</span>
#                 <span class="bp">self</span><span class="o">.</span><span class="n">scores</span><span class="p">[</span><span class="n">j</span><span class="p">,</span><span class="n">i</span><span class="p">]</span> <span clas
# 2.
# https://github.com/meinternational/fmri/tree/master/niftybold/pipeline/ica_noise_estimation.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>        <span class="n">pca</span><span class="o">.</span><span class="n">n_components</span> <span class="o">=</span> <span class="n">n</span>
#         <span class="n">fa</span><span class="o">.</span><span class="n">n_components</span> <span class="o">=</span> <span class="n">n</span>
#         <span class="n">pca_scores</span><span class="o">.</span><span class="n">append</span><span class="p">(</span><span class="n">np</span><span class="o">.</span><span class="n">mean</span><span class="p">(</span><span class="n">cross_val_score</span><span class="p">(</span><span class="n">pca</span><span class="p">,</span> <span class="n">X</span><span class="p">)))</span>
#         <span class="n">fa_scores</span><span class="o">.</span><span class="n">append</span><span class="p">(</span><span class="n">np</span><span class="o">.</span><span class="n">mean</span><span class="p">(</span><span class="n">cross_val_score</span><span class="p">(</span><span class="n">fa</span><span class="p">,</span> <span class="n">X</span><span class="p">)))</span>
#
#     <span class="k">return</span> <span class="n">pca_scores</span><span class="p">,</span> <span class="n">fa_scores</span>
#
#
# <span class="k">def</span> <span class="nf">shrunk_cov_score</span><span class="p">(</span><span class="n">X</span><span class="p">):</span>
#     <span class="n">shrinkages</span> <span class="o">=</span> <span class="n">np</span><span class="o">.</span><span class="n">logspace</span><span class="p">(</span><span class="o">-</span><span class="mi">2</span><span class="p">,</span> <span class="mi">0</span><span class="p">,</span> <span class="mi">30</span><span class="p">)</span>
#     <span class="n">cv</span> <span class="o">=</span> <span class="n">GridSearchCV</span><span class="p">(</span><span class="n">ShrunkCovariance</span><span class="p">(),</span> <span class="p">{</span><span class="s1">&#39;shrinkage&#39;</span><span class="p">:</span> <span class="n">shrinkages</span><span class="p">})</span>
#     <span class="k">return</span> <span class="n">np</span><span class="o">.</span><span class="n">mean</span><span class="p">(</span><span class="n">cross_val_score</span><span class="p">(</span><span class="n">cv</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X</span><span class="p">)</span><span class="o">.</span><span class="n">best_estimator_</span><span class="p">,</span> <span class="n">X</span><span class="p">))</span>
#
#
# <span class="k">def</span> <span class="nf">lw_score</span><span class="p">(</span><span class="n">X</span><span class="p">):</span>
#     <span class="k">return</span> <span class="n">np</span><span class="o">.</span><span class="n">mean</span><span class="p">(</span><span class="n">cross_val_score</span><span class="p">(</span><span class="n">LedoitWolf</span><span class="p">(),</span> <span class="n">X</span><span class="p">))</span>
#
#
# <span class="k">for</span> <span class="n">X</span><span class="p">,</span> <span class="n">title</span> <span class="ow">in</span> <span class="p">[(</span><span class="n">X</span><span class="p">,</span> <span class="s1">&#39;Homoscedastic Noise&#39;</span><span class="p">),</span>
#                  <span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="s1">&#39;Heteroscedastic Noise&#39;</span><span class="p">)]:</span>
# </pre></div>
# 3.
# https://github.com/cognoma/machine-learning/tree/master/explore/marginal-gain/marginal-gain-multiple-genes-pca.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="s1">&#39;classify__alpha&#39;</span><span class="p">:</span> <span class="p">[</span><span class="mi">10</span> <span class="o">**</span> <span class="n">x</span> <span class="k">for</span> <span class="n">x</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="o">-</span><span class="mi">6</span><span class="p">,</span> <span class="mi">1</span><span class="p">)],</span>
#     <span class="s1">&#39;classify__l1_ratio&#39;</span><span class="p">:</span> <span class="p">[</span><span class="mi">0</span><span class="p">],</span>
# <span class="p">}</span>
#
# <span class="n">pipeline</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">(</span><span class="n">steps</span><span class="o">=</span><span class="p">[</span>
#     <span class="p">(</span><span class="s1">&#39;standardize&#39;</span><span class="p">,</span> <span class="n">StandardScaler</span><span class="p">()),</span>
#     <span class="p">(</span><span class="s1">&#39;classify&#39;</span><span class="p">,</span> <span class="n">SGDClassifier</span><span class="p">(</span><span class="n">random_state</span><span class="o">=</span><span class="mi">0</span><span class="p">,</span> <span class="n">class_weight</span><span class="o">=</span><span class="s1">&#39;balanced&#39;</span><span class="p">,</span> <span class="n">loss</span><span class="o">=</span><span class="n">param_fixed</span><span class="p">[</span><span class="s1">&#39;loss&#39;</span><span class="p">],</span>
#                                <span class="n">penalty</span><span class="o">=</span><span class="n">param_fixed</span><span class="p">[</span><span class="s1">&#39;penalty&#39;</span><span class="p">]))</span>
# <span class="p">])</span>
#
# <span class="n">pipeline</span> <span class="o">=</span> <span class="n">GridSearchCV</span><span class="p">(</span><span class="n">estimator</span><span class="o">=</span><span class="n">pipeline</span><span class="p">,</span> <span class="n">param_grid</span><span class="o">=</span><span class="n">param_grid</span><span class="p">,</span> <span class="n">scoring</span><span class="o">=</span><span class="s1">&#39;roc_auc&#39;</span><span class="p">)</span>
#
#
# <span class="c1"># In[28]:</span>
#
# <span class="c1"># Helper training/evaluation functions.</span>
# <span class="k">def</span> <span class="nf">train_and_evaluate</span><span class="p">(</span><span class="n">data</span><span class="p">,</span> <span class="n">pipeline</span><span class="p">):</span>
#     <span class="s2">&quot;&quot;&quot;</span>
# <span class="s2">    Train each model using grid search, and ouput:</span>
# <span class="s2">    1) all_best_estimator_aurocs: contains aurocs for mean_cv, train, and test for chosen grid parameters</span>
# </pre></div>
# 4.
# https://github.com/tadeas/social-deviance/tree/master/scikit_brackets.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="n">text_clf</span> <span class="o">=</span> <span class="n">text_clf</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">messages_train</span><span class="p">,</span> <span class="n">likes_train</span><span class="p">)</span>
#     <span class="k">print</span><span class="p">(</span><span class="s1">&#39;Training finished.&#39;</span><span class="p">)</span>
#
#     <span class="n">predicted</span> <span class="o">=</span> <span class="n">text_clf</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">messages_test</span><span class="p">)</span>
#     <span class="k">print</span><span class="p">(</span><span class="s1">&#39;Correct predictions: &#39;</span><span class="p">,</span> <span class="n">precision</span><span class="p">(</span><span class="n">likes_test</span><span class="p">,</span> <span class="n">predicted</span><span class="p">))</span>
#
#     <span class="c1">#print(&#39;Starting search for better parameters.&#39;)</span>
#     <span class="c1">#parameters = {</span>
#     <span class="c1">#              &#39;clf__tol&#39;: (1e-2, 1e-3, 1e-4),</span>
#     <span class="c1">#             }</span>
#     <span class="c1">#gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1)</span>
#     <span class="c1">#gs_clf = gs_clf.fit(messages_train, likes_train)</span>
#     <span class="c1">#print(&#39;Search for better parameters finished.&#39;)</span>
#
#     <span class="c1">#predicted = gs_clf.predict(messages_test)</span>
#     <span class="c1">#print(&#39;Correct predictions: &#39;, precision(likes_test, predicted))</span>
#
#     <span class="c1">#print(&#39;Best score: &#39;, gs_clf.best_score_)</span>
#     <span class="c1">#for param_name in sorted(parameters.keys()):</span>
#     <span class="c1">#    print(&#39;{}: {}&#39;.format(param_name, gs_clf.best_params_[param_name]))</span>
# </pre></div>
# 5.
# https://github.com/oduwa/Wheat-Count/tree/master/SVM.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>            <span class="k">elif</span><span class="p">(</span><span class="n">featureRepresentation</span> <span class="o">==</span> <span class="s1">&#39;glcm&#39;</span><span class="p">):</span>
#                 <span class="n">test_data</span><span class="p">[</span><span class="n">i</span><span class="p">]</span> <span class="o">=</span> <span class="n">Helper</span><span class="o">.</span><span class="n">get_textural_features</span><span class="p">(</span><span class="n">img</span><span class="p">,</span> <span class="n">glcm_distance</span><span class="p">,</span> <span class="n">glcm_isMultidirectional</span><span class="p">)</span>
#             <span class="n">i</span> <span class="o">=</span> <span class="n">i</span> <span class="o">+</span> <span class="mi">1</span><span class="p">;</span>
#     <span class="k">else</span><span class="p">:</span>
#         <span class="p">(</span><span class="n">train_data</span><span class="p">,</span> <span class="n">train_targets</span><span class="p">,</span> <span class="n">test_data</span><span class="p">,</span> <span class="n">expected</span><span class="p">)</span> <span class="o">=</span> <span class="n">Helper</span><span class="o">.</span><span class="n">unserialize</span><span class="p">(</span><span class="n">dataset_file</span><span class="p">)</span>
#
#     <span class="c1"># Perform build iterations</span>
#     <span class="k">for</span> <span class="n">i</span> <span class="ow">in</span> <span class="n">tqdm</span><span class="o">.</span><span class="n">tqdm</span><span class="p">(</span><span class="nb">range</span><span class="p">(</span><span class="mi">0</span><span class="p">,</span> <span class="n">iters</span><span class="p">)):</span>
#         <span class="c1"># Build Classifier</span>
#         <span class="n">param_grid</span> <span class="o">=</span> <span class="p">{</span><span class="s1">&#39;C&#39;</span><span class="p">:</span> <span class="p">[</span><span class="mf">1e0</span><span class="p">,</span> <span class="mf">5e0</span><span class="p">,</span> <span class="mf">1e1</span><span class="p">,</span> <span class="mf">5e1</span><span class="p">,</span> <span class="mf">1e2</span><span class="p">],</span> <span class="s1">&#39;kernel&#39;</span><span class="p">:</span> <span class="p">[</span><span class="s1">&#39;rbf&#39;</span><span class="p">,</span> <span class="s1">&#39;poly&#39;</span><span class="p">]</span> <span class="p">}</span>
#         <span class="n">classifier</span> <span class="o">=</span> <span class="n">svm</span><span class="o">.</span><span class="n">SVC</span><span class="p">(</span><span class="n">kernel</span><span class="o">=</span><span class="s1">&#39;rbf&#39;</span><span class="p">)</span><span class="c1">#grid_search.GridSearchCV(svm.SVC(kernel=&#39;rbf&#39;, class_weight=&#39;balanced&#39;), param_grid)</span>
#         <span class="n">classifier</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">train_data</span><span class="p">,</span> <span class="n">train_targets</span><span class="p">)</span>
#
#         <span class="c1"># Get previous classifier and assess</span>
#         <span class="n">serialized_classifier</span> <span class="o">=</span> <span class="n">Helper</span><span class="o">.</span><span class="n">unserialize</span><span class="p">(</span><span class="n">SVM_FILE</span><span class="p">)</span>
#         <span class="k">if</span><span class="p">(</span><span class="n">serialized_classifier</span><span class="p">):</span>
#             <span class="n">predictions</span> <span class="o">=</span> <span class="n">serialized_classifier</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">test_data</span><span class="p">)</span>
#             <span cla
# 6.
# https://github.com/mulhod/reviewer_experience_prediction/tree/master/util/cv_learn.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>            <span class="k">if</span> <span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">data_</span><span class="o">.</span><span class="n">grid_search_folds</span> <span class="o">&lt;</span> <span class="mi">2</span>
#                 <span class="ow">or</span> <span class="n">folds_diff</span><span class="o">/</span><span class="n">cfg</span><span class="o">.</span><span class="n">grid_search_folds</span> <span class="o">&gt;</span> <span class="mf">0.25</span><span class="p">):</span>
#                 <span class="n">msg</span> <span class="o">=</span> <span class="p">(</span><span class="s1">&#39;Either there weren</span><span class="se">\&#39;</span><span class="s1">t enough folds after collecting &#39;</span>
#                        <span class="s1">&#39;data (via `ExperimentalData`) to do the grid search &#39;</span>
#                        <span class="s1">&#39;round or the number of folds had to be reduced to such&#39;</span>
#                        <span class="s1">&#39; a degree that it would mean a +25\</span><span class="si">% r</span><span class="s1">eduction in the &#39;</span>
#                        <span class="s1">&#39;total number of folds used during the grid search &#39;</span>
#                        <span class="s1">&#39;round.&#39;</span><span class="p">)</span>
#                 <span class="n">logerr</span><span class="p">(</span><span class="n">msg</span><span class="p">)</span>
#                 <span class="k">raise</span> <span class="ne">ValueError</span><span class="p">(</span><span class="n">msg</span><span class="p">)</span>
#             <span class="n">gs_cv</span> <span class="o">=</span> <span class="n">GridSearchCV</span><span class="p">(</span><span class="n">learner</span><span class="p">(),</span>
#                                  <span class="n">param_grids</span><span class="p">,</span>
#                                  <span class="n">cv</span><span class="o">=</span><span class="n">gs_cv_folds_</span><span class="p">,</span>
#                                  <span class="n">scoring</span><span class="o">=</span><span class="bp">self</span><span class="o">.</span><span class="n">_resolve_objective_function</span><span class="p">())</span>
#
#             <span class="c1"># Do the grid search cross-validation</span>
#             <span class="n">gs_cv</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X_train</span><span class="p">,</span> <span class="n">y_train</span><span class="p">)</span>
#             <span class="n">learner_gs_cv_params_</span><span class="p">[</span><span class="n">learner_name</span><span class="p">]</span> <span class="o">=</span> <span class="n">gs_cv</span><span class="o">.</span><span class="n">best_params_</span>
#             <span class="k">del</span> <span class="n">gs_cv</span>
# </pre></div>
# 7.
# https://github.com/ijmarshall/cochrane-nlp/tree/master/supervised_learner.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# ...
# </pre></div>
# 28.
# https://github.com/ksomemo/BuildingMachineLearningSystemsWithPython/tree/master/ch06/04_sent.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="n">param_grid</span> <span class="o">=</span> <span class="nb">dict</span><span class="p">(</span><span class="n">vect__ngram_range</span><span class="o">=</span><span class="p">[(</span><span class="mi">1</span><span class="p">,</span> <span class="mi">1</span><span class="p">),</span> <span class="p">(</span><span class="mi">1</span><span class="p">,</span> <span class="mi">2</span><span class="p">),</span> <span class="p">(</span><span class="mi">1</span><span class="p">,</span> <span class="mi">3</span><span class="p">)],</span>
#                       <span class="n">vect__min_df</span><span class="o">=</span><span class="p">[</span><span class="mi">1</span><span class="p">,</span> <span class="mi">2</span><span class="p">],</span>
#                       <span class="n">vect__smooth_idf</span><span class="o">=</span><span class="p">[</span><span class="bp">False</span><span class="p">,</span> <span class="bp">True</span><span class="p">],</span>
#                       <span class="n">vect__use_idf</span><span class="o">=</span><span class="p">[</span><span class="bp">False</span><span class="p">,</span> <span class="bp">True</span><span class="p">],</span>
#                       <span class="n">vect__sublinear_tf</span><span class="o">=</span><span class="p">[</span><span class="bp">False</span><span class="p">,</span> <span class="bp">True</span><span class="p">],</span>
#                       <span class="n">vect__binary</span><span class="o">=</span><span class="p">[</span><span class="bp">False</span><span class="p">,</span> <span class="bp">True</span><span class="p">],</span>
#                       <span class="n">clf__alpha</span><span class="o">=</span><span class="p">[</span><span class="mi">0</span><span class="p">,</span> <span class="mf">0.01</span><span class="p">,</span> <span class="mf">0.05</span><span class="p">,</span> <span class="mf">0.1</span><span class="p">,</span> <span class="mf">0.5</span><span class="p">,</span> <span class="mi">1</span><span class="p">],</span>
#                       <span class="p">)</span>
#
#     <span class="n">grid_search</span> <span class="o">=</span> <span class="n">GridSearchCV</span><span class="p">(</span><span class="n">clf_factory</span><span class="p">(),</span>
#                                <span class="n">param_grid</span><span class="o">=</span><span class="n">param_grid</span><span class="p">,</span>
#                                <span class="n">cv</span><span class="o">=</span><span class="n">cv</span><span class="p">,</span>
#                                <span class="n">score_func</span><span class="o">=</span><span class="n">f1_score</span><span class="p">,</span>
#                                <span class="n">verbose</span><span class="o">=</span><span class="mi">10</span><span class="p">)</span>
#     <span class="n">grid_search</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="n">Y</span><span class="p">)</span>
#     <span class="n">clf</span> <span class="o">=</span> <span class="n">grid_search</span><span class="o">.</span><span class="n">best_estimator_</span>
#     <span class="k">print</span><span class="p">(</span><span class="n">clf</span><span class="p">)</span>
#
#     <span class="k">return</span> <span class="n">clf</span>
# </pre></div>
# 29.
# https://github.com/whitews/wa-isit/tree/master/isi_lib/utils.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">build_trained_model</span><span class="p">(</span><span class="n">training_data</span><span class="p">,</span> <span class="n">classifier</span><span class="o">=</span><span class="s1">&#39;svc&#39;</span><span class="p">):</span>
#     <span class="n">alpha</span> <span class="o">=</span> <span class="p">[</span><span class="mf">1e-5</span><span class="p">,</span> <span class="mf">1e-4</span><span class="p">,</span> <span class="mf">1e-3</span><span class="p">,</span> <span class="mf">1e-2</span><span class="p">,</span> <span class="mf">1e-1</span><span class="p">,</span> <span class="mi">1</span><span class="p">,</span> <span class="mi">10</span><span class="p">]</span>
#     <span class="n">ridge_params</span> <span class="o">=</span> <span class="p">{</span><span class="s1">&#39;alpha&#39;</span><span class="p">:</span> <span class="n">alpha</span><span class="p">}</span>
#
#     <span class="n">c_s</span> <span class="o">=</span> <span class="p">[</span><span class="mf">0.01</span><span class="p">,</span> <span class="mf">0.1</span><span class="p">,</span> <span class="mf">1.0</span><span class="p">,</span> <span class="mf">10.0</span><span class="p">,</span> <span class="mf">100.0</span><span class="p">]</span>
#     <span class="n">gamma</span> <span class="o">=</span> <span class="p">[</span><span class="mf">1e-4</span><span class="p">,</span> <span class="mf">1e-3</span><span class="p">,</span> <span class="mf">1e-2</span><span class="p">,</span> <span class="mf">1e-1</span><span class="p">,</span> <span class="mi">1</span><span class="p">,</span> <span class="mi">10</span><span class="p">]</span>
#     <span class="n">svc_params</span> <span class="o">=</span> <span class="p">[{</span><span class="s1">&#39;kernel&#39;</span><span class="p">:</span> <span class="p">[</span><span class="s1">&#39;rbf&#39;</span><span class="p">],</span> <span class="s1">&#39;gamma&#39;</span><span class="p">:</span> <span class="n">gamma</span><span class="p">,</span> <span class="s1">&#39;C&#39;</span><span class="p">:</span> <span class="n">c_s</span><span class="p">},</span>
#                   <span class="p">{</span><span class="s1">&#39;kernel&#39;</span><span class="p">:</span> <span class="p">[</span><span class="s1">&#39;linear&#39;</span><span class="p">],</span> <span class="s1">&#39;C&#39;</span><span class="p">:</span> <span class="n">c_s</span><span class="p">}]</span>
#
#     <span class="k">if</span> <span class="n">classifier</span> <span class="o">==</span> <span class="s1">&#39;svc&#39;</span><span class="p">:</span>
#         <span class="n">clf</span> <span class="o">=</span> <span class="n">GridSearchCV</span><span class="p">(</span><span class="n">SVC</span><span class="p">(</span><span class="n">probability</span><span class="o">=</span><span class="bp">True</span><span class="p">),</span> <span class="n">svc_params</span><span class="p">,</span> <span class="n">cv</span><span class="o">=</span><span class="mi">5</span><span class="p">)</span>
#         <span class="c1"># clf = GridSearchCV(SVC(probability=True, class_weight=&#39;balanced&#39;), svc_params, cv=5)</span>
#     <span class="k">elif</span> <span class="n">classifier</span> <span class="o">==</span> <span class="s1">&#39;ridge&#39;</span><span class="p">:</span>
#         <span class="n">clf</span> <span class="o">=</span> <span class="n">GridSearchCV</span><span class="p">(</span><span class="n">RidgeClassifier</span><span class="p">(),</span> <span class="n">ridge_params</span><span class="p">,</span> <span class="n">cv</span><span class="o">=</span><span class="mi">5</span><span class="p">)</span>
#     <span class="k">else</span><span class="p">:</span>
#         <span class="k">raise</span> <span class="ne">NotImplementedError</span><span

# %%
pipelineContext = getContext("Pipeline(")
prettyPrintContext(pipelineContext[1:30])
# Out:
# 1.
# https://github.com/salma1601/nilearn/tree/master/examples/decoding/plot_haxby_anova_svm.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">### Define the dimension reduction to be used.</span>
# <span class="c1"># Here we use a classical univariate feature selection based on F-test,</span>
# <span class="c1"># namely Anova. We set the number of features to be selected to 500</span>
# <span class="n">feature_selection</span> <span class="o">=</span> <span class="n">SelectKBest</span><span class="p">(</span><span class="n">f_classif</span><span class="p">,</span> <span class="n">k</span><span class="o">=</span><span class="mi">500</span><span class="p">)</span>
#
# <span class="c1"># We have our classifier (SVC), our feature selection (SelectKBest), and now,</span>
# <span class="c1"># we can plug them together in a *pipeline* that performs the two operations</span>
# <span class="c1"># successively:</span>
# <span class="kn">from</span> <span class="nn">sklearn.pipeline</span> <span class="kn">import</span> <span class="n">Pipeline</span>
# <span class="n">anova_svc</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;anova&#39;</span><span class="p">,</span> <span class="n">feature_selection</span><span class="p">),</span> <span class="p">(</span><span class="s1">&#39;svc&#39;</span><span class="p">,</span> <span class="n">svc</span><span class="p">)])</span>
#
# <span class="c1">### Fit and predict ###########################################################</span>
#
# <span class="n">anova_svc</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="n">y</span><span class="p">)</span>
# <span class="n">y_pred</span> <span class="o">=</span> <span class="n">anova_svc</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">X</span><span class="p">)</span>
#
# <span class="c1">### Visualization #############################################################</span>
#
# <span class="c1">### Look at the SVC&#39;s discriminating weights</span>
# </pre></div>
# 2.
# https://github.com/eboreapps/Scikit-Learn-Playground/tree/master/ScikitlearnPlayground/MultiLabelClassification.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1"># Create a binary array marking values as True or False</span>
# <span class="n">y_train_binarized</span> <span class="o">=</span> <span class="n">MultiLabelBinarizer</span><span class="p">()</span><span class="o">.</span><span class="n">fit_transform</span><span class="p">(</span><span class="n">y_train</span><span class="p">)</span>
#
# <span class="n">X_test</span> <span class="o">=</span> <span class="n">np</span><span class="o">.</span><span class="n">array</span><span class="p">([</span><span class="s1">&#39;nice day in nyc&#39;</span><span class="p">,</span>
#                    <span class="s1">&#39;welcome to london&#39;</span><span class="p">,</span>
#                    <span class="s1">&#39;hello welcome to new york. enjoy it here and london too&#39;</span><span class="p">])</span>
#
# <span class="n">target_names</span> <span class="o">=</span> <span class="p">[</span><span class="s1">&#39;New York&#39;</span><span class="p">,</span> <span class="s1">&#39;London&#39;</span><span class="p">]</span>
#
# <span class="n">classifier</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([</span>
#     <span class="p">(</span><span class="s1">&#39;vectorizer&#39;</span><span class="p">,</span> <span class="n">CountVectorizer</span><span class="p">()),</span>
#     <span class="p">(</span><span class="s1">&#39;tfidf&#39;</span><span class="p">,</span> <span class="n">TfidfTransformer</span><span class="p">()),</span>
#     <span class="p">(</span><span class="s1">&#39;clf&#39;</span><span class="p">,</span> <span class="n">OneVsRestClassifier</span><span class="p">(</span><span class="n">SVC</span><span class="p">(</span><span class="n">kernel</span><span class="o">=</span><span class="s1">&#39;linear&#39;</span><span class="p">)))])</span>
#
# <span class="n">classifier</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X_train</span><span class="p">,</span> <span class="n">y_train_binarized</span><span class="p">)</span>
#
# <span class="n">predicted</span> <span class="o">=</span> <span class="n">classifier</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">X_test</span><span class="p">)</span>
#
# <span class="k">for</span> <span class="n">item</span><span class="p">,</span> <span class="n">preds</span> <span class="ow">in</span> <span class="nb">zip</span><span class="p">(</span><span class="n">X_test</span><span class="p">,</span> <span class="n">predicted</span><span class="p">):</span>
# </pre></div>
# 3.
# https://github.com/mikekestemont/ruzicka/tree/master/code/ruzicka/vectorization.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>        <span class="k">if</span> <span class="n">ngram_type</span> <span class="o">==</span> <span class="s1">&#39;word&#39;</span><span class="p">:</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">params</span><span class="p">[</span><span class="s1">&#39;tokenizer&#39;</span><span class="p">]</span> <span class="o">=</span> <span class="n">identity</span>
#         <span class="k">elif</span> <span class="n">ngram_type</span> <span class="ow">in</span> <span class="p">(</span><span class="s1">&#39;char&#39;</span><span class="p">,</span> <span class="s1">&#39;char_wb&#39;</span><span class="p">):</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">params</span><span class="p">[</span><span class="s1">&#39;analyzer&#39;</span><span class="p">]</span> <span class="o">=</span> <span class="n">ngram_type</span>
#
#         <span class="n">n</span> <span class="o">=</span> <span class="n">Normalizer</span><span class="p">(</span><span class="n">norm</span><span class="o">=</span><span class="s2">&quot;l2&quot;</span><span class="p">,</span> <span class="n">copy</span><span class="o">=</span><span class="bp">False</span><span class="p">)</span>
#
#         <span class="k">if</span> <span class="n">vector_space</span> <span class="o">==</span> <span class="s1">&#39;tf&#39;</span><span class="p">:</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">params</span><span class="p">[</span><span class="s1">&#39;use_idf&#39;</span><span class="p">]</span> <span class="o">=</span> <span class="bp">False</span>
#             <span class="n">v</span> <span class="o">=</span> <span class="n">TfidfVectorizer</span><span class="p">(</span><span class="o">**</span><span class="bp">self</span><span class="o">.</span><span class="n">params</span><span class="p">)</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">transformer</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;s1&#39;</span><span class="p">,</span> <span class="n">v</span><span class="p">),</span> <span class="p">(</span><span class="s1">&#39;s2&#39;</span><span class="p">,</span> <span class="n">n</span><span class="p">)])</span>
#
#         <span class="k">elif</span> <span class="n">vector_space</span> <span class="o">==</span> <span class="s1">&#39;tf_std&#39;</span><span class="p">:</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">params</span><span class="p">[</span><span class="s1">&#39;use_idf&#39;</span><span class="p">]</span> <span class="o">=</span> <span class="bp">False</span>
#             <span class="n">v</span> <span class="o">=</span> <span class="n">TfidfVectorizer</span><span class="p">(</span><span class="o">**</span><span class="bp">self</span><span class="o">.</span><span class="n">params</span><span class="p">)</span>
#             <span class="n">scaler</span> <span class="o">=</span> <span class="n">StdDevScaler</span><span class="p">()</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">transformer</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;s1&#39;</span><span class="p">,</span> <span class="n">v</span><span class="p">),</span> <span class="p">(</span><span class="s1">&#39;s2&#39;</span><span class="p">,</span> <span class="n">scaler</span><span class="p">),</span> <span class="p">(</span><span class="s1">&#39;s3&#39;</span><span class="p">,</span> <span class="n">n</span><span class="p">)])</span>
#
#         <span class="k">elif</span> <span class="n">vector_space</span> <span class="o">==</span> <span class="s1">&#39;tf_idf&#39;</span><span c
# 4.
# https://github.com/sorpaas/reread/tree/master/reader/learn.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="kn">from</span> <span class="nn">sklearn.feature_extraction.text</span> <span class="kn">import</span> <span class="n">TfidfTransformer</span><span class="p">,</span> <span class="n">CountVectorizer</span>
#
#
# <span class="k">def</span> <span class="nf">normalize</span><span class="p">(</span><span class="n">text</span><span class="p">):</span>
#     <span class="n">stemmer</span> <span class="o">=</span> <span class="n">EnglishStemmer</span><span class="p">()</span>
#     <span class="k">return</span> <span class="s1">&#39; &#39;</span><span class="o">.</span><span class="n">join</span><span class="p">([</span><span class="n">stemmer</span><span class="o">.</span><span class="n">stem</span><span class="p">(</span><span class="n">s</span><span class="p">)</span> <span class="k">for</span> <span class="n">s</span> <span class="ow">in</span> <span class="n">text</span><span class="o">.</span><span class="n">split</span><span class="p">()])</span>
#
#
# <span class="k">def</span> <span class="nf">predict_articles</span><span class="p">(</span><span class="n">reader</span><span class="p">,</span> <span class="n">articles</span><span class="p">,</span> <span class="n">n</span><span class="o">=</span><span class="mi">5</span><span class="p">):</span>
#     <span class="kn">from</span> <span class="nn">reader.documents</span> <span class="kn">import</span> <span class="n">ReadRecord</span>
#     <span class="n">text_clf</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;vect&#39;</span><span class="p">,</span> <span class="n">CountVectorizer</span><span class="p">()),</span>
#                          <span class="p">(</span><span class="s1">&#39;tfidf&#39;</span><span class="p">,</span> <span class="n">TfidfTransformer</span><span class="p">()),</span>
#                          <span class="p">(</span><span class="s1">&#39;clf&#39;</span><span class="p">,</span> <span class="n">SGDRegressor</span><span class="p">())])</span>
#     <span class="n">records</span> <span class="o">=</span> <span class="n">ReadRecord</span><span class="o">.</span><span class="n">objects</span><span class="p">(</span><span class="n">reader</span><span class="o">=</span><span class="n">reader</span><span class="p">)</span>
#     <span class="n">text_clf</span><span class="o">.</span><span class="n">fit</span><span class="p">([</span><span class="n">normalize</span><span class="p">(</span><span class="n">x</span><span class="o">.</span><span class="n">article</span><span class="o">.</span><span class="n">content_text</span><span class="p">)</span> <span class="k">for</span> <span class="n">x</span> <span class="ow">in</span> <span class="n">records</span><span class="p">],</span>
#                  <span class="p">[(</span><span class="mi">1</span> <span class="k">if</span> <span class="n">x</span><span class="o">.</span><span class="n">is_liked</span> <span class="k">else</span> <span class="mi">0</span><span class="p">)</span> <span class="k">for</span> <span class="n">x</span> <span class="ow">in</span> <span class="n">records</span><span class="p">])</span>
#     <span class="n">predicted</span> <span class="o">=</span> <span class="n">text_clf</span><span class="o">.</span><span class="n">predict</span><span class="p">([</span><span class="n">normalize</span><span class="p">(</span><span class="n">x</span><span class="o">.</span><span class="n">content_text</span><span class="p">)</span> <span class="k">for</span> <span class="n">x</span> <span class="ow">in</span> <span class="n">articles</span><span class="p">])</span>
#     <span class="k">return</span> <span class="nb">sorted</span><span class="p">(</span><span class="nb">zip</span><span class="p">(</span><span class="nb">list</span><span class="p">(</span><span
# 5.
# https://github.com/annavicente/Tatooine/tree/master/machine-learning-python/programas/ML1.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>
# 	<span class="sd">&#39;&#39;&#39; AVALIANDO NOSSOS RESULTADOS &#39;&#39;&#39;</span>
# 	<span class="c1">#y_train_pred = clf.predict(x_train)</span>
# 	<span class="c1">#print(metrics.accuracy_score(y_train,y_train_pred)) #--&gt; Nunca testar a acuracia no conjunto de treinamento por causa do overfitting</span>
#
# 	<span class="n">y_pred</span> <span class="o">=</span> <span class="n">clf</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">x_test</span><span class="p">)</span>
# 	<span class="c1">#print(metrics.accuracy_score(y_test,y_pred))</span>
# 	<span class="c1">#print(metrics.classification_report(y_test, y_pred, target_names = iris.target_names))</span>
# 	<span class="c1">#print(metrics.confusion_matrix(y_test,y_pred)) #--&gt; a matriz de confusao quantifica quantos exemplos da base de dados utilizada seriam classficiados bem pelo metodo construido (diagonal principal) sendo que os outros seriam mal classificados</span>
#
# 	<span class="n">clf</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;scaler&#39;</span><span class="p">,</span> <span class="n">preprocessing</span><span class="o">.</span><span class="n">StandardScaler</span><span class="p">()),(</span><span class="s1">&#39;linear_model&#39;</span><span class="p">,</span> <span class="n">SGDClassifier</span><span class="p">())])</span> <span class="c1">#--&gt; StandardScaler : Padroniza recursos, removendo a media e escalando para variancia unitaria</span>
# 	<span class="n">cv</span> <span class="o">=</span> <span class="n">KFold</span><span class="p">(</span><span class="n">x</span><span class="o">.</span><span class="n">shape</span><span class="p">[</span><span class="mi">0</span><span class="p">],</span> <span class="mi">5</span><span class="p">,</span> <span class="n">shuffle</span> <span class="o">=</span> <span class="bp">True</span><span class="p">,</span> <span class="n">random_state</span> <span class="o">=</span> <span class="mi">33</span><span class="p">)</span> <span class="c1">#--&gt; quantidade de conjuntos de validacao cruzada</span>
# 	<span class="n">scores</span> <span class="o">=</span> <span class="n">cross_val_score</span><span class="p">(</span><span class="n">clf</span><span class="p">,</span><span class="n">x</span><span class="p">,</span><span class="n">y</span><span class="p">,</span><span class="n">cv</span> <span class="o">=</span> <span class="n">cv</span><span class="p">)</span> <span class="c1">#por padrao retorna a acuracia</span>
# 	<span class="c1">#print(scores)</span>
# 	<span class="c1">#print(mean_scores(scores))</span>
#
#
# 	<span class="k">return</span> <span class="mi">0</span>
#
# <span class="k">if</span> <span class="n">__name__</span> <span class="o">==</span> <span class="s1">&#39;__main__&#39;</span><span class="p">:</span>
# </pre></div>
# 6.
# https://github.com/bcraenen/KFClassifier/tree/master/deploy/hpc/RandomForestSampleJaume.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="k">print</span> <span class="s2">&quot;initialise label encoder&quot;</span>
# <span class="n">labelEncoder</span> <span class="o">=</span> <span class="n">preprocessing</span><span class="o">.</span><span class="n">LabelEncoder</span><span class="p">()</span>
# <span class="k">print</span> <span class="s2">&quot;initialise scaler&quot;</span>
# <span class="n">scaler</span> <span class="o">=</span> <span class="n">preprocessing</span><span class="o">.</span><span class="n">RobustScaler</span><span class="p">()</span>
# <span class="k">print</span> <span class="s2">&quot;initialise classifier&quot;</span>
# <span class="n">classifier</span> <span class="o">=</span> <span class="n">RandomForestClassifier</span><span class="p">(</span><span class="n">n_estimators</span><span class="o">=</span><span class="mi">200</span><span class="p">,</span> <span class="n">oob_score</span><span class="o">=</span><span class="bp">True</span><span class="p">,</span> <span class="n">bootstrap</span><span class="o">=</span><span class="bp">True</span><span class="p">)</span>
# <span class="k">print</span> <span class="s2">&quot;initialise selector&quot;</span>
# <span class="n">selector</span> <span class="o">=</span> <span class="n">RFE</span><span class="p">(</span><span class="n">classifier</span><span class="p">,</span> <span class="n">n_features_to_select</span> <span class="o">=</span> <span class="mi">10</span><span class="p">,</span> <span class="n">step</span><span class="o">=</span><span class="mf">0.10</span><span class="p">)</span>
#
# <span class="k">print</span> <span class="s2">&quot;Setup pipeline&quot;</span>
# <span class="n">pipeline</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s2">&quot;scaler&quot;</span><span class="p">,</span><span class="n">scaler</span><span class="p">),(</span><span class="s2">&quot;RFE&quot;</span><span class="p">,</span> <span class="n">selector</span><span class="p">),</span> <span class="p">(</span><span class="s2">&quot;classifier&quot;</span><span class="p">,</span><span class="n">classifier</span><span class="p">)])</span>
#
# <span class="k">print</span> <span class="s2">&quot;Setup parameter grid&quot;</span>
# <span class="n">param_grid</span> <span class="o">=</span> <span class="nb">dict</span><span class="p">(</span><span class="n">RFE__n_features_to_select</span><span class="o">=</span><span class="p">[</span><span class="mi">2</span><span class="p">,</span><span class="mi">3</span><span class="p">,</span><span class="mi">5</span><span class="p">,</span><span class="mi">10</span><span class="p">,</span><span class="mi">20</span><span class="p">],</span> <span class="n">classifier__max_depth</span><span class="o">=</span><span class="p">[</span><span class="mi">2</span><span class="p">,</span><span class="mi">3</span><span class="p">,</span><span class="mi">4</span><span class="p">,</span><span class="mi">5</span><span class="p">,</span><span class="mi">10</span><span class="p">],</span> <span class="n">classifier__n_estimators</span><span class="o">=</span><span class="p">[</span><span class="mi">100</span><span class="p">,</span> <span class="mi">200</span><span class="p">,</span> <span class="mi">300</span><span class="p">,</span> <span class="mi">500</span><span class="p">,</span> <span class="mi">1000</span><span class="p">,</span> <span class="mi">3000</span><span class="p">])</span>
# <span class="c1">#param_grid = dict(RFE__n_features_to_select=[2], classifier__max_depth=[2], classifier__n_estimators=[100, 200, 300, 500, 1000, 3000])</span>
#
# <span class="k">print</span> <span class="s2">&quot;Initialise arff decoder&quot;</span>
# <span class="n">arffDecoder</span> <span class="o">=</span> <span class="n">arff</span><span class="o">.</span><span class
# 7.
# https://github.com/ipashchenko/ml4vs/tree/master/ml4vs/xgb_f1.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# ...
#     <span class="k">return</span> <span class="n">f1_score</span><span class="p">(</span><span class="n">ys</span><span class="p">,</span> <span class="n">ypred</span><span class="p">)</span>
#
#
#
# <span class="sd">&#39;&#39;&#39;</span>
# <span class="sd">#hyperparameterization tuning loop</span>
# <span class="sd">#note that this does not do any better ...</span>
# <span class="sd">P = PCA()</span>
# <span class="sd">L = LogisticRegression()</span>
# <span class="sd">pipe = Pipeline(steps=[(&#39;pca&#39;,P),(&#39;log&#39;,L)])</span>
# <span class="sd">parameters = {&#39;log__penalty&#39;: [&#39;l1&#39;,&#39;l2&#39;],</span>
# <span class="sd">              &#39;log__C&#39; : expon(loc=0.0,scale=0.05),</span>
# <span class="sd">              &#39;pca__n_components&#39; : geom(0.01,loc=0.0),</span>
# <span class="sd">              &#39;pca__whiten&#39; : [True,False]}</span>
# <span class="sd">H = RandomizedSearchCV(pipe, parameters, n_iter = 50, verbose = 10)</span>
# <span class="sd">H.fit(Xtr, ytr)</span>
# <span class="sd">print H.score(Xte,yte)</span>
# <span class="sd">print H.score(Xtr,ytr)</span>
# <span class="sd">&#39;&#39;&#39;</span>
# </pre></div>
# 28.
# https://github.com/jasonwbw/tmp_game/tree/master/code/training_tfidf.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">#####################################################################################</span>
#
# <span class="k">print</span> <span class="s1">&#39;Training... &#39;</span>
#
# <span class="c1"># Kappa Scorer </span>
# <span class="n">kappa_scorer</span> <span class="o">=</span> <span class="n">metrics</span><span class="o">.</span><span class="n">make_scorer</span><span class="p">(</span><span class="n">quadratic_weighted_kappa</span><span class="p">,</span> <span class="n">greater_is_better</span><span class="o">=</span><span class="bp">True</span><span class="p">)</span>
#
# <span class="n">lr</span> <span class="o">=</span> <span class="n">LogisticRegression</span><span class="p">(</span><span class="n">penalty</span><span class="o">=</span><span class="s1">&#39;l2&#39;</span><span class="p">,</span> <span class="n">dual</span><span class="o">=</span><span class="bp">True</span><span class="p">,</span> <span class="n">fit_intercept</span><span class="o">=</span><span class="bp">True</span><span class="p">,</span>
# 	<span class="n">intercept_scaling</span><span class="o">=</span><span class="mf">2.0</span><span class="p">,</span> <span class="n">class_weight</span><span class="o">=</span><span class="s1">&#39;auto&#39;</span><span class="p">,</span> <span class="n">random_state</span><span class="o">=</span><span class="mi">1981</span><span class="p">)</span>
# <span class="c1"># Create the pipeline </span>
# <span class="n">clf</span> <span class="o">=</span> <span class="n">pipeline</span><span class="o">.</span><span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;lr&#39;</span><span class="p">,</span> <span class="n">lr</span><span class="p">)])</span>
# <span class="c1"># Create a parameter grid to search for best parameters for everything in the pipeline</span>
# <span class="n">param_grid</span> <span class="o">=</span> <span class="p">{</span><span class="s1">&#39;lr__C&#39;</span> <span class="p">:</span> <span class="p">[</span><span class="mf">0.1</span><span class="p">,</span> <span class="mi">1</span><span class="p">,</span> <span class="mi">10</span><span class="p">],</span> <span class="s1">&#39;lr__tol&#39;</span><span class="p">:</span> <span class="p">[</span><span class="mf">0.0005</span><span class="p">,</span> <span class="mf">0.0001</span><span class="p">,</span> <span class="mf">0.001</span><span class="p">]}</span>
# <span class="c1"># Initialize Grid Search Model</span>
# <span class="n">model</span> <span class="o">=</span> <span class="n">grid_search</span><span class="o">.</span><span class="n">GridSearchCV</span><span class="p">(</span><span class="n">estimator</span> <span class="o">=</span> <span class="n">clf</span><span class="p">,</span> <span class="n">param_grid</span><span class="o">=</span><span class="n">param_grid</span><span class="p">,</span> <span class="n">scoring</span><span class="o">=</span><span class="n">kappa_scorer</span><span class="p">,</span>
# 	<span class="n">verbose</span><span class="o">=</span><span class="mi">10</span><span class="p">,</span> <span class="n">n_jobs</span><span class="o">=-</span><span class="mi">1</span><span class="p">,</span> <span class="n">iid</span><span class="o">=</span><span class="bp">True</span><span class="p">,</span> <span class="n">refit</span><span class="o">=</span><span class="bp">True</span><span class="p">,</span> <span class="n">cv</span><span class="o">=</span><span class="mi">5</span><span class="p">)</span>
# <span class="c1"># Fit Grid Search Model</span>
# <span class="n">model</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="n">y</span><span class="p">)</span>
# <span class="k">print</span><span class="p">(</span><span class="s2">&
# 29.
# https://github.com/Stargrazer82301/CAAPR/tree/master/CAAPR_AstroMagic/PTS/pts/magic/sky/skysubtractor.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="k">def</span> <span class="nf">try_to_interpolate_smart</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">aperture_centers</span><span class="p">,</span> <span class="n">aperture_means</span><span class="p">):</span>
#
#         <span class="sd">&quot;&quot;&quot;</span>
# <span class="sd">        This function ...</span>
# <span class="sd">        :param aperture_centers:</span>
# <span class="sd">        :param aperture_means:</span>
# <span class="sd">        :return:</span>
# <span class="sd">        &quot;&quot;&quot;</span>
#
#         <span class="n">model</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;poly&#39;</span><span class="p">,</span> <span class="n">PolynomialFeatures</span><span class="p">(</span><span class="n">degree</span><span class="o">=</span><span class="mi">3</span><span class="p">)),</span> <span class="p">(</span><span class="s1">&#39;linear&#39;</span><span class="p">,</span> <span class="n">LinearRegression</span><span class="p">(</span><span class="n">fit_intercept</span><span class="o">=</span><span class="bp">False</span><span class="p">))])</span>
#
#         <span class="c1"># fit to an order-3 polynomial data</span>
#         <span class="n">x</span> <span class="o">=</span> <span class="n">np</span><span class="o">.</span><span class="n">arange</span><span class="p">(</span><span class="mi">5</span><span class="p">)</span>
#
#         <span class="n">y</span> <span class="o">=</span> <span class="mi">3</span> <span class="o">-</span> <span class="mi">2</span> <span class="o">*</span> <span class="n">x</span> <span class="o">+</span> <span class="n">x</span> <span class="o">**</span> <span class="mi">2</span> <span class="o">-</span> <span class="n">x</span> <span class="o">**</span> <span class="mi">3</span>
#
#         <span class="n">model</span> <span class="o">=</span> <span class="n">model</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">x</span><span class="p">[:,</span> <span class="n">np</span><span class="o">.</span><span class="n">newaxis</span><span class="p">],</span> <span class="n">y</span><span class="p">)</span>
#
#     <span class="c1"># -----------------------------------------------------------------</span>
# </pre></div>

# %%
rfcContext = getContext("RandomForestClassifier()")

# %%
def prettyPrintPythonCode(code):
    from pygments import highlight
    from pygments.lexers import PythonLexer
    from IPython.display import HTML
    from pygments.formatters import HtmlFormatter
    import IPython

    IPython.display.display(HTML('<style type="text/css">{}</style>{}'.format(
            HtmlFormatter().get_style_defs('.highlight'),
            highlight(code, PythonLexer(), HtmlFormatter()))))

# %%
def prettyPrintContext(context):
    i = 1
    for val, path, repo_name, count in context:
        print("%d."%i,)
        getGithubURL([(repo_name, path)])
        prettyPrintPythonCode(val)
        i +=1
    return

# %% [markdown]
# ### Context for RandomForestClassifier

# %%
prettyPrintContext(rfcContext[1:20])
# Out:
# 1.
# https://github.com/ChristianSch/skml/tree/master/doc/auto_examples/example_br.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="kn">from</span> <span class="nn">sklearn.metrics</span> <span class="kn">import</span> <span class="n">f1_score</span>
# <span class="kn">from</span> <span class="nn">sklearn.metrics</span> <span class="kn">import</span> <span class="n">precision_score</span>
# <span class="kn">from</span> <span class="nn">sklearn.metrics</span> <span class="kn">import</span> <span class="n">recall_score</span>
# <span class="kn">from</span> <span class="nn">sklearn.ensemble</span> <span class="kn">import</span> <span class="n">RandomForestClassifier</span>
# <span class="kn">import</span> <span class="nn">numpy</span> <span class="kn">as</span> <span class="nn">np</span>
#
# <span class="kn">from</span> <span class="nn">skml.problem_transformation</span> <span class="kn">import</span> <span class="n">BinaryRelevance</span>
# <span class="kn">from</span> <span class="nn">skml.datasets</span> <span class="kn">import</span> <span class="n">load_dataset</span>
#
# <span class="n">X</span><span class="p">,</span> <span class="n">y</span> <span class="o">=</span> <span class="n">load_dataset</span><span class="p">(</span><span class="s1">&#39;yeast&#39;</span><span class="p">)</span>
# <span class="n">clf</span> <span class="o">=</span> <span class="n">BinaryRelevance</span><span class="p">(</span><span class="n">RandomForestClassifier</span><span class="p">())</span>
# <span class="n">clf</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="n">np</span><span class="o">.</span><span class="n">array</span><span class="p">(</span><span class="n">y</span><span class="p">))</span>
# <span class="n">y_pred</span> <span class="o">=</span> <span class="n">clf</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">X</span><span class="p">)</span>
#
# <span class="k">print</span> <span class="s2">&quot;hamming loss: &quot;</span>
# <span class="k">print</span> <span class="n">hamming_loss</span><span class="p">(</span><span class="n">y</span><span class="p">,</span> <span class="n">y_pred</span><span class="p">)</span>
#
# <span class="k">print</span> <span class="s2">&quot;accuracy:&quot;</span>
# <span class="k">print</span> <span class="n">accuracy_score</span><span class="p">(</span><span class="n">y</span><span class="p">,</span> <span class="n">y_pred</span><span class="p">)</span>
# </pre></div>
# 2.
# https://github.com/basvandenberg/spice/tree/master/spice/classification.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="k">elif</span><span class="p">(</span><span class="n">classifier_str</span> <span class="o">==</span> <span class="s1">&#39;gnb&#39;</span><span class="p">):</span>
#         <span class="n">cl</span> <span class="o">=</span> <span class="n">naive_bayes</span><span class="o">.</span><span class="n">GaussianNB</span><span class="p">()</span>
#     <span class="k">elif</span><span class="p">(</span><span class="n">classifier_str</span> <span class="o">==</span> <span class="s1">&#39;mnb&#39;</span><span class="p">):</span>
#         <span class="n">cl</span> <span class="o">=</span> <span class="n">naive_bayes</span><span class="o">.</span><span class="n">MultinomialNB</span><span class="p">()</span>
#     <span class="k">elif</span><span class="p">(</span><span class="n">classifier_str</span> <span class="o">==</span> <span class="s1">&#39;bnb&#39;</span><span class="p">):</span>
#         <span class="n">cl</span> <span class="o">=</span> <span class="n">naive_bayes</span><span class="o">.</span><span class="n">BernoulliNB</span><span class="p">()</span>
#     <span class="c1"># Decision tree</span>
#     <span class="k">elif</span><span class="p">(</span><span class="n">classifier_str</span> <span class="o">==</span> <span class="s1">&#39;dtree&#39;</span><span class="p">):</span>
#         <span class="n">cl</span> <span class="o">=</span> <span class="n">tree</span><span class="o">.</span><span class="n">DecisionTreeClassifier</span><span class="p">()</span>
#     <span class="k">elif</span><span class="p">(</span><span class="n">classifier_str</span> <span class="o">==</span> <span class="s1">&#39;rforest&#39;</span><span class="p">):</span>
#         <span class="n">cl</span> <span class="o">=</span> <span class="n">ensemble</span><span class="o">.</span><span class="n">RandomForestClassifier</span><span class="p">()</span>
#     <span class="k">else</span><span class="p">:</span>
#         <span class="c1"># raise error if classifier not found</span>
#         <span class="k">raise</span> <span class="ne">ValueError</span><span class="p">(</span><span class="s1">&#39;Classifier not implemented: </span><span class="si">%s</span><span class="s1">&#39;</span> <span class="o">%</span> <span class="p">(</span><span class="n">classifier_str</span><span class="p">))</span>
#
#     <span class="k">return</span> <span class="p">(</span><span class="n">cl</span><span class="p">)</span>
#
#
# <span class="c1">#if __name__ == &#39;__main__&#39;:</span>
# <span class="c1"># TODO add test run</span>
# </pre></div>
# 3.
# https://github.com/samfu1994/cs838webpage/tree/master/code/train_and_test.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>	<span class="n">test_data</span> <span class="o">=</span> <span class="n">test_data</span><span class="p">[</span><span class="mi">1</span><span class="p">:]</span>
# 	<span class="k">for</span> <span class="n">instance</span> <span class="ow">in</span> <span class="n">test_data</span><span class="p">:</span>
# 		<span class="n">instance</span><span class="p">[</span><span class="mi">3</span><span class="p">]</span> <span class="o">=</span> <span class="nb">int</span><span class="p">(</span><span class="n">instance</span><span class="p">[</span><span class="mi">3</span><span class="p">])</span>
#
# 	<span class="c1">#start train with SVM</span>
# 	<span class="k">if</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;SVM&#39;</span><span class="p">:</span>
# 		<span class="n">clf</span> <span class="o">=</span> <span class="n">svm</span><span class="o">.</span><span class="n">SVC</span><span class="p">()</span>
# 	<span class="k">if</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;decision_tree&#39;</span><span class="p">:</span>
# 		<span class="n">clf</span> <span class="o">=</span> <span class="n">tree</span><span class="o">.</span><span class="n">DecisionTreeClassifier</span><span class="p">()</span>
# 	<span class="k">if</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;random_forest&#39;</span><span class="p">:</span>
# 		<span class="n">clf</span> <span class="o">=</span> <span class="n">RandomForestClassifier</span><span class="p">()</span>
# 	<span class="k">if</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;logistic_regression&#39;</span><span class="p">:</span>
# 		<span class="n">clf</span> <span class="o">=</span> <span class="n">LogisticRegression</span><span class="p">()</span>
# 	<span class="k">if</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;linear_regression&#39;</span> <span class="ow">or</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;neural_net&#39;</span><span class="p">:</span>
# 		<span class="k">if</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;linear_regression&#39;</span><span class="p">:</span>
# 			<span class="n">clf</span> <span class="o">=</span> <span class="n">LinearRegression</span><span class="p">()</span>
# 		<span class="k">elif</span> <span class="n">model_name</span> <span class="o">==</span> <span class="s1">&#39;neural_net&#39;</span><span class="p">:</span>
# 			<span class="n">clf</span> <span class="o">=</span> <span class="n">MLPClassifier</span><span class="p">(</span><span class="n">solver</span><span class="o">=</span><span class="s1">&#39;lbfgs&#39;</span><span class="p">,</span> <span class="n">alpha</span><span class="o">=</span><span class="mf">1e-5</span><span class="p">,</span> <span class="n">hidden_layer_sizes</span><span class="o">=</span><span class="p">(</span><span class="mi">15</span><span class="p">,),</span> <span class="n">random_state</span><span class="o">=</span><span class="mi">1</span><span class="p">)</span>
# 		<span class="k">for</span> <span class="n">instance</span> <span class="ow">in</span> <span class="n">train_data</span><span class="p">:</span>
# 			<span class="k">for</span> <span class="n">feature_idx</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="nb">len</span><span class="p">(</span><span class="n">train_data</span><span class="p">[</span><span class="mi">0</span><span class="p">])):</span>
# </pre></div>
# 4.
# https://github.com/slimn/Data-Analyst/tree/master/P5-Identify Fraud from Enron Email/poi_id.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">### http://scikit-learn.org/stable/modules/pipeline.html</span>
#
# <span class="c1">### Convert pandas datafram to dictionary</span>
# <span class="n">tmp_df</span> <span class="o">=</span> <span class="n">enrondf</span><span class="o">.</span><span class="n">T</span>
# <span class="n">data_dict</span> <span class="o">=</span> <span class="n">tmp_df</span><span class="o">.</span><span class="n">to_dict</span><span class="p">()</span>
#
# <span class="c1">### Construct a simple classifiers to validate features set. </span>
# <span class="n">clf_cv</span> <span class="o">=</span> <span class="p">{}</span>
# <span class="n">clf_cv</span><span class="p">[</span><span class="s1">&#39;Naive Bayes&#39;</span><span class="p">]</span>   <span class="o">=</span> <span class="n">GaussianNB</span><span class="p">()</span>
# <span class="n">clf_cv</span><span class="p">[</span><span class="s1">&#39;Decision Tree&#39;</span><span class="p">]</span> <span class="o">=</span> <span class="n">DecisionTreeClassifier</span><span class="p">()</span>
# <span class="n">clf_cv</span><span class="p">[</span><span class="s1">&#39;Random Forest&#39;</span><span class="p">]</span> <span class="o">=</span> <span class="n">RandomForestClassifier</span><span class="p">()</span>
# <span class="n">clf_cv</span><span class="p">[</span><span class="s1">&#39;AdaBoost&#39;</span><span class="p">]</span>      <span class="o">=</span> <span class="n">AdaBoostClassifier</span><span class="p">()</span>
#
# <span class="c1">### validate features selection</span>
# <span class="n">validate_features</span> <span class="o">=</span> <span class="n">fin_features</span> <span class="o">+</span> <span class="n">email_features</span> <span class="o">+</span> <span class="n">new_features_list</span>
# <span class="c1">### TODO : uncomment to check log</span>
# <span class="sd">&#39;&#39;&#39;</span>
# <span class="sd">fcv_score = validateFeaturesSelection(data_dict, validate_features, clf_cv)</span>
# <span class="sd">&#39;&#39;&#39;</span>
# <span class="s1">&#39;&#39;&#39;</span>
# </pre></div>
# 5.
# https://github.com/Valay/cifar-10/tree/master/example/random_forest.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">#regression = linear_model.LinearRegression()</span>
# <span class="c1">#regression.fit(x,y)</span>
#
# <span class="c1"># fit a curve</span>
# <span class="c1"># curve = np.polyfit(x,y,10)</span>
# <span class="c1"># xfit = np.linspace(-10, 120, 100)</span>
# <span class="c1"># yfit = np.log(xfit)</span>
#
# <span class="c1"># Training</span>
# <span class="n">x</span> <span class="o">=</span> <span class="n">np</span><span class="o">.</span><span class="n">reshape</span><span class="p">(</span><span class="n">x</span><span class="p">,(</span><span class="mi">1000</span><span class="p">,</span><span class="mi">1</span><span class="p">))</span>
# <span class="n">rf</span> <span class="o">=</span> <span class="n">RandomForestClassifier</span><span class="p">()</span>
# <span class="n">rf</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">x</span><span class="p">,</span> <span class="n">y</span><span class="p">)</span>
#
# <span class="c1"># Testing</span>
# <span class="n">xfit</span> <span class="o">=</span> <span class="n">np</span><span class="o">.</span><span class="n">linspace</span><span class="p">(</span><span class="o">-</span><span class="mi">10</span><span class="p">,</span> <span class="mi">120</span><span class="p">,</span> <span class="mi">1000</span><span class="p">)</span>
# <span class="n">a</span><span class="p">,</span> <span class="o">=</span> <span class="n">xfit</span><span class="o">.</span><span class="n">shape</span>
# <span class="n">xfit</span> <span class="o">=</span> <span class="n">np</span><span class="o">.</span><span class="n">reshape</span><span class="p">(</span><span class="n">xfit</span><span class="p">,(</span><span class="n">a</span><span class="p">,</span><span class="mi">1</span><span class="p">))</span>
# <span class="n">yfit</span> <span class="o">=</span> <span class="n">rf</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">xfit</span><span class="p">)</span>
#
# <span class="n">plt</span><span class="o">.</span><span class="n">scatter</span><span class="p">(</span><span class="n">xfit</span><span class="p">,</span><span class="n">yfit</span><span class="p">)</span>
# </pre></div>
# 6.
# https://github.com/ricsoncheng/sarcasm_machine/tree/master/baseline.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="k">print</span> <span class="n">getf1</span><span class="p">(</span><span class="n">L</span><span class="p">,</span> <span class="n">Xte</span><span class="p">,</span> <span class="n">yte</span><span class="p">)</span>
#
# <span class="k">print</span> <span class="s1">&#39;svm&#39;</span>
# <span class="n">S</span> <span class="o">=</span> <span class="n">SVC</span><span class="p">(</span><span class="n">C</span> <span class="o">=</span> <span class="mf">0.1</span><span class="p">)</span>
# <span class="n">S</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">Xtr</span><span class="p">,</span><span class="n">ytr</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">S</span><span class="o">.</span><span class="n">score</span><span class="p">(</span><span class="n">Xte</span><span class="p">,</span><span class="n">yte</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">S</span><span class="o">.</span><span class="n">score</span><span class="p">(</span><span class="n">Xtr</span><span class="p">,</span><span class="n">ytr</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">getf1</span><span class="p">(</span><span class="n">S</span><span class="p">,</span> <span class="n">Xte</span><span class="p">,</span> <span class="n">yte</span><span class="p">)</span>
#
# <span class="k">print</span> <span class="s1">&#39;forest&#39;</span>
# <span class="n">R</span> <span class="o">=</span> <span class="n">RandomForestClassifier</span><span class="p">()</span>
# <span class="n">R</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">Xtr</span><span class="p">,</span><span class="n">ytr</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">R</span><span class="o">.</span><span class="n">score</span><span class="p">(</span><span class="n">Xte</span><span class="p">,</span><span class="n">yte</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">R</span><span class="o">.</span><span class="n">score</span><span class="p">(</span><span class="n">Xtr</span><span class="p">,</span><span class="n">ytr</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">getf1</span><span class="p">(</span><span class="n">R</span><span class="p">,</span> <span class="n">Xte</span><span class="p">,</span> <span class="n">yte</span><span class="p">)</span>
#
# <span class="k">print</span> <span class="s1">&#39;knn&#39;</span>
# <span class="n">K</span> <span class="o">=</span> <span class="n">KNeighborsClassifier</span><span class="p">(</span><span class="mi">9</span><span class="p">)</span>
# <span class="n">K</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">Xtr</span><span class="p">,</span><span class="n">ytr</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">K</span><span class="o">.</span><span class="n">score</span><span class="p">(</span><span class="n">Xte</span><span class="p">,</span><span class="n">yte</span><span class="p">)</span>
# </pre></div>
# 7.
# https://github.com/neilpat1995/IMDb-Movie-Rating-Predictor/tree/master/random_forests.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">#cv_int = ShuffleSplit(n_splits=3, test_size=TESTING_SET_DECIMAL, random_state=0)</span>
#
#
# <span class="sd">&#39;&#39;&#39;</span>
# <span class="sd">GridSearchCV implementation-&gt; 38.6-39%</span>
# <span class="sd">&#39;&#39;&#39;</span>
#
# <span class="sd">&#39;&#39;&#39;</span>
#
# <span class="sd">parameters = {&#39;n_estimators&#39;:[n for n in range(25,46,5)], &#39;min_samples_split&#39;:[m for m in range(3,8) if m != 5]}</span>
# <span class="sd">rf_grid_model = RandomForestClassifier()</span>
# <span class="sd">rf_best_grid_model = GridSearchCV(rf_grid_model, parameters)</span>
# <span class="sd">rf_best_grid_model.fit(train_movies_X, train_movies_Y)</span>
# <span class="sd">print(&#39;Prediction accuracy for GridSearchCV optimum model: %.3f&#39; %rf_best_grid_model.score(test_movies_X, test_movies_Y))</span>
#
# <span class="sd">&#39;&#39;&#39;</span>
#
# <span class="n">best_model</span> <span class="o">=</span> <span class="bp">None</span>	<span class="c1"># Maintain a model and score for the best fold</span>
# <span class="n">best_score</span> <span class="o">=</span> <span class="mf">0.0</span>
# <span class="s1">&#39;&#39;&#39;</span>
# </pre></div>
# 8.
# https://github.com/reiinakano/scikit-plot/tree/master/examples/plot_feature_importances.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# ...
#
#     <span class="c1"># Fit trained model</span>
#     <span class="n">model</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">dataset</span><span class="p">)</span>
#     <span class="n">model</span><span class="o">.</span><span class="n">save</span><span class="p">()</span>
#
#     <span class="c1"># Eval model on train</span>
#     <span class="n">scores</span> <span class="o">=</span> <span class="n">model</span><span class="o">.</span><span class="n">evaluate</span><span class="p">(</span><span class="n">dataset</span><span class="p">,</span> <span class="p">[</span><span class="n">classification_metric</span><span class="p">])</span>
#     <span class="k">assert</span> <span class="n">scores</span><span class="p">[</span><span class="n">classification_metric</span><span class="o">.</span><span class="n">name</span><span class="p">]</span> <span class="o">&gt;</span> <span class="o">.</span><span class="mi">9</span>
# </pre></div>
# 18.
# https://github.com/afoss925/kaggle_schizophrenia_2014/tree/master/make_benchmarks.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="k">if</span> <span class="n">__name__</span> <span class="o">==</span> <span class="s2">&quot;__main__&quot;</span><span class="p">:</span>
#     <span class="n">ids</span><span class="p">,</span> <span class="n">data</span><span class="p">,</span> <span class="n">labels</span> <span class="o">=</span> <span class="n">load_data</span><span class="p">()</span>
#     <span class="n">evaluate</span><span class="p">(</span><span class="n">data</span><span class="p">,</span><span class="n">labels</span><span class="p">)</span>
#
# <span class="n">OTHER_CLASSIFEIRS_TO_TRY</span> <span class="o">=</span> <span class="p">[</span>
#     <span class="n">naive_bayes</span><span class="o">.</span><span class="n">GaussianNB</span><span class="p">(),</span>
#     <span class="n">naive_bayes</span><span class="o">.</span><span class="n">BernoulliNB</span><span class="p">(),</span>
#     <span class="n">Pipeline</span><span class="p">([(</span><span class="s2">&quot;normalize&quot;</span><span class="p">,</span> <span class="n">StandardScaler</span><span class="p">()),</span>
#               <span class="p">(</span><span class="s2">&quot;svm&quot;</span><span class="p">,</span><span class="n">svm</span><span class="o">.</span><span class="n">SVC</span><span class="p">()),]),</span>
#     <span class="n">svm</span><span class="o">.</span><span class="n">LinearSVC</span><span class="p">(),</span>
#     <span class="n">RandomForestClassifier</span><span class="p">(),</span>
#     <span class="n">AdaBoostClassifier</span><span class="p">(),</span>
#     <span class="c1"># # LinearRegression(),</span>
#     <span class="n">LogisticRegression</span><span class="p">(),</span>
#     <span class="n">GIVEN_OPT</span><span class="p">,</span>
#     <span class="n">KNeighborsClassifier</span><span class="p">(),</span>
#     <span class="n">DecisionTreeClassifier</span><span class="p">(),</span>
#     <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;linear_svm&#39;</span><span class="p">,</span><span class="n">svm</span><span class="o">.</span><span class="n">LinearSVC</span><span class="p">()),</span>
#               <span class="p">(</span><span class="s1">&#39;bernoulli&#39;</span><span class="p">,</span><span class="n">naive_bayes</span><span class="o">.</span><span class="n">BernoulliNB</span><span class="p">())]),</span>
#     <span class="n">Pipeline</span><span class="p">([(</span><span class="s2">&quot;rfe_svm&quot;</span><span class="p">,</span>
# </pre></div>
# 19.
# https://github.com/georgetown-analytics/housing-risk/tree/master/code/prediction/run_models.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="c1">##################################################</span>
#     <span class="c1">#Attach our unfitted model instances to the ManyModels instance</span>
#     <span class="kn">from</span> <span class="nn">sklearn.neighbors</span> <span class="kn">import</span> <span class="n">KNeighborsClassifier</span>
#     <span class="kn">from</span> <span class="nn">sklearn.ensemble</span> <span class="kn">import</span> <span class="n">RandomForestClassifier</span>
#     <span class="kn">from</span> <span class="nn">sklearn.linear_model</span> <span class="kn">import</span> <span class="n">LogisticRegression</span>
#     <span class="kn">from</span> <span class="nn">sklearn.naive_bayes</span> <span class="kn">import</span> <span class="n">GaussianNB</span>
#     <span class="kn">from</span> <span class="nn">sklearn.svm</span> <span class="kn">import</span> <span class="n">SVC</span>
#
#
#     <span class="n">modeler</span><span class="o">.</span><span class="n">models</span> <span class="o">=</span> <span class="p">{</span>    <span class="s2">&quot;KNeighbors_default&quot;</span><span class="p">:</span> <span class="n">sklearn</span><span class="o">.</span><span class="n">neighbors</span><span class="o">.</span><span class="n">KNeighborsClassifier</span><span class="p">()</span>
#                       <span class="p">,</span> <span class="s2">&quot;RandomForest&quot;</span><span class="p">:</span> <span class="n">sklearn</span><span class="o">.</span><span class="n">ensemble</span><span class="o">.</span><span class="n">RandomForestClassifier</span><span class="p">()</span>
#                       <span class="p">,</span> <span class="s2">&quot;LogisticRegression&quot;</span><span class="p">:</span> <span class="n">sklearn</span><span class="o">.</span><span class="n">linear_model</span><span class="o">.</span><span class="n">LogisticRegression</span><span class="p">(</span><span class="n">penalty</span><span class="o">=</span><span class="s1">&#39;l1&#39;</span><span class="p">,</span> <span class="n">C</span><span class="o">=</span><span class="mf">0.1</span><span class="p">)</span>
#                       <span class="p">,</span> <span class="s2">&quot;GaussianNB&quot;</span><span class="p">:</span> <span class="n">GaussianNB</span><span class="p">()</span>
#                       <span class="p">,</span> <span class="s2">&quot;SVC_rbf&quot;</span><span class="p">:</span> <span class="n">SVC</span><span class="p">(</span><span class="n">kernel</span> <span class="o">=</span> <span class="s1">&#39;rbf&#39;</span><span class="p">,</span> <span class="n">probability</span> <span class="o">=</span> <span class="bp">True</span><span class="p">,</span> <span class="n">random_state</span> <span class="o">=</span> <span class="mi">0</span><span class="p">)</span>
#                       <span class="p">,</span> <span class="s2">&quot;SVC_linear&quot;</span><span class="p">:</span> <span class="n">SVC</span><span class="p">(</span><span class="n">kernel</span> <span class="o">=</span> <span class="s1">&#39;linear&#39;</span><span class="p">,</span> <span class="n">probability</span> <span class="o">=</span> <span class="bp">True</span><span class="p">,</span>  <span class="n">random_state</span> <span class="o">=</span> <span class="mi">0</span><span class="p">)</span>
#                       <span class="p">,</span> <span class="s2">&quot;SVC_poly&quot;</span><span class="p">:</span> <span class="n">SVC</span><span class="p">(</span><span class="n">kernel</span> <span class="o">=</span> <span class="s1">&#39;poly&#39;</span><span class="p">,</span> <span class="n">degree</span> <span class="o">=</span> <span class="mi">3</span><span class="p">,</span> <span class="n">probability</span> <span class="o">=</span> <span class="bp">True</span><span class="p">,

# %% [markdown]
# ### Context for SVC

# %%
prettyPrintContext(getContext("SVC()")[1:20])
# Out:
# 1.
# https://github.com/KellyChan/Kaggle/tree/master/kaggle-digit-recognizer/src/classify.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">loadData</span><span class="p">(</span><span class="n">datafile</span><span class="p">):</span>
#     <span class="k">return</span> <span class="n">pd</span><span class="o">.</span><span class="n">read_csv</span><span class="p">(</span><span class="n">datafile</span><span class="p">)</span>
#
# <span class="k">def</span> <span class="nf">decomPCA</span><span class="p">(</span><span class="n">train</span><span class="p">,</span> <span class="n">test</span><span class="p">):</span>
#     <span class="n">pca</span> <span class="o">=</span> <span class="n">decomposition</span><span class="o">.</span><span class="n">PCA</span><span class="p">(</span><span class="n">n_components</span><span class="o">=</span><span class="mi">256</span><span class="p">,</span> <span class="n">whiten</span><span class="o">=</span><span class="bp">True</span><span class="p">)</span>
#     <span class="n">train</span> <span class="o">=</span> <span class="n">pca</span><span class="o">.</span><span class="n">fit_transform</span><span class="p">(</span><span class="n">train</span><span class="p">)</span>
#     <span class="n">test</span> <span class="o">=</span> <span class="n">pca</span><span class="o">.</span><span class="n">transform</span><span class="p">(</span><span class="n">test</span><span class="p">)</span>
#     <span class="k">return</span> <span class="n">train</span><span class="p">,</span> <span class="n">test</span>
#
# <span class="k">def</span> <span class="nf">createSVM</span><span class="p">():</span>
#     <span class="n">clf</span> <span class="o">=</span> <span class="n">SVC</span><span class="p">()</span>
#     <span class="k">return</span> <span class="n">clf</span>
#
# <span class="k">def</span> <span class="nf">createKNN</span><span class="p">():</span>
#     <span class="n">clf</span> <span class="o">=</span> <span class="n">KNeighborsClassifier</span><span class="p">(</span><span class="n">n_neighbors</span><span class="o">=</span><span class="mi">13</span><span class="p">,</span><span class="n">algorithm</span><span class="o">=</span><span class="s1">&#39;kd_tree&#39;</span><span class="p">,</span><span class="n">weights</span><span class="o">=</span><span class="s1">&#39;uniform&#39;</span><span class="p">,</span><span class="n">p</span><span class="o">=</span><span class="mi">1</span><span class="p">)</span>
#     <span class="k">return</span> <span class="n">clf</span>
#
# <span class="k">def</span> <span class="nf">createDecisionTree</span><span class="p">():</span>
#     <span class="n">clf</span> <span class="o">=</span> <span class="n">DecisionTreeClassifier</span><span class="p">(</span><span class="n">max_depth</span><span class="o">=</span><span class="bp">None</span><span class="p">,</span> <span class="n">min_samples_split</span><span class="o">=</span><span class="mi">1</span><span class="p">,</span> <span class="n">random_state</span><span class="o">=</span><span class="mi">0</span><span class="p">)</span>
#     <span class="k">return</span> <span class="n">clf</span>
# </pre></div>
# 2.
# https://github.com/chkoar/imbalanced-learn/tree/master/imblearn/tests/test_pipeline.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>                      <span class="o">**</span><span class="n">pipe</span><span class="o">.</span><span class="n">get_params</span><span class="p">(</span><span class="n">deep</span><span class="o">=</span><span class="bp">False</span><span class="p">)))</span>
#
#     <span class="c1"># Check that params are set</span>
#     <span class="n">pipe</span><span class="o">.</span><span class="n">set_params</span><span class="p">(</span><span class="n">svc__a</span><span class="o">=</span><span class="mf">0.1</span><span class="p">)</span>
#     <span class="n">assert_equal</span><span class="p">(</span><span class="n">clf</span><span class="o">.</span><span class="n">a</span><span class="p">,</span> <span class="mf">0.1</span><span class="p">)</span>
#     <span class="n">assert_equal</span><span class="p">(</span><span class="n">clf</span><span class="o">.</span><span class="n">b</span><span class="p">,</span> <span class="bp">None</span><span class="p">)</span>
#     <span class="c1"># Smoke test the repr:</span>
#     <span class="nb">repr</span><span class="p">(</span><span class="n">pipe</span><span class="p">)</span>
#
#     <span class="c1"># Test with two objects</span>
#     <span class="n">clf</span> <span class="o">=</span> <span class="n">SVC</span><span class="p">()</span>
#     <span class="n">filter1</span> <span class="o">=</span> <span class="n">SelectKBest</span><span class="p">(</span><span class="n">f_classif</span><span class="p">)</span>
#     <span class="n">pipe</span> <span class="o">=</span> <span class="n">Pipeline</span><span class="p">([(</span><span class="s1">&#39;anova&#39;</span><span class="p">,</span> <span class="n">filter1</span><span class="p">),</span> <span class="p">(</span><span class="s1">&#39;svc&#39;</span><span class="p">,</span> <span class="n">clf</span><span class="p">)])</span>
#
#     <span class="c1"># Check that we can&#39;t instantiate with non-transformers on the way</span>
#     <span class="c1"># Note that NoTrans implements fit, but not transform</span>
#     <span class="n">assert_raises_regex</span><span class="p">(</span><span class="ne">TypeError</span><span class="p">,</span>
#                         <span class="s1">&#39;implement fit and transform or sample&#39;</span><span class="p">,</span>
#                         <span class="n">Pipeline</span><span class="p">,</span> <span class="p">[(</span><span class="s1">&#39;t&#39;</span><span class="p">,</span> <span class="n">NoTrans</span><span class="p">()),</span> <span class="p">(</span><span class="s1">&#39;svc&#39;</span><span class="p">,</span> <span class="n">clf</span><span class="p">)])</span>
# </pre></div>
# 3.
# https://github.com/zhangmianhongni/MyPractice/tree/master/Python/MachineLearning/A Dream in Red Mansions/test.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="k">print</span> <span class="nb">len</span><span class="p">(</span><span class="n">trainDfE</span><span class="p">[</span><span class="s1">u&#39;如今&#39;</span><span class="p">])</span>
# <span class="n">trainTargetE</span> <span class="o">=</span> <span class="p">[</span><span class="mi">1</span> <span class="k">for</span> <span class="n">i</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="mi">15</span><span class="p">)]</span>
# <span class="k">print</span> <span class="n">trainTargetE</span>
#
# <span class="n">trainDf</span> <span class="o">=</span> <span class="n">pd</span><span class="o">.</span><span class="n">concat</span><span class="p">([</span><span class="n">trainDfF</span><span class="p">,</span> <span class="n">trainDfE</span><span class="p">])</span>
# <span class="n">trainTargetF</span><span class="o">.</span><span class="n">extend</span><span class="p">(</span><span class="n">trainTargetE</span><span class="p">)</span>
#
# <span class="k">print</span> <span class="nb">len</span><span class="p">(</span><span class="n">trainDf</span><span class="p">[</span><span class="s1">u&#39;如今&#39;</span><span class="p">])</span>
# <span class="k">print</span> <span class="n">trainTargetF</span>
#
# <span class="n">clf</span> <span class="o">=</span> <span class="n">svm</span><span class="o">.</span><span class="n">LinearSVC</span><span class="p">()</span>
# <span class="n">clf</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">trainDf</span><span class="p">,</span> <span class="n">trainTargetF</span><span class="p">)</span>
#
# <span class="n">predict</span> <span class="o">=</span> <span class="n">clf</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">df</span><span class="p">)</span>
# <span class="k">print</span> <span class="n">predict</span>
# </pre></div>
# 4.
# https://github.com/qwertzdenek/mtagger/tree/master/classifier.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>        <span class="n">cls</span> <span class="o">=</span> <span class="nb">int</span><span class="p">(</span><span class="n">stats</span><span class="o">.</span><span class="n">mode</span><span class="p">(</span><span class="n">res</span><span class="p">)[</span><span class="mi">0</span><span class="p">])</span>
#         <span class="n">callback</span><span class="p">(</span><span class="n">row</span><span class="p">,</span> <span class="n">Classifier</span><span class="o">.</span><span class="n">CLASSIFIED</span><span class="p">,</span> <span class="n">cls</span><span class="p">)</span>
#
#     <span class="k">def</span> <span class="nf">new_training</span><span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="n">y</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;reads training vector and fits new hypothesis</span>
# <span class="sd">        :param X: training vector</span>
# <span class="sd">        :param y: target vector (classes)</span>
# <span class="sd">        :returns: True on success and False afterwards</span>
# <span class="sd">        &quot;&quot;&quot;</span>
#         <span class="n">clf</span> <span class="o">=</span> <span class="n">svm</span><span class="o">.</span><span class="n">SVC</span><span class="p">()</span>
#         <span class="n">param_grid</span> <span class="o">=</span> <span class="p">{</span><span class="s1">&#39;C&#39;</span><span class="p">:</span> <span class="p">[</span><span class="mf">0.5</span><span class="p">,</span> <span class="mi">5</span><span class="p">,</span> <span class="mi">50</span><span class="p">,</span> <span class="mi">500</span><span class="p">],</span> <span class="s1">&#39;gamma&#39;</span><span class="p">:</span> <span class="p">[</span><span class="mf">0.001</span><span class="p">,</span> <span class="mf">0.0001</span><span class="p">],</span> <span class="s1">&#39;kernel&#39;</span><span class="p">:</span> <span class="p">[</span><span class="s1">&#39;rbf&#39;</span><span class="p">]}</span>
#         <span class="n">Classifier</span><span class="o">.</span><span class="n">clf</span> <span class="o">=</span> <span class="n">grid_search</span><span class="o">.</span><span class="n">GridSearchCV</span><span class="p">(</span><span class="n">clf</span><span class="p">,</span> <span class="n">param_grid</span><span class="p">,</span> <span class="n">n_jobs</span><span class="o">=</span><span class="n">os</span><span class="o">.</span><span class="n">cpu_count</span><span class="p">())</span>
#         <span class="k">try</span><span class="p">:</span>
#             <span class="n">Classifier</span><span class="o">.</span><span class="n">clf</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X</span><span class="p">,</span> <span class="n">y</span><span class="p">)</span>
#         <span class="k">except</span> <span class="ne">ValueError</span> <span class="k">as</span> <span class="n">e</span><span class="p">:</span>
#             <span class="k">return</span> <span class="bp">False</span><span class="p">;</span>
#         <span class="n">Classifier</span><span class="o">.</span><span class="n">learned</span> <span class="o">=</span> <span class="bp">True</span>
#         <span class="k">return</span> <span class="bp">True</span>
# </pre></div>
# 5.
# https://github.com/ElvisLouis/code/tree/master/work/ML/tensorflow/separa/tool.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>			<span class="k">else</span><span class="p">:</span>
# 				<span class="n">train_data</span><span class="p">[</span><span class="n">count_train</span><span class="p">]</span> <span class="o">=</span> <span class="n">data</span><span class="p">[</span><span class="n">x</span><span class="p">]</span>
# 				<span class="n">train_label</span><span class="p">[</span><span class="n">count_train</span><span class="p">]</span> <span class="o">=</span> <span class="n">label</span><span class="p">[</span><span class="n">x</span><span class="p">]</span>
# 				<span class="n">count_train</span> <span class="o">+=</span> <span class="mi">1</span>
#
# 		<span class="k">if</span> <span class="n">count_eval</span> <span class="o">!=</span> <span class="n">size_sample</span><span class="p">:</span>
# 			<span class="k">print</span> <span class="p">(</span><span class="s2">&quot;ATTENTION FOR INT&quot;</span><span class="p">)</span>
# 		<span class="k">return</span> <span class="n">train_data</span><span class="p">,</span> <span class="n">train_label</span><span class="p">,</span> <span class="n">eval_data</span><span class="p">,</span> <span class="n">eval_label</span>
#
# 	<span class="k">def</span> <span class="nf">svm_train</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">data</span><span class="p">,</span> <span class="n">label</span><span class="p">):</span>
# 		<span class="n">clf</span> <span class="o">=</span> <span class="n">svm</span><span class="o">.</span><span class="n">SVC</span><span class="p">()</span>
# 		<span class="k">print</span> <span class="p">(</span><span class="s2">&quot;training&quot;</span><span class="p">)</span>
# 		<span class="n">clf</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">data</span><span class="p">,</span> <span class="n">label</span><span class="p">)</span>
# 		<span class="k">print</span> <span class="p">(</span><span class="s2">&quot;done&quot;</span><span class="p">)</span>
# 		<span class="k">return</span> <span class="n">clf</span>
#
# 	<span class="k">def</span> <span class="nf">svm_predict</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">clf</span><span class="p">,</span> <span class="n">data</span><span class="p">):</span>
# 		<span class="n">result</span> <span class="o">=</span> <span class="n">clf</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">data</span><span class="p">)</span>
# 		<span class="k">return</span> <span class="n">result</span>
# </pre></div>
# 6.
# https://github.com/kaylanb/SkinApp/tree/master/machine_learn/HOG/calc_stats_for_HogMethod.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>        <span class="n">stats</span><span class="o">.</span><span class="n">N</span><span class="p">[</span><span class="n">n</span><span class="p">]</span> <span class="o">=</span> <span class="nb">len</span><span class="p">(</span><span class="n">Food_df</span><span class="p">[</span><span class="n">cTestF</span><span class="p">])</span>
#
#         <span class="n">forest2</span> <span class="o">=</span> <span class="n">ExtraTreesClassifier</span><span class="p">(</span><span class="n">n_estimators</span><span class="o">=</span><span class="mi">50</span><span class="p">,</span> <span class="n">max_depth</span><span class="o">=</span><span class="bp">None</span><span class="p">,</span> <span class="n">min_samples_split</span><span class="o">=</span><span class="mi">1</span><span class="p">,</span> <span class="n">random_state</span><span class="o">=</span><span class="mi">0</span><span class="p">)</span>
#         <span class="n">forest2</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">TrainX</span><span class="p">,</span><span class="n">TrainY</span><span class="p">)</span>
#         <span class="n">forestOut2</span> <span class="o">=</span> <span class="n">forest2</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">TestX</span><span class="p">)</span>
#         <span class="n">stats</span><span class="o">.</span><span class="n">ET</span><span class="o">.</span><span class="n">TP</span><span class="p">[</span><span class="n">n</span><span class="p">]</span> <span class="o">=</span> <span class="nb">sum</span><span class="p">(</span><span class="n">forestOut2</span><span class="p">[</span><span class="mi">0</span><span class="p">:</span><span class="n">stats</span><span class="o">.</span><span class="n">P</span><span class="p">[</span><span class="n">n</span><span class="p">]]</span> <span class="o">==</span> <span class="n">TestY</span><span class="p">[</span><span class="mi">0</span><span class="p">:</span><span class="n">stats</span><span class="o">.</span><span class="n">P</span><span class="p">[</span><span class="n">n</span><span class="p">]])</span>
#         <span class="n">stats</span><span class="o">.</span><span class="n">ET</span><span class="o">.</span><span class="n">TN</span><span class="p">[</span><span class="n">n</span><span class="p">]</span> <span class="o">=</span> <span class="nb">sum</span><span class="p">(</span><span class="n">forestOut2</span><span class="p">[</span><span class="n">stats</span><span class="o">.</span><span class="n">P</span><span class="p">[</span><span class="n">n</span><span class="p">]</span><span class="o">+</span><span class="mi">1</span><span class="p">:]</span> <span class="o">==</span> <span class="n">TestY</span><span class="p">[</span><span class="n">stats</span><span class="o">.</span><span class="n">P</span><span class="p">[</span><span class="n">n</span><span class="p">]</span><span class="o">+</span><span class="mi">1</span><span class="p">:])</span>
#         <span class="n">stats</span><span class="o">.</span><span class="n">ET</span><span class="o">.</span><span class="n">FP</span><span class="p">[</span><span class="n">n</span><span class="p">]</span> <span class="o">=</span> <span class="n">stats</span><span class="o">.</span><span class="n">N</span><span class="p">[</span><span class="n">n</span><span class="p">]</span> <span class="o">-</span> <span class="n">stats</span><span class="o">.</span><span class="n">ET</span><span class="o">.</span><span class="n">TN</span><span class="p">[</span><span class="n">n</span><span class="p">]</span>
#         <span class="n">stats</span><span class="o">.</span><span class="n">ET</span><span class="o">.</span><span class="n">F
# 7.
# https://github.com/chrisjdavie/shares/tree/master/machine_learning/teaching_try1.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="kn">from</span> <span class="nn">sklearn.cross_validation</span> <span class="kn">import</span> <span class="n">train_test_split</span>
#     <span class="n">news_train</span><span class="p">,</span> <span class="n">news_test</span><span class="p">,</span> <span class="n">y_train</span><span class="p">,</span> <span class="n">y_test</span> <span class="o">=</span> <span class="n">train_test_split</span><span class="p">(</span>
# ...
#         <span class="n">cm</span> <span class="o">=</span> <span class="n">np</span><span class="o">.</span><span class="n">zeros</span><span class="p">((</span><span class="mi">2</span><span class="p">,</span><span class="mi">2</span><span class="p">))</span>
#         <span class="k">for</span> <span class="n">p</span><span class="p">,</span><span class="n">t</span> <span class="ow">in</span> <span class="nb">zip</span>
# 18.
# https://github.com/tmills/uda/tree/master/scripts/eval_bootstrap.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>    <span class="c1">## C &lt; 1 =&gt; more regularization</span>
#     <span class="c1">## C &gt; 1 =&gt; more fitting to training</span>
#     <span class="n">C_list</span> <span class="o">=</span> <span class="p">[</span><span class="mf">0.001</span><span class="p">,</span> <span class="mf">0.01</span><span class="p">,</span> <span class="mf">0.1</span><span class="p">,</span> <span class="mf">1.0</span><span class="p">,</span> <span class="mf">10.0</span><span class="p">]</span>
#     <span class="p">(</span><span class="n">l1_c</span><span class="p">,</span> <span class="n">l1_f1</span><span class="p">)</span> <span class="o">=</span> <span class="n">find_best_c</span><span class="p">(</span><span class="n">X_train</span><span class="p">,</span> <span class="n">y_train</span><span class="p">,</span> <span class="n">goal_ind</span><span class="p">,</span> <span class="n">penalty</span><span class="o">=</span><span class="s1">&#39;l1&#39;</span><span class="p">,</span> <span class="n">dual</span><span class="o">=</span><span class="bp">False</span><span class="p">)</span>
#     <span class="k">print</span><span class="p">(</span><span class="s2">&quot;Optimizing l1 with cross-validation gives C=</span><span class="si">%f</span><span class="s2"> and f1=</span><span class="si">%f</span><span class="s2">&quot;</span> <span class="o">%</span> <span class="p">(</span><span class="n">l1_c</span><span class="p">,</span> <span class="n">l1_f1</span><span class="p">))</span>
#     <span class="p">(</span><span class="n">l2_c</span><span class="p">,</span> <span class="n">l2_f1</span><span class="p">)</span> <span class="o">=</span> <span class="n">find_best_c</span><span class="p">(</span><span class="n">X_train</span><span class="p">,</span> <span class="n">y_train</span><span class="p">,</span> <span class="n">goal_ind</span><span class="p">)</span>
#     <span class="k">print</span><span class="p">(</span><span class="s2">&quot;Optimizing l2 with cross-validation gives C=</span><span class="si">%f</span><span class="s2"> and f1=</span><span class="si">%f</span><span class="s2">&quot;</span> <span class="o">%</span> <span class="p">(</span><span class="n">l2_c</span><span class="p">,</span> <span class="n">l2_f1</span><span class="p">))</span>
#
#     <span class="k">print</span><span class="p">(</span><span class="s2">&quot;Balanced bootstrapping method (add equal amounts of true/false examples)&quot;</span><span class="p">)</span>
#     <span class="k">for</span> <span class="n">percentage</span> <span class="ow">in</span> <span class="p">[</span><span class="mf">0.01</span><span class="p">,</span> <span class="mf">0.1</span><span class="p">,</span> <span class="mf">0.25</span><span class="p">]:</span>
#         <span class="n">svc</span> <span class="o">=</span> <span class="n">svm</span><span class="o">.</span><span class="n">LinearSVC</span><span class="p">()</span>
#         <span class="n">svc</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">X_train</span><span class="p">,</span> <span class="n">y_train</span><span class="p">)</span>
#         <span class="n">preds</span> <span class="o">=</span> <span class="n">svc</span><span class="o">.</span><span class="n">decision_function</span><span class="p">(</span><span class="n">X_test</span><span class="p">)</span>
#         <span class="n">added_X</span> <span class="o">=</span> <span class="p">[]</span>
#         <span class="n">added_y</span> <span class="o">=</span> <span class="p">[]</span>
#         <span class="k">for</span> <span class="n">i</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="nb">int</span><span class="p">(</span><span class="n">percentage</span> <span class="o">*</span> <span class="n">num_test_in
# 19.
# https://github.com/dkdfirefly/speaker_project/tree/master/code/src/classify.py
# <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span>  <span class="n">knn</span> <span class="o">=</span> <span class="n">neighbors</span><span class="o">.</span><span class="n">KNeighborsClassifier</span><span class="p">(</span><span class="n">n_neighbors</span> <span class="o">=</span> <span class="mi">10</span><span class="p">)</span>
#   <span class="n">knn</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">dataNP</span><span class="p">,</span><span class="n">labels</span><span class="p">)</span>
#   <span class="n">cm</span> <span class="o">=</span> <span class="n">confusion_matrix</span><span class="p">(</span><span class="n">labels</span><span class="p">,</span> <span class="n">knn</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">predNP</span><span class="p">))</span>
#   <span class="k">print</span> <span class="nb">str</span><span class="p">(</span><span class="n">cm</span><span class="p">)</span>
#   <span class="k">print</span> <span class="s1">&#39;</span><span class="se">\t</span><span class="s1">Accuracy: &#39;</span> <span class="o">+</span> <span class="nb">str</span><span class="p">(</span><span class="n">knn</span><span class="o">.</span><span class="n">score</span><span class="p">(</span><span class="n">predNP</span><span class="p">,</span> <span class="n">labels</span><span class="p">))</span>
#
#   <span class="k">print</span>
#   <span class="k">print</span> <span class="s1">&#39;Linear SVC&#39;</span>
#   <span class="k">print</span> <span class="s1">&#39;--------------&#39;</span>
#   <span class="k">print</span> <span class="s1">&#39;Confusion Matrix&#39;</span>
#   <span class="n">clf</span> <span class="o">=</span> <span class="n">svm</span><span class="o">.</span><span class="n">LinearSVC</span><span class="p">()</span>
#   <span class="n">clf</span><span class="o">.</span><span class="n">fit</span><span class="p">(</span><span class="n">dataNP</span><span class="p">,</span> <span class="n">labels</span><span class="p">)</span>
#   <span class="n">cm</span> <span class="o">=</span> <span class="n">confusion_matrix</span><span class="p">(</span><span class="n">labels</span><span class="p">,</span> <span class="n">clf</span><span class="o">.</span><span class="n">predict</span><span class="p">(</span><span class="n">predNP</span><span class="p">))</span>
#   <span class="k">print</span> <span class="nb">str</span><span class="p">(</span><span class="n">cm</span><span class="p">)</span>
#   <span class="k">print</span> <span class="s1">&#39;</span><span class="se">\t</span><span class="s1">Accuracy: &#39;</span> <span class="o">+</span> <span class="nb">str</span><span class="p">(</span><span class="n">clf</span><span class="o">.</span><span class="n">score</span><span class="p">(</span><span class="n">predNP</span><span class="p">,</span> <span class="n">labels</span><span class="p">))</span>
#
#   <span class="k">print</span>
#   <span class="k">print</span> <span class="s1">&#39;Gaussian NB&#39;</span>
#   <span class="k">print</span> <span class="s1">&#39;--------------&#39;</span>
#   <span class="k">print</span> <span class="s1">&#39;Confusion Matrix&#39;</span>
# </pre></div>

# %% [markdown]
# # Instantiation

# %% [markdown]
# ### Instantiation of RandomForestClassifier

# %%
def getInstantiation(modelName):
    instantiateQuery = """\
    SELECT
      REGEXP_EXTRACT(content, r'(%s *\(.*?\))') match,
      count(*) count
    FROM   
      [scikit-learn-research:pyfiles.content_py] 
    WHERE
      (NOT sample_repo_name CONTAINS "scikit-learn") AND
      (NOT sample_repo_name CONTAINS "sklearn") AND
      (NOT sample_path CONTAINS "scikit-learn") AND
      (NOT sample_path CONTAINS "sklearn")
    GROUP BY
    match
    HAVING
      (NOT match is NULL)
    ORDER BY
    count DESC
    """ % (modelName)
    return GithubPython().run(instantiateQuery)

# %%
rfcInst = getInstantiation("RandomForestClassifier")

# %%
rfcInst[:50]
# Out:
# [('RandomForestClassifier()', 361),
#  ('RandomForestClassifier(n_estimators=100)', 132),
#  ('RandomForestClassifier(random_state=0)', 56),
#  ('RandomForestClassifier(n_estimators=10)', 52),
#  ('RandomForestClassifier(n_estimators = 100)', 51),
#  ('RandomForestClassifier(n_estimators=100, n_jobs=-1)', 44),
#  ('RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)', 43),
#  ('RandomForestClassifier(n_estimators=500)', 25),
#  ('RandomForestClassifier(n_estimators=1000)', 19),
#  ('RandomForestClassifier(n_estimators=50)', 18),
#  ('RandomForestClassifier(n_classifiers)', 18),
#  ('RandomForestClassifier(n_jobs=-1)', 17),
#  ('RandomForestClassifier(**params)', 12),
#  ('RandomForestClassifier(n_estimators=25)', 12),
#  ('RandomForestClassifier(**kwargs)', 12),
#  ("RandomForestClassifier(n_estimators=1, criterion='entropy', max_depth=1)",
#   11),
#  ('RandomForestClassifier(n_jobs=2)', 11),
#  ('RandomForestClassifier(n_estimators=30)', 11),
#  ('RandomForestClassifier(n_estimators=300, n_jobs=-1)', 10),
#  ('RandomForestClassifier(n_estimators=n_estimators)', 10),
#  ('RandomForestClassifier(numTrees=3, maxDepth=2, labelCol="indexed", seed=42)',
#   10),
#  ('RandomForestClassifier(n_estimators=200)', 10),
#  ('RandomForestClassifier(n_estimators=20)', 10),
#  ('RandomForestClassifier(random_state=1)', 10),
#  ('RandomForestClassifier( n_estimators = 100 )', 10),
#  ('RandomForestClassifier(n_estimators=100, n_jobs=2)', 8),
#  ('RandomForestClassifier(n_estimators=50, n_jobs=-1)', 7),
#  ('RandomForestClassifier(n_estimators=100, random_state=1)', 7),
#  ('RandomForestClassifier(n_estimators=1000, n_jobs=-1)', 7),
#  ('RandomForestClassifier(n_estimators=rf_n_estimators, max_features=rf_max_features, random_state=random_state)',
#   7),
#  ('RandomForestClassifier(n_estimators=trees)', 6),
#  ('RandomForestClassifier(min_samples_split=100)', 6),
#  ('RandomForestClassifier(n_estimators = 100, n_jobs = 12, random_state = 4)',
#   6),
#  ('RandomForestClassifier(n_estimators=10, max_depth=None, min_samples_split=1, random_state=0)',
#   6),
#  ('RandomForestClassifier(n_estimators=750)', 6),
#  ('RandomForestClassifier(n_estimators=300)', 6),
#  ('RandomForestClassifier(min_samples_leaf=20,n_jobs=-1)', 5),
#  ('RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0)', 5),
#  ('RandomForestClassifier(n_estimators=1, verbose=verbose)', 5),
#  ('RandomForestClassifier(n_estimators=500, max_depth=None, min_samples_split=1, random_state=0)',
#   5),
#  ("RandomForestClassifier(n_estimators=100, n_jobs=-1, criterion='gini')", 5),
#  ('RandomForestClassifier(object)', 5),
#  ('RandomForestClassifier(n_estimators=50, verbose=2, compute_importances=True, n_jobs=-1)',
#   5),
#  ('RandomForestClassifier(n_estimators=150)', 4),
#  ('RandomForestClassifier(n_estimators = 50)', 4),
#  ("RandomForestClassifier(n_estimators=100,criterion= 'entropy')", 4),
#  ("RandomForestClassifier(criterion='entropy')", 4),
#  ('RandomForestClassifier(labelCol="indexedLabel", featuresCol="indexedFeatures", numTrees=10)',
#   4),
#  ('RandomForestClassifier(**self.params)', 4),
#  ('RandomForestClassifier(SklModel)', 4)]

# %% [markdown]
# ### When people use default param, do they use together with GridSearch?

# %%
def defaultInstantiationWithGridSearch(modelName):
    withGridSearch = """\
    SELECT
      COUNT(*) count from (
      SELECT
        REGEXP_EXTRACT(content, r'(%s *\(\))') match,
        content,
      FROM
        [scikit-learn-research:pyfiles.content_py]
      WHERE
        (NOT sample_repo_name CONTAINS "scikit-learn") AND
        (NOT sample_repo_name CONTAINS "sklearn") AND
        (NOT sample_path CONTAINS "scikit-learn") AND
        (NOT sample_path CONTAINS "sklearn") 
      )
    WHERE
      match!=""
      AND content CONTAINS 'GridSearchCV'
    """ % modelName
    withGridSearchNum = GithubPython().run(withGridSearch)[0][0]
    withoutGridSearch = """\
    SELECT
      COUNT(*) count from(
      SELECT
        REGEXP_EXTRACT(content, r'(%s *\(\))') match,
        content,
      FROM
        [scikit-learn-research:pyfiles.content_py]
      WHERE
        (NOT sample_repo_name CONTAINS "scikit-learn") AND
        (NOT sample_repo_name CONTAINS "sklearn") AND
        (NOT sample_path CONTAINS "scikit-learn") AND
        (NOT sample_path CONTAINS "sklearn")
      )
    WHERE
      match!=""
      AND NOT content CONTAINS 'GridSearchCV'
    """ % modelName
    withoutGridSearchNum = GithubPython().run(withoutGridSearch)[0][0]
    return (withGridSearchNum, withoutGridSearchNum)

# %%
rfcWithGridSearch, rfcWithoutGridSearch = defaultInstantiationWithGridSearch("RandomForestClassifier")

# %%
def plotPie(labels, sizes):
    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    plt.show()

# %%
labels = 'RandomForestClassifier() with GridSearchCV', 'RandomForestClassifier() without GridSearchCV'
sizes = [rfcWithGridSearch, rfcWithoutGridSearch]
plotPie(labels,sizes)

# %%
labels = 'SVC() with GridSearchCV', 'SVC() without GridSearchCV'
sizes = defaultInstantiationWithGridSearch('SVC')
plotPie(labels,sizes)

# %%
labels = 'LogisticRegression() with GridSearchCV', 'LogisticRegression() without GridSearchCV'
sizes = defaultInstantiationWithGridSearch('LogisticRegression')
plotPie(labels,sizes)
